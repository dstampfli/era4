# %% [markdown]
# # Setup

# %%
# %pip install -qU IProgress
# %pip install -qU ipywidgets
# %pip install -qU python-dotenv
# %pip install -qU tqdm

# %pip install -qU google-cloud-aiplatform
# %pip install -qU google-cloud-discoveryengine

# %pip install -qU langchain-google-community
# %pip install -qU langchain-google-genai
# %pip install -qU langchain-google-vertexai

# %pip install -qU ragas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.1.25 requires langchain-core<0.3.0,>=0.2.40, but you have langchain-core 0.3.29 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Environment Variables

# %%
# Get environment variables

from dotenv import load_dotenv


# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Utilities

# %%
# # Create embeddings using Vertex AI

# https://python.langchain.com/docs/integrations/text_embedding/google_vertex_ai_palm/

from langchain_google_vertexai import VertexAIEmbeddings

def create_embeddings_vertexai(model="text-embedding-004") -> VertexAIEmbeddings:

	creds, _ = google.auth.default(quota_project_id=os.environ["PROJECT_ID"])

	# Initialize the VertexAIEmbeddings class
	embeddings = VertexAIEmbeddings(model_name=model, 
								 credentials=creds)

	return embeddings

#####

def test_create_embeddings_vertexai():
	text = 'What is the annual revenue of Uber?'
	embeddings = create_embeddings_vertexai()
	vector = embeddings.embed_query(text)
	print(vector)
	return embeddings

test_create_embeddings_vertexai()
# Out:
# [0.02146485447883606, 0.0032845812384039164, -0.035835348069667816, 0.029619421809911728, -0.002756676869466901, 0.04315217211842537, -0.013563795015215874, 0.0016460827318951488, -0.03228216990828514, 0.033295925706624985, -0.022703394293785095, 0.00990962516516447, 0.01698439009487629, -0.007040613796561956, 0.02690504677593708, -0.045531436800956726, -0.06957240402698517, -0.012293071486055851, -0.09951302409172058, -0.07442105561494827, -0.008149843662977219, 0.016129935160279274, 0.016556166112422943, 0.04220563918352127, -0.036016568541526794, 0.002811049809679389, 0.024883603677153587, 0.027063611894845963, 0.0024628739338368177, 0.007052501197904348, 0.03644833341240883, 0.05271162837743759, -0.008111889474093914, -0.025406625121831894, -0.026322247460484505, -0.0005133617087267339, -0.0012304255506023765, 0.027262013405561447, 0.02606879360973835, -0.033861689269542694, -0.05780947580933571, 0.018501874059438705, -0.061953648924827576, 0.017459912225604057, 0.006403829902410507, 0.0306008979678154, -0.02825102210044861, -0.02412918210029602, -0.00019257381791248918, 0.04139157012104988, -0.027411239221692085, -0.049260884523391724, -0.05407671257853508, -0.0250693392008543, -0.02545267343521118, 0.0132816256955266, -0.013032644055783749, -0.10960797965526581, 0.060327496379613876, 0.019813664257526398, 0.006920375395566225, 0.023007700219750404, 0.004558029118925333, -0.03064144402742386, 0.00753128482028842, -0.033002760261297226, -0.02387900836765766, -0.019513152539730072, -0.11052271723747253, -0.017010869458317757, 0.004822090268135071, -0.054007746279239655, 0.019484547898173332, 0.028444185853004456, -0.008577539585530758, -0.014742949046194553, -0.037009671330451965, -0.03620409592986107, -0.03161210939288139, 0.03995346277952194, -0.024702755734324455, 0.041685979813337326, 0.08342889696359634, 0.07470826804637909, -0.0011657801223918796, 0.019277965649962425, -0.01562909223139286, -0.050447121262550354, 0.015046252869069576, -0.05561080574989319, 0.010246866382658482, -0.028178120031952858, 0.023360760882496834, 0.023514827713370323, 0.0555766262114048, 0.0021632828284054995, -0.08548973500728607, -0.02476329356431961, 0.12270603328943253, 0.03779442980885506, 0.01666048727929592, 0.041412413120269775, -0.002814170904457569, -0.002901161089539528, 0.039957739412784576, 0.05416307970881462, 0.012927082367241383, -0.0839867815375328, -0.013241195119917393, 0.0005913209170103073, 0.004506117198616266, -0.011793307960033417, -0.011387297883629799, 0.003207472851499915, 0.04036153480410576, -0.02764335460960865, -0.06031966954469681, -0.009362767450511456, -0.01745048351585865, 0.03938005119562149, 0.0011248437222093344, -0.04616066813468933, 0.034770917147397995, 0.02020980976521969, 0.03201165422797203, 0.03843627870082855, 0.06171894073486328, -0.006457731127738953, -0.07230325043201447, 0.016984188929200172, 0.02277345024049282, 0.011091361753642559, 0.006131213158369064, -0.004293062724173069, -0.009335711598396301, 0.00037540189805440605, 0.06229807436466217, -0.012011941522359848, -0.022644706070423126, 0.014638987369835377, 0.025196965783834457, -0.04239121451973915, -0.09044014662504196, -0.007291452027857304, -0.00020694210252258927, -0.027094876393675804, -0.019127801060676575, -0.05330045521259308, -0.0025132286828011274, 0.024461952969431877, 0.0074766092002391815, -0.05295750871300697, -0.02110215090215206, -0.018765011802315712, -0.031664032489061356, -0.10248909145593643, 0.029783982783555984, 0.005768104922026396, 0.05262453854084015, 0.03934596851468086, -0.05793483182787895, 0.018847744911909103, -0.035362523049116135, -0.04170716553926468, 0.036016032099723816, 0.057037267833948135, -0.021955933421850204, 0.009745470248162746, 0.000635842327028513, 0.04318392276763916, -0.033049438148736954, 0.008035236969590187, -0.028408564627170563, -0.09056351333856583, -0.03972301259636879, 0.03777423873543739, -0.007540978491306305, -0.028110848739743233, -0.010413297452032566, -0.07748562097549438, 0.04 ...
# VertexAIEmbeddings(client=<vertexai.language_models.TextEmbeddingModel object at 0x138797a10>, async_client=None, project='era4-holiday', location='us-central1', request_parallelism=5, max_retries=6, stop=None, model_name='text-embedding-004', full_model_name=None, client_options=ClientOptions: {'api_endpoint': 'us-central1-aiplatform.googleapis.com', 'client_cert_source': None, 'client_encrypted_cert_source': None, 'quota_project_id': None, 'credentials_file': None, 'scopes': None, 'api_key': None, 'api_audience': None, 'universe_domain': None}, api_endpoint=None, api_transport=None, default_metadata=(), additional_headers=None, client_cert_source=None, credentials=<google.oauth2.credentials.Credentials object at 0x138a630d0>, client_preview=None, temperature=None, max_output_tokens=None, top_p=None, top_k=None, n=1, seed=None, streaming=False, model_family=None, safety_settings=None, tuned_model_name=None, instance={'max_batch_size': 250, 'batch_size': 250, 'min_batch_size': 5, 'min_good_batch_size': 5, 'lock': <unlocked _thread.lock object at 0x138aa2f40>, 'batch_size_validated': False, 'task_executor': <concurrent.futures.thread.ThreadPoolExecutor object at 0x11a56bbd0>, 'get_embeddings_with_retry': <function _TextEmbeddingModel.get_embeddings at 0x138cb0d60>})

# %%
# Create a Vertex AI retriever

# https://python.langchain.com/docs/integrations/retrievers/google_vertex_ai_search/

from langchain_google_community import VertexAISearchRetriever

def create_retriever_vertexai() -> VertexAISearchRetriever:

	retriever = VertexAISearchRetriever(project_id=os.environ["PROJECT_ID"], location_id=os.environ["LOCATION_ID"], data_store_id=os.environ["DATA_STORE_ID"], max_documents=3)

	return retriever

#####

def test_create_retriever_vertexai(text:str):
	retriever = create_retriever_vertexai()
	docs = retriever.invoke(text)
	print(docs[0])

test_create_retriever_vertexai("What is the annual revenue of Uber?")
# Out:
# page_content='# Note 2 - Revenue
#
# The following tables present our revenues disaggregated by offering and geographical region. Revenue by geographical region is based on where the transaction occurred. This level of disaggregation takes into consideration how the nature, amount, timing, and uncertainty of revenue and cash flows are affected by economic factors (in millions):
#
# _START_OF_TABLE_
# TABLE_IN_MARKDOWN:
# |-|-|-|-|
# |  |  | Year Ended December 31, |  |
# |  | 2021 | 2022 | 2023 |
# | Mobility revenue (1) | 6,953 $ | $ 14,029 | $ 19,832 |
# | Delivery revenue (1) | 8,362 | 10,901 | 12,204 |
# | Freight revenue | 2,132 | 6,947 | 5,245 |
# | All Other revenue | 8 |  |  |
# | Total revenue | 17,455 $ | $ 31,877 | $ 37,281 |
#
# _END_OF_TABLE_
# (1) We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass ("Subscription"). We recognize Subscription fees ratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering during the respective period.
#
# _START_OF_TABLE_
# TABLE_IN_MARKDOWN:
# |-|-|-|-|-|-|
# |  |  | Year Ended December 31, |  |  |  |
# |  | 2021 | 2022 |  |  | 2023 |
# | United States and Canada ("US&CAN") Latin America ("LatAm") | $ 10,094 1,417 | $ | 19,474 1,978 | $ | 20,436 2,512 |
# | Europe, Middle East and Africa ("EMEA") Asia Pacific ("APAC") | 3,213 2,731 |  | 6,944 3,481 |  | 9,904 4,429 |
# | Total revenue | $ 17,455 | $ | 31,877 | $ | 37,281 |
#
# _END_OF_TABLE_
#
#
# # Revenue
#
# Mobility Revenue We derive revenue from fees paid by Mobility Drivers for the use of our platform(s) and related services to facilitate and complete Mobility services and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Mobility revenue also includes immaterial revenue streams such as our financial partnerships products. Additionally, in certain markets where we are responsible for Mobility services, fees charged to end-users are also included in revenue, while payments to Drivers in exchange for Mobility services are recognized in cost of revenue, exclusive of depreciation and amortization.
#
# # Delivery Revenue
#
# We derive revenue for Delivery from Merchants' and Couriers' use of the Delivery platform and related service to facilitate and complete Delivery transactions and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Additionally, in certain markets where we are responsible for Delivery services, delivery fees charged to end-users are also included in revenue, while payments to Couriers in exchange for Delivery services are recognized in cost of revenue, exclusive of depreciation and amortization. Delivery also includes advertising revenue from sponsored listing fees paid by Merchants and brands in exchange for advertising services.' metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'year': '2023', 'type': '10-K', 'company': 'Uber', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.799920916557312}

# %%
# Create a prompt template

# https://python.langchain.com/v0.1/docs/modules/model_io/prompts/quick_start/#chatprompttemplate
# https://python.langchain.com/v0.2/api_reference/core/prompts/langchain_core.prompts.chat.ChatPromptTemplate.html

from langchain.prompts import ChatPromptTemplate

def create_chat_prompt_template(template: str = None) -> ChatPromptTemplate:
	
	if template is None:
		template = '''
		You are an expert assistant designed to help users analyze and answer questions about 10K annual reports filed by publicly traded companies. Users may ask about specific sections, financial metrics, trends, or comparisons across multiple reports. Your role is to provide accurate, concise, and relevant answers, referencing appropriate sections or data points where applicable.

		When responding, adhere to the following principles:

		Understand the Question: Identify whether the query is focused on a specific company, year, or metric, or if it spans multiple reports for comparison.
		Clarify Uncertainty: If a user's question is unclear, ask for clarification or additional context.
		Locate and Reference Information: Use relevant sections of the 10K report(s), such as MD&A, Financial Statements, Risk Factors, or Notes to Financial Statements, to back up your answers.
		Synthesize Data: Provide summaries or insights when the question involves comparing data or trends across multiple reports.
		Stay Objective: Avoid providing subjective opinions or interpretations beyond the factual content in the reports.
		Example User Queries and Expected Responses:

		"What was the revenue for Company X in 2022 and 2023?"

		Locate and report the revenue figures from the Income Statements of the respective 10K reports for 2022 and 2023.
		"What are the main risk factors for Company Y in its latest report?"

		Summarize the key risk factors from the most recent 10K report's "Risk Factors" section.
		"How did the operating income of Company Z change over the last three years?"

		Extract operating income figures from the 10K reports for the past three years and provide a brief comparison.
		"Compare the debt levels of Company A and Company B in 2023."

		Retrieve debt-related figures from the Balance Sheets or Notes to Financial Statements of both companies and summarize the comparison.
		"What trends are evident in Company W's R&D expenses over the last five years?"

		Summarize trends using data from the Income Statements or footnotes for R&D expenses across five consecutive 10K reports.
		Assumptions and Constraints:

		Only use inforomation from 10K reports provided in the context below. 
		For complex queries spanning multiple reports, provide a structured summary highlighting key comparisons or trends.
		If certain information is unavailable, state so clearly and suggest alternative approaches to obtain it.

		Now it's your turn!
		
		{question}

		{context}
		'''
	
	prompt = ChatPromptTemplate.from_template(template)

	return prompt

#####

def test_create_chat_prompt_template():
	prompt = create_chat_prompt_template()
	
	print(prompt)

# test_create_chat_prompt_template()

# %%
# Create a Langchain chain..

# https://python.langchain.com/docs/integrations/llms/google_ai/
# https://python.langchain.com/docs/integrations/chat/google_generative_ai/
# https://ai.google.dev/gemini-api/docs/safety-settings 

from google.generativeai.types import HarmCategory, HarmBlockThreshold
from langchain_core.retrievers import BaseRetriever
from langchain_core.runnables import RunnablePassthrough
from langchain_core.runnables import RunnableSerializable
from langchain_google_genai import ChatGoogleGenerativeAI
from operator import itemgetter

def create_chain (model_name: str, 
				  prompt_template: ChatPromptTemplate, 
				  retriever: BaseRetriever) -> RunnableSerializable:

	llm = ChatGoogleGenerativeAI(
		model=model_name,
		temperature=0,
		safety_settings={
				HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_ONLY_HIGH,
				HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_ONLY_HIGH,
				HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_ONLY_HIGH,
				HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_ONLY_HIGH,
			},
		)
		
	chain = (
		{"context": itemgetter("question") | retriever, "question": itemgetter("question")} 
		| RunnablePassthrough.assign(context=itemgetter("context")) 
		| {"response": prompt_template | llm, "context": itemgetter("context")}
		)

	return chain

#####


def test_create_chain_vertexai():
	retreiver = create_retriever_vertexai()
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain('gemini-1.5-flash', chat_prompt_template, retreiver)
	result = chain.invoke({'question' : 'What is the annual revenue of Uber?'})
	print(result)

# test_create_chain_vertexai()
# Out:
# {'response': AIMessage(content='Uber\'s total revenue for 2023 was $37,281 million.  This is according to the "Note 2 - Revenue" section of their 2023 10-K report.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-52df6fb2-c767-4d37-a896-27d709c53367-0', usage_metadata={'input_tokens': 2479, 'output_tokens': 50, 'total_tokens': 2529, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'year': '2023', 'type': '10-K', 'company': 'Uber', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.799920916557312}, page_content='# Note 2 - Revenue\n\nThe following tables present our revenues disaggregated by offering and geographical region. Revenue by geographical region is based on where the transaction occurred. This level of disaggregation takes into consideration how the nature, amount, timing, and uncertainty of revenue and cash flows are affected by economic factors (in millions):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2021 | 2022 | 2023 |\n| Mobility revenue (1) | 6,953 $ | $ 14,029 | $ 19,832 |\n| Delivery revenue (1) | 8,362 | 10,901 | 12,204 |\n| Freight revenue | 2,132 | 6,947 | 5,245 |\n| All Other revenue | 8 |  |  |\n| Total revenue | 17,455 $ | $ 31,877 | $ 37,281 |\n\n_END_OF_TABLE_\n(1) We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass ("Subscription"). We recognize Subscription fees ratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering during the respective period.\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|-|\n|  |  | Year Ended December 31, |  |  |  |\n|  | 2021 | 2022 |  |  | 2023 |\n| United States and Canada ("US&CAN") Latin America ("LatAm") | $ 10,094 1,417 | $ | 19,474 1,978 | $ | 20,436 2,512 |\n| Europe, Middle East and Africa ("EMEA") Asia Pacific ("APAC") | 3,213 2,731 |  | 6,944 3,481 |  | 9,904 4,429 |\n| Total revenue | $ 17,455 | $ | 31,877 | $ | 37,281 |\n\n_END_OF_TABLE_\n\n\n# Revenue\n\nMobility Revenue We derive revenue from fees paid by Mobility Drivers for the use of our platform(s) and related services to facilitate and complete Mobility services and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Mobility revenue also includes immaterial revenue streams such as our financial partnerships products. Additionally, in certain markets where we are responsible for Mobility services, fees charged to end-users are also included in revenue, while payments to Drivers in exchange for Mobility services are recognized in cost of revenue, exclusive of depreciation and amortization.\n\n# Delivery Revenue\n\nWe derive revenue for Delivery from Merchants\' and Couriers\' use of the Delivery platform and related service to facilitate and complete Delivery transactions and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Additionally, in certain markets where we are responsible for Delivery services, delivery fees charged to end-users are also included in revenue, while payments to Couriers in exchange for Delivery services are recognized in cost of revenue, exclusive of depreciation and amortization. Delivery also includes advertising revenue from sponsored listing fees paid by Merchants and brands in exchange for advertising services.'), Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments':  ...

# %%
# Generate answers from a chain using a list of questions

from typing import List, Tuple

from langchain_core.output_parsers import JsonOutputParser, StrOutputParser
from langchain_core.runnables import RunnableSerializable


def generate_answers_contexts(chain: RunnableSerializable, 
							  questions: list
							  ) -> Tuple[List, List]:
	
	answers = []
	contexts = []

	# Loop over the list of questions and call the chain to get the answer and context
	for question in questions:
		print(question)

		# Call the chain to get answers and contexts
		response = chain.invoke({"question" : question})
		print(response)

		# Capture the answer and context 
		answers.append(response["response"].content)
		contexts.append([context.page_content for context in response["context"]])

	return answers, contexts

#####

def test_generate_answers_contexts():
	retreiver = create_retriever_vertexai()
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain('gemini-1.5-flash', chat_prompt_template, retreiver)
	
	questions = ["What is the annual revenue of Lyft?",
			  "What is the annual revenue of Uber?",
			  "Which company has a larger annual revenue - Lyft or Uber?"]	
	
	answers, contexts = generate_answers_contexts(chain=chain, questions=questions)
	
	print(f"Total number of answers = {len(answers)}")
	print(f"Total number of contexts = {len(contexts)}")

# test_generate_answers_contexts()
# Out:
# What is the annual revenue of Lyft?
# {'response': AIMessage(content='Lyft\'s total revenue for 2023 was $4,403,589,000.  This is according to the "Lyft, Inc. Notes to Consolidated Financial Statements" section of their 2023 10-K report.  The report breaks this down into $4,116,216,000 from contracts with customers and $287,373,000 in rental revenue.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-3c4cd5cb-bb24-4fd1-95c3-ec221317bc0d-0', usage_metadata={'input_tokens': 2139, 'output_tokens': 104, 'total_tokens': 2243, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'year': '2023', 'type': '10-K', 'company': 'lyft', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.790586531162262}, page_content='# Lyft, Inc. Notes to Consolidated Financial Statements\n\n## Revenue Recognition\n\nThe Company generates its revenue from its multimodal transportation networks that offer access to a variety of transportation options through the Lyft Platform and mobile-based applications. Substantially all, or approximately 85% or more, of the Company\'s revenue is generated from its ridesharing marketplace that connects drivers and riders and is recognized in accordance 83 with Accounting Standards Codification Topic 606 (“ASC 606"). In addition, the Company generates revenue in accordance with ASC 606 from licensing and data access, subscription fees, revenue from bikes and bike station hardware and software sales and revenue from arrangements to provide advertising services to third parties, which are not significant components of the Company\'s consolidated revenues. The Company also generates rental revenue from Flexdrive and its network of Light Vehicles, which is recognized in accordance with Accounting Standards Codification Topic 842 ("ASC 842"). The table below presents the Company\'s revenues as included on the consolidated statements of operations (in thousands):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2023 | 2022 | 2021 |\n| Revenue from contracts with customers (ASC 606) | 4,116,216 $ | $ 3,811,993 $ | 2,957,979 |\n| Rental revenue (ASC 842) | 287,373 | 283,142 | 250,344 |\n| Total revenue | 4,403,589 $ | $ 4,095,135 $ | 3,208,323 |\n\n_END_OF_TABLE_\n'), Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7285593748092651}, page_content='# Note 2 - Revenue\n\nThe following tables present our revenues disaggregated by offering and geographical region. Revenue by geographical region is based on where the transaction occurred. This level of disaggregation takes into consideration how the nature, amount, timing, and uncertainty of revenue and cash flows are affected by economic factors (in millions):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2021 | 2022 | 2023 |\n| Mobility revenue (1) | 6,953 $ | $ 14,029 | $ 19,832 |\n| Delivery revenue (1) | 8,362 | 10,901 | 12,204 |\n| Freight revenue | 2,132 | 6,947 | 5,245 |\n| All Other revenue | 8 |  |  |\n| Total revenue | 17,455 $ | $ 31,877 | $ 37,281 |\n\n_END_OF_TABLE_\n(1) We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass ("Subscription"). We recognize Subscription fees ratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering during the respective period.\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|-|\n|  |  | Year Ended  ...
# What is the annual revenue of Uber?
# {'response': AIMessage(content='Uber\'s total revenue for 2023 was $37,281 million.  This is according to the "Note 2 - Revenue" section of their 2023 10-K report.  The report breaks this down further by service type (Mobility, Delivery, Freight) and geographic region.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-5b464652-2803-40a9-b30e-9b07daea9e15-0', usage_metadata={'input_tokens': 2479, 'output_tokens': 71, 'total_tokens': 2550, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.799920916557312}, page_content='# Note 2 - Revenue\n\nThe following tables present our revenues disaggregated by offering and geographical region. Revenue by geographical region is based on where the transaction occurred. This level of disaggregation takes into consideration how the nature, amount, timing, and uncertainty of revenue and cash flows are affected by economic factors (in millions):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2021 | 2022 | 2023 |\n| Mobility revenue (1) | 6,953 $ | $ 14,029 | $ 19,832 |\n| Delivery revenue (1) | 8,362 | 10,901 | 12,204 |\n| Freight revenue | 2,132 | 6,947 | 5,245 |\n| All Other revenue | 8 |  |  |\n| Total revenue | 17,455 $ | $ 31,877 | $ 37,281 |\n\n_END_OF_TABLE_\n(1) We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass ("Subscription"). We recognize Subscription fees ratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering during the respective period.\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|-|\n|  |  | Year Ended December 31, |  |  |  |\n|  | 2021 | 2022 |  |  | 2023 |\n| United States and Canada ("US&CAN") Latin America ("LatAm") | $ 10,094 1,417 | $ | 19,474 1,978 | $ | 20,436 2,512 |\n| Europe, Middle East and Africa ("EMEA") Asia Pacific ("APAC") | 3,213 2,731 |  | 6,944 3,481 |  | 9,904 4,429 |\n| Total revenue | $ 17,455 | $ | 31,877 | $ | 37,281 |\n\n_END_OF_TABLE_\n\n\n# Revenue\n\nMobility Revenue We derive revenue from fees paid by Mobility Drivers for the use of our platform(s) and related services to facilitate and complete Mobility services and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Mobility revenue also includes immaterial revenue streams such as our financial partnerships products. Additionally, in certain markets where we are responsible for Mobility services, fees charged to end-users are also included in revenue, while payments to Drivers in exchange for Mobility services are recognized in cost of revenue, exclusive of depreciation and amortization.\n\n# Delivery Revenue\n\nWe derive revenue for Delivery from Merchants\' and Couriers\' use of the Delivery platform and related service to facilitate and complete Delivery transactions and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Additionally, in certain markets where we are responsible for Delivery services, delivery fees charged to end-users are also included in revenue, while payments to Couriers in exchange for Delivery services are recognized in cost of revenue, exclusive of depreciation and amortization. Delivery also includes advertising revenue from sponsored listing fees paid by Merchants and brands in exchange for advertising services.'), Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'year': '2023', 'type': '10-K', 'company': 'lyft', 'url': 'https://d18 ...
# Which company has a larger annual revenue - Lyft or Uber?
# {'response': AIMessage(content='Based on the provided 2023 10-K reports, Uber had a larger annual revenue than Lyft.  Uber reported $37,281 million in revenue, while Lyft reported $4,403,589 thousand ($4,403.59 million).\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-e86fa9be-5be3-4c6a-a7d7-d7d636eca4f6-0', usage_metadata={'input_tokens': 2074, 'output_tokens': 65, 'total_tokens': 2139, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7134150266647339}, page_content='# Lyft, Inc. Notes to Consolidated Financial Statements\n\n## Revenue Recognition\n\nThe Company generates its revenue from its multimodal transportation networks that offer access to a variety of transportation options through the Lyft Platform and mobile-based applications. Substantially all, or approximately 85% or more, of the Company\'s revenue is generated from its ridesharing marketplace that connects drivers and riders and is recognized in accordance 83 with Accounting Standards Codification Topic 606 (“ASC 606"). In addition, the Company generates revenue in accordance with ASC 606 from licensing and data access, subscription fees, revenue from bikes and bike station hardware and software sales and revenue from arrangements to provide advertising services to third parties, which are not significant components of the Company\'s consolidated revenues. The Company also generates rental revenue from Flexdrive and its network of Light Vehicles, which is recognized in accordance with Accounting Standards Codification Topic 842 ("ASC 842"). The table below presents the Company\'s revenues as included on the consolidated statements of operations (in thousands):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2023 | 2022 | 2021 |\n| Revenue from contracts with customers (ASC 606) | 4,116,216 $ | $ 3,811,993 $ | 2,957,979 |\n| Rental revenue (ASC 842) | 287,373 | 283,142 | 250,344 |\n| Total revenue | 4,403,589 $ | $ 4,095,135 $ | 3,208,323 |\n\n_END_OF_TABLE_\n'), Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'year': '2023', 'type': '10-K', 'company': 'Uber', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.6799073219299316}, page_content='# Driver Classification Developments\n\nIn addition, if we are required to classify Drivers as employees, this may impact our current financial statement presentation including revenue, cost of revenue, incentives and promotions as further described in Note 1 - Description of Business and Summary of Significant Accounting Policies in the notes to the consolidated financial statements included in Part II, Item 8, "Financial Statements and Supplementary Data," and the section titled "Critical Accounting Estimates" in Part II, Item 7, of this Annual Report on Form 10-K. 49\n\n# Financial and Operational Highlights\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|\n|  |  |  | Year Ended December 31, |  |\n| (In millions, except percentages) | 2022 | 2023 | % Change | % Change (Constant Currency (1) |\n| Monthly Active Platform Consumers (“MAPCs”) (2), (3) | 131 | 150 | 15% |  |\n| Trips (2) | 7,642 | 9,448 | 24% |  |\n| Gross Bookings (2) | 115,395 $ $ 137,865 |  | 19% | 20% |\n| Revenue | 31,877 $ | $ 37,281 | 17% | 18% |\n| Income (loss) from operations | (1,832) $ | $ 1,110 | ** |  |\n| Net income (loss) attributable to Uber Technologies, Inc. Adjusted EBITDA (1), (2) | (9,141) $ 1,713 $ | $ 1,887 $ 4,052 | ** 137% |  |\n| Net cash provid ...
# Total number of answers = 3
# Total number of contexts = 3

# %%
# Run a Ragas evaluation 

import time
from typing import Tuple

import pandas as pd
from pandas import DataFrame

from datasets import Dataset
from langchain_core.runnables import RunnableSerializable
from ragas import evaluate
from ragas.metrics import (
    answer_correctness,
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness,
)

def run_ragas_evaluation(chain: RunnableSerializable, 
						questions: list, 
						groundtruths: list, 
						eval_metrics: list = [answer_correctness, answer_relevancy, context_recall, context_precision, faithfulness]
						):
	
	answers = []
	contexts = []
	answers, contexts = generate_answers_contexts(chain=chain, questions=questions)

	# Create the input dataset 
	input_dataset = Dataset.from_dict({"question" : questions,       	# From the dataframe
										"answer" : answers,             # From the chain
										"contexts" : contexts,          # From the chain
										"ground_truth" : groundtruths   # From the dataframe
										})

	# Run the Ragas evaluation using the input dataset and eval metrics
	ragas_results = evaluate(input_dataset, eval_metrics)
	ragas_results_df = ragas_results.to_pandas()
	
	return ragas_results, ragas_results_df
	
#####

def test_run_ragas_evaluation():
	retreiver = create_retriever_vertexai()
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain('gemini-1.5-flash', chat_prompt_template, retreiver)
	
	testset_df = pd.read_csv("testsets/10k_test_testset.csv")	# This testset contains a small number of questions
	questions = testset_df["question"].values.tolist()
	questions = [str(question) for question in questions]
	groundtruths = testset_df["ground_truth"].values.tolist()
	groundtruths = [str(ground_truth) for ground_truth in groundtruths]  
	eval_metrics = [answer_correctness, answer_relevancy, context_precision, context_recall, faithfulness]
	ragas_results, ragas_results_df = run_ragas_evaluation(chain, questions, groundtruths, eval_metrics)
	
	timestr = time.strftime("%Y%m%d%H%M%S")
	ragas_results_df.to_csv(f"evaluations/10x_test_testset_evaluation_{timestr}.csv")
	
	print(ragas_results)

test_run_ragas_evaluation()
# Out:
# What challenges do jurisdictions pose to business operations in the context of regulatory compliance?
# {'response': AIMessage(content="Based on the provided Uber 10-K report excerpt, jurisdictions pose several challenges to business operations regarding regulatory compliance:\n\n1. **Conflicting and Differing Regulations:** Uber operates in numerous jurisdictions with varying and sometimes conflicting laws and regulations related to its business model (including Mobility, Delivery, and Freight products).  This fragmented regulatory environment creates significant complexities.\n\n2. **Evolving and Uncertain Regulations:**  Laws and regulations are constantly evolving, and their interpretation and application can be unpredictable. This uncertainty poses a risk to Uber's business.\n\n3. **Restrictions on Ridesharing:** Some jurisdictions (Argentina, Germany, Italy, Japan, South Korea, and Spain are specifically mentioned) have either banned certain ridesharing products or imposed significant operational restrictions.  This directly limits Uber's ability to operate in these markets.\n\n4. **Extensive Compliance Requirements:**  Many jurisdictions, particularly in the US, have implemented Transportation Network Company (TNC) regulations. These regulations impose numerous requirements on companies like Uber, covering areas such as background checks, vehicle inspections, insurance, driver training, and safety.  Compliance with these diverse and potentially stringent regulations is a significant operational challenge.\n\n5. **Lack of Regulation in Some Jurisdictions:** The excerpt highlights that while some jurisdictions have adopted TNC regulations, others have not. This inconsistency creates further complexity for Uber's operations and necessitates a flexible approach to compliance across different regions.\n\n\nThe Lyft 10-K excerpt does not directly address jurisdictional challenges to regulatory compliance in the same detail as the Uber excerpt.  It focuses more on the risks associated with acquisitions and investments, including the potential for acquired companies to lack adequate controls and compliance procedures, and the risk of new, adverse regulations impacting acquired businesses.  However, this indirectly supports the challenges highlighted in the Uber excerpt, as acquiring companies in different jurisdictions would inherently expose Lyft to the same complexities of varying regulatory landscapes.\n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-c275bf85-94b8-4b9a-84de-45f18efeed5c-0', usage_metadata={'input_tokens': 2000, 'output_tokens': 389, 'total_tokens': 2389, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.6214617490768433}, page_content='# PART I\n\n## Government Regulation\n\nWe operate in a particularly complex legal and regulatory environment. Our business is subject to a variety of U.S. federal, state, local and foreign laws, rules, and regulations, including those related to Internet activities, privacy, cybersecurity, data protection, intellectual property, competition, consumer protection, payments, labor and employment, transportation services, transportation network companies, licensing regulations and taxation. These laws and regulations are constantly evolving and may be interpreted, applied, created, or amended, in a manner that could harm our business. Examples of certain laws and regulations we are subject to are described below. For further discussion of risks relating to government regulation, see our risk factors, including the risk factors in the section titled "Legal and Regulatory Risks Related to Our Business" in Part I, Item 1A of this Annual Report on Form 10-K. Our platform, and in partic ...
# What challenges does competition in technology pose for maintaining interoperability of platforms?
# {'response': AIMessage(content='Competition in the technology sector poses several challenges to maintaining platform interoperability for companies like Lyft and Uber.  Both companies\' 10-K filings highlight these risks:\n\n* **Third-party actions:** Competitors or technology partners may take actions that disrupt interoperability.  This could involve changes to their products, standards, or terms of use that negatively impact the functionality or performance of Lyft\'s and Uber\'s platforms (Lyft 2023 10-K).  This could also include preferential treatment given to competing products or services.  Uber\'s 2023 10-K specifically mentions reliance on open marketplaces like the Apple App Store and Google Play, and the potential for these marketplaces to change their structures or fees, impacting distribution.\n\n* **Evolving third-party applications and services:**  The constant evolution of third-party applications, products, and services makes it difficult for Lyft and Uber to maintain compatibility.  Modifying their platforms to ensure ongoing compatibility requires significant resources and may not always be feasible (Lyft 2023 10-K; Uber 2023 10-K).  Uber highlights the reliance on Google Maps as a critical component, emphasizing the risk if Google were to alter access or terms.\n\n* **Software errors and vulnerabilities:** The complexity of the software underlying these platforms increases the risk of undetected errors or vulnerabilities.  Lyft\'s use of "continuous deployment" further amplifies this risk.  Errors or vulnerabilities, whether in their own code or in third-party software, could lead to negative publicity, user loss, revenue loss, security breaches, and the need for significant resources to address these issues (Lyft 2023 10-K).\n\n\nIn summary, the dynamic nature of the technology landscape, coupled with reliance on third-party services and the inherent complexities of software development, creates significant challenges for maintaining the interoperability of ride-sharing platforms.  The potential for competitive actions and evolving third-party offerings introduces considerable uncertainty and risk.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-aba0eab6-0b26-4270-99dc-b647b2f35ba3-0', usage_metadata={'input_tokens': 1974, 'output_tokens': 422, 'total_tokens': 2396, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.5300078392028809}, page_content='# We depend on the interoperability of our platform across third-party applications and services that we do not control.\n\nWe have integrations with a variety of productivity, collaboration, travel, data management and security vendors. As our offerings expand and evolve, including to the extent we continue to develop autonomous technology, we may have an increasing number of integrations with other third-party applications, products and services. Third-party applications, products and services are constantly evolving, and we may not be able to maintain or modify our platform to ensure its compatibility with third-party offerings following development changes. In addition, some of our competitors or technology partners may take actions which disrupt the interoperability of our platform with their own products or services, or exert strong business influence on our ability to, and the terms on which we operate and distribute our platform. As our respective products evolve, we expect the types and levels of competition to 35 increase. Should any of our competitors or technology partners modify their products, standards or terms of use in a manner that degrades t ...
# Evaluating:   0%|          | 0/10 [00:00<?, ?it/s]
# {'answer_correctness': 0.3091, 'answer_relevancy': 0.9143, 'context_precision': 1.0000, 'context_recall': 1.0000, 'faithfulness': 0.7404}

# %% [markdown]
# # Environment Checks

# %%
# Check user permissions

import os
import sys

import google.auth

# If running in Colab, use the permissions of the currently authenticated user
if 'google.colab' in sys.modules:
	print('Running in Google Colab')
	from google.colab import auth

	auth.authenticate_user()

# If not, set the GOOGLE_APPLICATION_CREDENTIALS to the service account credentials file 
else:
	print('Running locally')
	# os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'credentials.json'
	# print(os.environ['GOOGLE_APPLICATION_CREDENTIALS'])

#####

def test_google_perms():
	from google.cloud import storage
	
	creds, _ = google.auth.default(quota_project_id=os.environ["PROJECT_ID"])

	# Now, you can use the Google Cloud client libraries
	client = storage.Client(credentials=creds)

	# List all buckets in your project
	buckets = list(client.list_buckets())
	print(buckets)

test_google_perms()
# Out:
# Running locally
# [<Bucket: 10k-docs>, <Bucket: 351215155115_us_central1_import_custom>, <Bucket: 351215155115_us_central1_import_document>]

# %%
# Check Google API key

import requests

GOOGLE_API_KEY = os.environ['GOOGLE_API_KEY']
url = f'https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent?key={GOOGLE_API_KEY}'
  
headers = {
	"Content-Type": "application/json",
}
  
data = {"contents":[{"parts":[{"text":"What was Uber's annual revenue for 2022?"}]}]}

response = requests.post(url, headers=headers, json=data)
print(response.text)
# Out:
# {
#   "candidates": [
#     {
#       "content": {
#         "parts": [
#           {
#             "text": "Uber's annual revenue for 2022 was **$31.9 billion**.\n"
#           }
#         ],
#         "role": "model"
#       },
#       "finishReason": "STOP",
#       "avgLogprobs": -0.0052050462081318812
#     }
#   ],
#   "usageMetadata": {
#     "promptTokenCount": 14,
#     "candidatesTokenCount": 21,
#     "totalTokenCount": 35
#   },
#   "modelVersion": "gemini-1.5-flash-latest"
# }

# %%
# Check Vertex AI Agent Builder data store

import json

import google.auth
from google.auth.transport.requests import Request
import requests

def query_chunks(query: str, 
				page_size: int, 
				access_token:str) -> str:
		
	PROJECT_ID = os.environ['PROJECT_ID']
	LOCATION_ID = os.environ['LOCATION_ID']
	DATA_STORE_ID = os.environ['DATA_STORE_ID']

	if LOCATION_ID == 'us':
		api_endpoint = 'us-discoveryengine.googleapis.com'
	else:
		api_endpoint = 'discoveryengine.googleapis.com'

	url = f"https://{api_endpoint}/v1alpha/projects/{PROJECT_ID}/locations/{LOCATION_ID}/collections/default_collection/dataStores/{DATA_STORE_ID}/servingConfigs/default_search:search"
	print(url)
	
	headers = {
			"Authorization": f"Bearer {access_token}",
			"Content-Type": "application/json",
	}
	
	post_data = {
			"servingConfig": f"projects/{PROJECT_ID}/locations/{LOCATION_ID}/collections/default_collection/dataStores/{DATA_STORE_ID}/servingConfigs/default_search",
			"pageSize": page_size,
			"query": query,
			"contentSearchSpec": {"searchResultMode": "CHUNKS"},
	}
	
	response = requests.post(url, headers=headers, json=post_data)

	if response.status_code != 200:
		print(
				f"Error retrieving search results: {response.status_code} -"
				f" {response.text}"
		)

	return response.json()

#####

def test_query_chunks():
	creds, _ = google.auth.default()
	creds.refresh(Request())
	access_token = creds.token
	print(access_token)
	response = query_chunks(query = "What is the annual revenue of Uber?", page_size=3, access_token=access_token)
	print(json.dumps(response, indent=4))

test_query_chunks()
# Out:
# ya29.a0ARW5m77LeuENt6Yk1dWywbrX8GB--5F2egzWhDdIpAPoU5tdNm4wnYObVMrr1nUqbSCTKe9bxotnT3ad8PNfByK2PiG5VDnD6_o6eVnRlsqqtQNpIp-MaJW2wKn0KCiWAlhUqvmJCFMPGxen9oCWKqQCDFViCy-P5U17JE2NhpgaCgYKAcsSARESFQHGX2MiUKYpscaHLwZDRs3GfoGTaQ0178
# https://us-discoveryengine.googleapis.com/v1alpha/projects/era4-holiday/locations/us/collections/default_collection/dataStores/10k-docs_1735917605966/servingConfigs/default_search:search
# {
#     "results": [
#         {
#             "chunk": {
#                 "name": "projects/351215155115/locations/us/collections/default_collection/dataStores/10k-docs_1735917605966/branches/0/documents/2/chunks/c209",
#                 "id": "c209",
#                 "content": "# Note 2 - Revenue\n\nThe following tables present our revenues disaggregated by offering and geographical region. Revenue by geographical region is based on where the transaction occurred. This level of disaggregation takes into consideration how the nature, amount, timing, and uncertainty of revenue and cash flows are affected by economic factors (in millions):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2021 | 2022 | 2023 |\n| Mobility revenue (1) | 6,953 $ | $ 14,029 | $ 19,832 |\n| Delivery revenue (1) | 8,362 | 10,901 | 12,204 |\n| Freight revenue | 2,132 | 6,947 | 5,245 |\n| All Other revenue | 8 |  |  |\n| Total revenue | 17,455 $ | $ 31,877 | $ 37,281 |\n\n_END_OF_TABLE_\n(1) We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass (\"Subscription\"). We recognize Subscription fees ratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering during the respective period.\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|-|\n|  |  | Year Ended December 31, |  |  |  |\n|  | 2021 | 2022 |  |  | 2023 |\n| United States and Canada (\"US&CAN\") Latin America (\"LatAm\") | $ 10,094 1,417 | $ | 19,474 1,978 | $ | 20,436 2,512 |\n| Europe, Middle East and Africa (\"EMEA\") Asia Pacific (\"APAC\") | 3,213 2,731 |  | 6,944 3,481 |  | 9,904 4,429 |\n| Total revenue | $ 17,455 | $ | 31,877 | $ | 37,281 |\n\n_END_OF_TABLE_\n\n\n# Revenue\n\nMobility Revenue We derive revenue from fees paid by Mobility Drivers for the use of our platform(s) and related services to facilitate and complete Mobility services and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Mobility revenue also includes immaterial revenue streams such as our financial partnerships products. Additionally, in certain markets where we are responsible for Mobility services, fees charged to end-users are also included in revenue, while payments to Drivers in exchange for Mobility services are recognized in cost of revenue, exclusive of depreciation and amortization.\n\n# Delivery Revenue\n\nWe derive revenue for Delivery from Merchants' and Couriers' use of the Delivery platform and related service to facilitate and complete Delivery transactions and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Additionally, in certain markets where we are responsible for Delivery services, delivery fees charged to end-users are also included in revenue, while payments to Couriers in exchange for Delivery services are recognized in cost of revenue, exclusive of depreciation and amortization. Delivery also includes advertising revenue from sponsored listing fees paid by Merchants and brands in exchange for advertising services.",
#                 "documentMetadata": {
#                     "uri": "gs://10k-docs/uber.pdf",
#                     "title": "uber",
#                     "structData": {
#                         "year": "2023",
#                         "type": "10-K",
#                         "company": "Uber",
#                         "url": "https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf"
#                     }
#                 },
#                 "pageSpan": {
#                     "pageStart": 96,
#                     "pageEnd": 96
#                 },
#                 "relevanceScore": 0.799920916557312
#             }
#         },
#         {
#             "chunk": {
#                 "name": "projects/351215155115/locations/us/collections/default_collection/dataStores/10k-docs_1735917605966/branches/0/documents/2/chunks/c175",
#                 "id": "c175",
#                 "content": "# (In millions, except share amounts which are reflected in thousands, and per share amounts)\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2021 | 2022 | 2023 |\n| Revenue | 17,455 $ | 31,877 $ | $ 37,281 |\n| Costs and expenses |  |  |  |\n| Cost of revenue, exclusive of depreciation and amortization shown separately below | 9,351 | 19,659 | 22,457 |\n| Operations and support | 1,877 | 2,413 | 2,689 |\n| Sales and marketing | 4,789 | 4,756 | 4,356 |\n| Research and development | 2,054 | 2,798 | 3,164 |\n| General and administrative | 2,316 | 3,136 | 2,682 |\n| Depreciation and amortization | 902 | 947 | 823 |\n| Total costs and expenses | 21,289 | 33,709 | 36,171 |\n| Income (loss) from operations | (3,834) | (1,832) | 1,110 |\n| Interest expense | (483) | (565) | (633) |\n| ), net Other income (expense | 3,292 | (7,029) | 1,844 |\n| Income (loss) before income taxes and income from equity method investments | (1,025) | (9,426) | 2,321 |\n| Provision for (benefit from) income taxes | (492) | (181) | 213 |\n| Income (loss) from equity method investments | (37) | 107 | 48 |\n| Net income (loss) including non-controlling interests | (570) | (9,138) | 2,156 |\n| Less: net income (loss) attributable to non-controlling interests, net of tax | (74) | 3 | 269 |\n| Net income (loss) attributable to Uber Technologies, Inc. | (496) $ | (9,141) $ | $ 1,887 |\n| Net income (loss) per share attributable to Uber Technologies, Inc. common stockholders: |  |  |  |\n| Basic | (0.26) $ | (4.64) $ | $ 0.93 |\n| Diluted | (0.29) $ | $ (4.65) | $ 0.87 |\n| Weighted-average shares used to compute net income (loss) per share attributable to common stockholders: |  |  |  |\n| Basic | 1,892,546 | 1,972,131 | 2,035,651 |\n| Diluted | 1,895,519 | 1,974,928 | 2,091,782 |\n\n_END_OF_TABLE_\nThe accompanying notes are an integral part of these consolidated financial statements. 75",
#                 "documentMetadata": {
#                     "uri": "gs://10k-docs/uber.pdf",
#                     "title": "uber",
#                     "structData": {
#                         "type": "10-K",
#                         "company": "Uber",
#                         "url": "https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf",
#                         "year": "2023"
#                     }
#                 },
#                 "pageSpan": {
#                     "pageStart": 77,
#                     "pageEnd": 78
#                 },
#                 "relevanceScore": 0.7639488577842712
#             }
#         },
#         {
#             "chunk": {
#                 "name": "projects/351215155115/locations/us/collections/default_collection/dataStores/10k-docs_1735917605966/branches/0/documents/2/chunks/c133",
#                 "id": "c133",
#                 "content": "# Driver Classification Developments\n\nIn addition, if we are required to classify Drivers as employees, this may impact our current financial statement presentation including revenue, cost of revenue, incentives and promotions as further described in Note 1 - Description of Business and Summary of Significant Accounting Policies in the notes to the consolidated financial statements included in Part II, Item 8, \"Financial Statements and Supplementary Data,\" and the section titled \"Critical Accounting Estimates\" in Part II, Item 7, of this Annual Report on Form 10-K. 49\n\n# Financial and Operational Highlights\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|\n|  |  |  | Year Ended December 31, |  |\n| (In millions, except percentages) | 2022 | 2023 | % Change | % Change (Constant Currency (1) |\n| Monthly Active Platform Consumers (\u201cMAPCs\u201d) (2), (3) | 131 | 150 | 15% |  |\n| Trips (2) | 7,642 | 9,448 | 24% |  |\n| Gross Bookings (2) | 115,395 $ $ 137,865 |  | 19% | 20% |\n| Revenue | 31,877 $ | $ 37,281 | 17% | 18% |\n| Income (loss) from operations | (1,832) $ | $ 1,110 | ** |  |\n| Net income (loss) attributable to Uber Technologies, Inc. Adjusted EBITDA (1), (2) | (9,141) $ 1,713 $ | $ 1,887 $ 4,052 | ** 137% |  |\n| Net cash provided by operating activities (4) Free cash flow (1), (4) | 642 $ 390 $ | $ 3,585 $ 3,362 | ** ** |  |\n\n_END_OF_TABLE_\n(1) See the section titled \"Reconciliations of Non-GAAP Financial Measures\" for more information and reconciliations to the most directly comparable GAAP financial measure. (2) See the section titled \"Certain Key Metrics and Non-GAAP Financial Measures\" below for more information. (3) MAPCs presented for annual periods are MAPCs for the fourth quarter of the year. (4) Net cash provided by operating activities and free cash flow during the year ended December 31, 2022 reflected an approximately $733 million (\u00a3613 million) cash outflow related to the resolution of all outstanding HMRC VAT claims that were paid during the fourth quarter of 2022. Net cash provided by operating activities and free cash flow during the year ended December 31, 2023 reflected an approximately $789 million (\u00a3631 million) cash outflow related to payments of HMRC VAT assessments for the period of March 2022 to June 2023. For additional information on these matters, refer to Note 14 \u2013 Commitments and Contingencies to our consolidated financial statements included in Part II, Item 8, \"Financial Statements and Supplementary Data,\" of this Annual Report on Form 10-K as well as the section titled \"Liquidity and Capital Resources\". ** Percentage not meaningful.",
#                 "documentMetadata": {
#                     "uri": "gs://10k-docs/uber.pdf",
#                     "title": "uber",
#                     "structData": {
#                         "company": "Uber",
#                         "year": "2023",
#                         "type": "10-K",
#                         "url": "https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf"
#                     }
#                 },
#                 "pageSpan": {
#                     "pageStart": 51,
#                     "pageEnd": 52
#                 },
#                 "relevanceScore": 0.7951330542564392
#             }
#         }
#     ],
#     "totalSize": 249,
#     "attributionToken": "zgHwzQoMCKep5bsGEJWS8qYBEiQ2NzZlZjIyMS0wMDAwLTJkNTItOGJhNi01ODI0MjlhNzk5NjQiB0dFTkVSSUMqjAHm3cQwrfizLY2ktDDJndswxMaxMLa3jC359rMt6d3EMNuPmiKgibMtxcvzF67Eii2OkckwzJ3bMMT4vDCQ97Iw1LKdFc7mtS_E_MswmNa3Lfz2sy2jgJcix8axMNHmtS_C8J4VkKS0MJvWty3B_MswqvizLY6-nRXej5oilZLFMKOJsy2rxIotwfi8MDAB",
#     "nextPageToken": "AN2kTO3EWOyQjM4UTL2EmY40iM1QmMtADMwATLwIjMmVmN3YDJaEg7zn4uQYwu1L5pIwgEzEgC",
#     "guidedSearchResult": {},
#     "summary": {},
#     "queryExpansionInfo": {}
# }

# %% [markdown]
# # Test 2 - Gemini and Vertex AI

# %%
# Build RAG chain using Vertex AI Agent Builder datastore

retreiver = create_retriever_vertexai()
chat_prompt_template = create_chat_prompt_template()
chain = create_chain(model_name='gemini-1.5-flash', 
                     prompt_template=chat_prompt_template, 
                     retriever=retreiver)

# %%
# Test the chain with a few questions 

questions = ["What is the annual revenue of Uber?",
"What is the annual revenue of Lyft?",
"How does Uber's revenue compare to Lyft's revenue?",]

for question in questions:
	print(question)
	result = chain.invoke({"question" : question})
	print(result)
	print(result["response"].content)
	print("\n*****")
# Out:
# What is the annual revenue of Uber?
# {'response': AIMessage(content='Uber\'s total revenue for 2023 was $37,281 million.  This is according to the "Note 2 - Revenue" section of their 2023 10-K report.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-ac0f1f5c-aab9-402c-af35-e33268ed6575-0', usage_metadata={'input_tokens': 2479, 'output_tokens': 50, 'total_tokens': 2529, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'year': '2023', 'type': '10-K', 'company': 'Uber', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.799920916557312}, page_content='# Note 2 - Revenue\n\nThe following tables present our revenues disaggregated by offering and geographical region. Revenue by geographical region is based on where the transaction occurred. This level of disaggregation takes into consideration how the nature, amount, timing, and uncertainty of revenue and cash flows are affected by economic factors (in millions):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2021 | 2022 | 2023 |\n| Mobility revenue (1) | 6,953 $ | $ 14,029 | $ 19,832 |\n| Delivery revenue (1) | 8,362 | 10,901 | 12,204 |\n| Freight revenue | 2,132 | 6,947 | 5,245 |\n| All Other revenue | 8 |  |  |\n| Total revenue | 17,455 $ | $ 31,877 | $ 37,281 |\n\n_END_OF_TABLE_\n(1) We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass ("Subscription"). We recognize Subscription fees ratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering during the respective period.\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|-|\n|  |  | Year Ended December 31, |  |  |  |\n|  | 2021 | 2022 |  |  | 2023 |\n| United States and Canada ("US&CAN") Latin America ("LatAm") | $ 10,094 1,417 | $ | 19,474 1,978 | $ | 20,436 2,512 |\n| Europe, Middle East and Africa ("EMEA") Asia Pacific ("APAC") | 3,213 2,731 |  | 6,944 3,481 |  | 9,904 4,429 |\n| Total revenue | $ 17,455 | $ | 31,877 | $ | 37,281 |\n\n_END_OF_TABLE_\n\n\n# Revenue\n\nMobility Revenue We derive revenue from fees paid by Mobility Drivers for the use of our platform(s) and related services to facilitate and complete Mobility services and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Mobility revenue also includes immaterial revenue streams such as our financial partnerships products. Additionally, in certain markets where we are responsible for Mobility services, fees charged to end-users are also included in revenue, while payments to Drivers in exchange for Mobility services are recognized in cost of revenue, exclusive of depreciation and amortization.\n\n# Delivery Revenue\n\nWe derive revenue for Delivery from Merchants\' and Couriers\' use of the Delivery platform and related service to facilitate and complete Delivery transactions and, in certain markets, revenue from fees paid by end-users for connection services obtained via the platform. Additionally, in certain markets where we are responsible for Delivery services, delivery fees charged to end-users are also included in revenue, while payments to Couriers in exchange for Delivery services are recognized in cost of revenue, exclusive of depreciation and amortization. Delivery also includes advertising revenue from sponsored listing fees paid by Merchants and brands in exchange for advertising services.'), Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'year': '2023', 'type': '10-K', 'company': 'lyft', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments':  ...
# Uber's total revenue for 2023 was $37,281 million.  This is according to the "Note 2 - Revenue" section of their 2023 10-K report.
#
#
# *****
# What is the annual revenue of Lyft?
# {'response': AIMessage(content='Lyft\'s total revenue for 2023 was $4,403,589,000.  This is according to the "Lyft, Inc. Notes to Consolidated Financial Statements" section of their 2023 10-K report.  The report breaks this down into $4,116,216,000 from contracts with customers and $287,373,000 in rental revenue.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-c537ac8d-45f0-4759-aa98-db30854f2c64-0', usage_metadata={'input_tokens': 2139, 'output_tokens': 104, 'total_tokens': 2243, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'year': '2023', 'type': '10-K', 'company': 'lyft', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.790586531162262}, page_content='# Lyft, Inc. Notes to Consolidated Financial Statements\n\n## Revenue Recognition\n\nThe Company generates its revenue from its multimodal transportation networks that offer access to a variety of transportation options through the Lyft Platform and mobile-based applications. Substantially all, or approximately 85% or more, of the Company\'s revenue is generated from its ridesharing marketplace that connects drivers and riders and is recognized in accordance 83 with Accounting Standards Codification Topic 606 (“ASC 606"). In addition, the Company generates revenue in accordance with ASC 606 from licensing and data access, subscription fees, revenue from bikes and bike station hardware and software sales and revenue from arrangements to provide advertising services to third parties, which are not significant components of the Company\'s consolidated revenues. The Company also generates rental revenue from Flexdrive and its network of Light Vehicles, which is recognized in accordance with Accounting Standards Codification Topic 842 ("ASC 842"). The table below presents the Company\'s revenues as included on the consolidated statements of operations (in thousands):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2023 | 2022 | 2021 |\n| Revenue from contracts with customers (ASC 606) | 4,116,216 $ | $ 3,811,993 $ | 2,957,979 |\n| Rental revenue (ASC 842) | 287,373 | 283,142 | 250,344 |\n| Total revenue | 4,403,589 $ | $ 4,095,135 $ | 3,208,323 |\n\n_END_OF_TABLE_\n'), Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7285593748092651}, page_content='# Note 2 - Revenue\n\nThe following tables present our revenues disaggregated by offering and geographical region. Revenue by geographical region is based on where the transaction occurred. This level of disaggregation takes into consideration how the nature, amount, timing, and uncertainty of revenue and cash flows are affected by economic factors (in millions):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2021 | 2022 | 2023 |\n| Mobility revenue (1) | 6,953 $ | $ 14,029 | $ 19,832 |\n| Delivery revenue (1) | 8,362 | 10,901 | 12,204 |\n| Freight revenue | 2,132 | 6,947 | 5,245 |\n| All Other revenue | 8 |  |  |\n| Total revenue | 17,455 $ | $ 31,877 | $ 37,281 |\n\n_END_OF_TABLE_\n(1) We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass ("Subscription"). We recognize Subscription fees ratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering during the respective period.\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|-|\n|  |  | Year Ended  ...
# Lyft's total revenue for 2023 was $4,403,589,000.  This is according to the "Lyft, Inc. Notes to Consolidated Financial Statements" section of their 2023 10-K report.  The report breaks this down into $4,116,216,000 from contracts with customers and $287,373,000 in rental revenue.
#
#
# *****
# How does Uber's revenue compare to Lyft's revenue?
# {'response': AIMessage(content="Uber's 2023 revenue was $37,281 million, significantly higher than Lyft's 2023 revenue of $4,403,589 thousand ($4,403.6 million).  This represents a substantial difference in scale between the two companies.  Note that the provided data uses different units (millions for Uber, thousands for Lyft).\n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-bdb4b011-cba2-4e4a-94f7-5e12fa02916c-0', usage_metadata={'input_tokens': 2145, 'output_tokens': 85, 'total_tokens': 2230, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7183594703674316}, page_content='# Lyft, Inc. Notes to Consolidated Financial Statements\n\n## Revenue Recognition\n\nThe Company generates its revenue from its multimodal transportation networks that offer access to a variety of transportation options through the Lyft Platform and mobile-based applications. Substantially all, or approximately 85% or more, of the Company\'s revenue is generated from its ridesharing marketplace that connects drivers and riders and is recognized in accordance 83 with Accounting Standards Codification Topic 606 (“ASC 606"). In addition, the Company generates revenue in accordance with ASC 606 from licensing and data access, subscription fees, revenue from bikes and bike station hardware and software sales and revenue from arrangements to provide advertising services to third parties, which are not significant components of the Company\'s consolidated revenues. The Company also generates rental revenue from Flexdrive and its network of Light Vehicles, which is recognized in accordance with Accounting Standards Codification Topic 842 ("ASC 842"). The table below presents the Company\'s revenues as included on the consolidated statements of operations (in thousands):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2023 | 2022 | 2021 |\n| Revenue from contracts with customers (ASC 606) | 4,116,216 $ | $ 3,811,993 $ | 2,957,979 |\n| Rental revenue (ASC 842) | 287,373 | 283,142 | 250,344 |\n| Total revenue | 4,403,589 $ | $ 4,095,135 $ | 3,208,323 |\n\n_END_OF_TABLE_\n'), Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'year': '2023', 'type': '10-K', 'company': 'Uber', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7054497003555298}, page_content='# Note 2 - Revenue\n\nThe following tables present our revenues disaggregated by offering and geographical region. Revenue by geographical region is based on where the transaction occurred. This level of disaggregation takes into consideration how the nature, amount, timing, and uncertainty of revenue and cash flows are affected by economic factors (in millions):\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|\n|  |  | Year Ended December 31, |  |\n|  | 2021 | 2022 | 2023 |\n| Mobility revenue (1) | 6,953 $ | $ 14,029 | $ 19,832 |\n| Delivery revenue (1) | 8,362 | 10,901 | 12,204 |\n| Freight revenue | 2,132 | 6,947 | 5,245 |\n| All Other revenue | 8 |  |  |\n| Total revenue | 17,455 $ | $ 31,877 | $ 37,281 |\n\n_END_OF_TABLE_\n(1) We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass ("Subscription"). We recognize Subscription fees ratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering during the respective period.\n\n_START_OF_TABLE_\nTABLE_IN_MARKDOWN:\n|-|-|-|-|-|-|\n|   ...
# Uber's 2023 revenue was $37,281 million, significantly higher than Lyft's 2023 revenue of $4,403,589 thousand ($4,403.6 million).  This represents a substantial difference in scale between the two companies.  Note that the provided data uses different units (millions for Uber, thousands for Lyft).
#
#
# *****

# %%
# Evaluate the chain using Ragas

import time

import pandas as pd

# Run the Ragas evaluation and show the results
# Get the questions and groundtruths from the dataframe
testset_df = pd.read_csv("testsets/10k_testset.csv")

questions = testset_df["question"].values.tolist()
questions = [str(question) for question in questions]

groundtruths = testset_df["ground_truth"].values.tolist()
groundtruths = [str(ground_truth) for ground_truth in groundtruths]  

# Specify the eval metrics
eval_metrics = [answer_correctness, answer_relevancy, context_precision, context_recall, faithfulness]

# Run the Ragas evaluation and show the results
ragas_results, ragas_results_df = run_ragas_evaluation(chain, questions, groundtruths, eval_metrics)

# Write the results to disk
timestr = time.strftime("%Y%m%d%H%M%S")
ragas_results_df.to_csv(f"evaluations/10x_test2_testset_evaluation_{timestr}.csv")

# Show the resutls
print(ragas_results)
# Out:
# What challenges do jurisdictions pose to business operations in the context of regulatory compliance?
# {'response': AIMessage(content="Based on the provided Uber 10-K report excerpt, jurisdictions pose several challenges to business operations regarding regulatory compliance:\n\n1. **Conflicting and Differing Regulations:** Uber operates in numerous jurisdictions with varying and sometimes conflicting laws and regulations related to its business model (mobility, delivery, freight).  This fragmented regulatory environment creates significant complexities for its operations.\n\n2. **Uncertainty and Evolving Regulations:**  Laws and regulations are constantly evolving, and their interpretation and application can be unpredictable. This uncertainty poses a risk to Uber's business, as new laws or interpretations could negatively impact its operations.\n\n3. **Restrictions on Ridesharing:** Some jurisdictions, including Argentina, Germany, Italy, Japan, South Korea, and Spain, have either banned certain ridesharing products or imposed significant operational restrictions. This limits Uber's expansion and market reach.\n\n4. **Extensive TNC Regulations:**  Substantially all US states and numerous municipalities worldwide have adopted Transportation Network Company (TNC) regulations. These regulations often impose requirements on background checks, vehicle inspections, insurance, driver training, and other aspects of Uber's operations, adding complexity and cost.\n\n5. **Lack of Regulation in Some Jurisdictions:**  The excerpt notes that some jurisdictions have not adopted any laws governing Uber's mobility business, creating a patchwork of regulatory environments that Uber must navigate.\n\nThe Lyft 10-K excerpt does not directly address jurisdictional challenges to regulatory compliance in the same detail as the Uber excerpt.  However, it highlights the risk that regulatory bodies may enact new laws or regulations adverse to acquired companies or that new regulatory burdens could negatively impact Lyft's business in unforeseen ways.  This indirectly supports the challenges described in the Uber 10-K.\n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-0c1ba896-777a-4207-adb7-51f9d02532a4-0', usage_metadata={'input_tokens': 2000, 'output_tokens': 357, 'total_tokens': 2357, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.6214617490768433}, page_content='# PART I\n\n## Government Regulation\n\nWe operate in a particularly complex legal and regulatory environment. Our business is subject to a variety of U.S. federal, state, local and foreign laws, rules, and regulations, including those related to Internet activities, privacy, cybersecurity, data protection, intellectual property, competition, consumer protection, payments, labor and employment, transportation services, transportation network companies, licensing regulations and taxation. These laws and regulations are constantly evolving and may be interpreted, applied, created, or amended, in a manner that could harm our business. Examples of certain laws and regulations we are subject to are described below. For further discussion of risks relating to government regulation, see our risk factors, including the risk factors in the section titled "Legal and Regulatory Risks Related to Our Business" in Part I, Item 1A of this Annual Report on Form 10-K. Our platform, and in particular our Mobility products, are subject to differing, and sometimes conflicting, laws, rules, and regulations in the numerous jurisdictions in which we operate. A large number of proposals are before various national, regional, and local legislative bodies and regulatory entities, both within the United States and ...
# What challenges does competition in technology pose for maintaining interoperability of platforms?
# {'response': AIMessage(content='Both Lyft (2023 10-K) and Uber (2023 10-K) highlight challenges to platform interoperability stemming from competition in the technology sector.  The core issue is dependence on third-party applications, services, and operating systems (like iOS and Android) that are outside their direct control.\n\n**Lyft\'s 10-K** notes that competitors or technology partners could take actions that disrupt interoperability,  potentially degrading platform functionality or performance.  This could be achieved through changes to their products, standards, or terms of use that favor their own offerings.  Furthermore, Lyft\'s reliance on "continuous deployment" increases the risk of undetected errors or vulnerabilities in their software, impacting interoperability and potentially leading to security breaches.\n\n**Uber\'s 10-K** emphasizes similar concerns.  Their reliance on open marketplaces (like the Apple App Store and Google Play) for distribution and on third-party software (such as Google Maps) creates vulnerabilities.  Changes in these marketplaces\' structures, pricing, or the availability of essential third-party software could severely impact Uber\'s platform functionality and distribution.  The example of Apple\'s user tracking permission requirements illustrates how third-party policies can directly affect Uber\'s advertising capabilities and user acquisition costs.  In essence, both companies face risks from the evolving landscape of third-party technologies and the competitive actions of other players in the ecosystem.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-2d413dc2-70d1-421b-925e-11aff9673692-0', usage_metadata={'input_tokens': 1974, 'output_tokens': 298, 'total_tokens': 2272, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'year': '2023', 'type': '10-K', 'company': 'lyft', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.5300078392028809}, page_content='# We depend on the interoperability of our platform across third-party applications and services that we do not control.\n\nWe have integrations with a variety of productivity, collaboration, travel, data management and security vendors. As our offerings expand and evolve, including to the extent we continue to develop autonomous technology, we may have an increasing number of integrations with other third-party applications, products and services. Third-party applications, products and services are constantly evolving, and we may not be able to maintain or modify our platform to ensure its compatibility with third-party offerings following development changes. In addition, some of our competitors or technology partners may take actions which disrupt the interoperability of our platform with their own products or services, or exert strong business influence on our ability to, and the terms on which we operate and distribute our platform. As our respective products evolve, we expect the types and levels of competition to 35 increase. Should any of our competitors or technology partners modify their products, standards or terms of use in a manner that degrades the functionality or performance of our platform or is otherwise unsatisfactory to us or gives preferential treatment to competitive products or services, our products, platform, business, financial condition and results of operations could be adversely affected. Defects, errors or vulnerabilities in our applications, backend systems or other technology systems and those of third-party technology providers, or system failures and resulting interruptions in our availability or the availability of other systems and providers, could harm our reputation and brand and adversely impact ...
# What factors could adversely impact the financial results of the company?
# {'response': AIMessage(content='Based on the provided 10-K excerpts, several factors could adversely impact Lyft\'s and Uber\'s financial results.  The documents highlight the following:\n\n**Lyft:**\n\n* **General macroeconomic conditions:**  Broad economic downturns could negatively affect ridership and revenue.\n* **Impact of pandemics and responsive measures:**  Events like the COVID-19 pandemic and related government responses (e.g., lockdowns) significantly impact ridership and the company\'s ability to operate.\n* **Natural disasters, economic downturns, public health crises, or political crises:** These events can all disrupt operations and reduce demand for ride-sharing services.\n\n\n**Uber:**\n\n* **Catastrophic events:**  Disease outbreaks, weather events, war, or terrorist attacks could severely disrupt operations and negatively impact financial performance.  The impact on business partners and third-party vendors is also a concern, as their difficulties could cascade to Uber.\n* **Future pandemics or outbreaks:** Similar to Lyft, future pandemics pose a significant risk to Uber\'s business.\n* **Geopolitical instability:** The Russia-Ukraine conflict and related global instability, including sanctions and embargoes, create uncertainty and could negatively affect Uber\'s operations and financial performance.\n* **Financial institution failures:**  The failure of a bank or other financial institution where Uber holds funds could impact its liquidity and financial performance.  This risk is heightened during times of broader economic instability.\n\n\nBoth companies\' financial results are vulnerable to unforeseen events and broader economic factors beyond their direct control.  The provided excerpts do not offer a complete picture of all potential risks, as they only represent sections of the full 10-K reports.  A more comprehensive risk assessment would require reviewing the complete "Risk Factors" sections of both companies\' 10-K filings.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-67c9bb4a-6fb6-4e7c-a4d1-97981dc58b84-0', usage_metadata={'input_tokens': 1949, 'output_tokens': 374, 'total_tokens': 2323, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'year': '2023', 'type': '10-K', 'company': 'lyft', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7243099212646484}, page_content='# Available Information\n\nOur website is located at www.lyft.com, and our investor relations website is located at investor.lyft.com. Copies of our Annual Report on Form 10-K, Quarterly Reports on Form 10-Q, Current Reports on Form 8-K and amendments to these reports filed or furnished pursuant to Section 13(a) or 15(d) of the Securities Exchange Act of 1934, as amended, are available free of charge on our investor relations website as soon as reasonably practicable after we file such material electronically with or furnish it to the Securities and Exchange Commission (the “SEC"). The SEC also maintains a website that contains our SEC filings at www.sec.gov. We announce material information to the public about us, our products and services and other matters through a variety of means, including filings with the SEC, press releases, public conference calls, webcasts, the investor relations section of our website (investor.lyft.com), our X accounts (@lyft and @davidrisher) and our blogs (including: lyft.com/blog, lyft.com/hub and eng.lyft.com) in order to achieve broad, non-exclusionary distribution of information to the public and for complying with our disclosure obligations under Regulation FD. The contents of our websites and corporate reports mentioned herein are not incorporated by reference into this Annual Report on Form ...
# What role did the Deputy Chief Technology Officer play in the context of cybersecurity at a Fortune 500 company?
# {'response': AIMessage(content='Based on the provided Uber 10-K report (2023), the Deputy Chief Technology Officer at a Fortune 500 company previously held the position of Chief Information Security Officer (CISO) and Deputy Chief Technology Officer.  The report does not detail the specific cybersecurity role or responsibilities this individual held in that previous position, only mentioning their experience in the field.  Therefore, a precise description of their role in cybersecurity at that unnamed Fortune 500 company cannot be provided from this document.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-318b7277-5602-4fd5-bb3e-446c4530a284-0', usage_metadata={'input_tokens': 2068, 'output_tokens': 106, 'total_tokens': 2174, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.5517542362213135}, page_content='# ITEM 1C. CYBERSECURITY\n\nSafeguarding our critical networks and the information that platform users share with us is vital to our business. One key way that Uber addresses this need is through its cybersecurity risk management program ("Cybersecurity Program"). Uber\'s Chief Information Security Officer ("CISO") is responsible for the Cybersecurity Program, which is coordinated and primarily executed by the global organization of engineers focused on risk management using the NIST Framework (Identify, Protect, Detect, Respond, and Recover) and activities such as automation, secure development, and advanced analytics and monitoring. The CISO has served in such role since February 2021 and has more than 20+ years of engineering and/or cybersecurity experience, including previously as CISO and Deputy Chief Technology Officer at a Fortune 500 company. The Cybersecurity Program is also supported by Uber\'s Chief Privacy Officer and Associate General Counsel, Privacy & Cybersecurity ("CPO"), who has served in that role since August 2018. The CPO has three decades of experience as a legal advisor to 45 multinational corporations, including serving as Chief Privacy & Security Counsel for a Fortune 100 technology company prior to her role at Uber. The Cybersecurity Program is supported by other members of Uber\'s senior management team as well, including the Chief Legal Officer, Head of Platform Engineering, and EU Data Protection Officer. Uber\'s Board of Directors oversees the Cybersecurity Program through regular updates. This Cybersecurity Program is a critical component of Uber\'s enterprise risk management program, through which Uber reviews business, cybersecurity, information technology, privacy, legal, and geopolitical risks, among others. The Cybersecurity Program is designed to assess, identify, and manage risks from cybersecurity threats. Key elements of this program include: Oversight and Governance. Uber\'s Board oversees the Cybersecurity Program, and Uber\'s risk profile with respect to cybersecurity matters, through regular reports and reviews. These include presentations by the CISO to the Board and Audit Committee on an alternating quarterly basis, quarterly reports of certain cybersecurity incidents to the Board, and annual reports by the CPO to the Board. The CISO also provides quarterly updates to Uber\'s senior management regarding cybersecurity risks, as well as interim updates during regular meetings with Uber\'s engineering, product and internal audit leadership. The CISO and CPO also jointly chair Uber\'s Privacy and Cybersecurity Council, which provides a venue for cross-functional insight and input into the Cybersecurity Program and our privacy program as they relate to Uber\'s business operations.  ...
# What benefits do members receive from the Uber One membership program?
# {'response': AIMessage(content='Based on the provided Uber 2023 10-K report, Uber One members receive discounts, special pricing, priority service, and exclusive perks across rides, delivery, and grocery offerings.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-de52b847-6f6a-4e22-a6a4-cd65a1c70ede-0', usage_metadata={'input_tokens': 1503, 'output_tokens': 42, 'total_tokens': 1545, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'year': '2023', 'type': '10-K', 'company': 'Uber', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7286988496780396}, page_content='# PART I\n\n## Our Platform\n\nWith our platform, we are making it even easier for our consumers to unlock convenience. In 2020, we rolled out our "Super App" view on iOS and Android, which combines our multiple offerings into a single app and is designed to remove friction for our consumers. During November 2021, we launched Uber One in the United States as our single cross-platform membership program that brings together the best of Uber. Uber One members have access to discounts, special pricing, priority service, and exclusive perks across our rides, delivery and grocery offerings. Since then, we have expanded Uber One to approximately 25 countries. Our Eats Pass membership program continues to remain available in select cities as a subscription offering. Our membership programs are designed to make utilizing our suite of products a seamless and rewarding experience for our consumers. We exited 2023 with 19 million members for our Uber One, Eats Pass and Rides Pass membership programs. We are also utilizing our data and scale to offer marketplace-centric advertising to connect merchants and brands with our platform network and unlocking cross-platform advertising formats. During October 2022, we officially launched Uber\'s advertising division and introduced Uber Journey Ads, an engaging way for brands to connect with consumers throughout the entire ride process. We now offer a model that enables brands to partner with Uber on a variety of advertising options on the Uber and Uber Eats apps, and beyond, while connecting with consumers in brand-safe and captivating ways. We also provide comprehensive reporting and analysis, which helps brands fine-tune their understanding of consumers and create more impactful campaigns as they connect with consumers at relevant points throughout their journeys and transactions. During the fourth quarter of 2023, active advertising merchants exceeded 550,000. We believe that our advertising further strengthens the power of our platform and will continue to do so as we onboard more advertisers.'), Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'year': '2023', 'type': '10-K', 'company': 'lyft', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.6872043609619141}, page_content='# Drivers\n\nExpress Drive. Our car rental program for drivers, including those who want to drive using our platform but do not have access to a vehicle that meets our requirements. Through our Express Drive program, drivers can enter into rental agreements with our independently managed subsidiary, Flexdrive, and our rental car partners for vehicles that may be used to provide ridesharing services on the Lyft Platform. Light Vehicles. We have a network of shared bikes and scooters in a number of cities to address the needs of users who are looking for options that are more active and often more cost-effective and efficient for shorter trips. These transportation modes can also help supplement the first-mile and last- mile o ...
# What challenges do ridesharing companies face in terms of government regulation?
# {'response': AIMessage(content='Ridesharing companies like Lyft and Uber face numerous challenges related to government regulation, as evidenced by their 10-K filings.  These challenges can be categorized as follows:\n\n**1. Contractor Classification:**  Both companies highlight the significant risk associated with the classification of their drivers as independent contractors.  Changes in legislation or differing interpretations of existing laws could reclassify drivers as employees, leading to substantial increases in costs related to payroll taxes, benefits, and potential legal liabilities.  (Lyft 10-K, Risk Factors; Uber 10-K,  "Legal and Regulatory Risks Related to Our Business").\n\n**2. Varying and Conflicting Jurisdictional Regulations:**  The regulatory landscape for ridesharing is fragmented and inconsistent across different jurisdictions (state, provincial, municipal, and international).  This creates complexities in operations and compliance.  Regulations vary widely regarding licensing, insurance, driver screening, minimum earnings, and operational restrictions. Some jurisdictions even have outright bans or significant limitations on ridesharing services. (Lyft 10-K; Uber 10-K,  "Legal and Regulatory Risks Related to Our Business").  Uber specifically mentions several countries (Argentina, Germany, Italy, Japan, South Korea, and Spain) where regulations pose significant challenges.\n\n**3. Evolving Regulations and Increased Scrutiny:**  The regulatory environment is dynamic, with ongoing changes and increased scrutiny of large technology companies and those using independent contractors.  New laws and regulations could be enacted that negatively impact the business model.  This includes potential regulations related to emerging technologies like AI, as noted by Lyft\'s mention of the proposed EU Artificial Intelligence Act. (Lyft 10-K; Uber 10-K).\n\n**4. Costs of Regulatory Compliance and Influence:**  Both companies acknowledge the significant resources invested in complying with existing regulations and attempting to influence or challenge legislation.  These efforts, even if successful, represent substantial costs and carry the risk of unsuccessful outcomes. (Lyft 10-K).\n\n**5.  Transportation Network Company (TNC) Regulations:** Uber specifically points out the widespread adoption of TNC regulations in the US and globally. These regulations often cover various aspects, including background checks, vehicle inspections, insurance, driver training, and consumer safety, adding to the compliance burden. (Uber 10-K).\n\n\nIn summary, the regulatory environment presents a significant and multifaceted challenge for ridesharing companies, impacting their operational costs, legal liabilities, and overall business model.  The uncertainty inherent in this evolving landscape is a key risk factor for both Lyft and Uber.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-379bb34b-a1e3-4e4a-99ae-fbdb443836ab-0', usage_metadata={'input_tokens': 1945, 'output_tokens': 538, 'total_tokens': 2483, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7564777135848999}, page_content='# Our business is subject to a wide range of laws and regulations, many of which are evolving, and failure to comply with such laws and regulations could harm our business, financial condition and results of operations.\n\nRecent financial, political and other events have increased the level of regulatory scrutiny on larger companies, technology companies in general and companies engaged in dealings with independent contractors, such as ridesharing and del ...
# What challenges could an 'investment company' face in operations and financial reporting?
# {'response': AIMessage(content='Based on the provided 10-K excerpts from Uber and Lyft, investment companies face several operational and financial reporting challenges:\n\n**1.  Investment Company Act Compliance:**  Uber\'s 10-K highlights the risk of being classified as an "investment company" under the Investment Company Act. This classification would trigger burdensome compliance requirements, restrictions on business activities (including capital structure and transactions with affiliates), and potentially necessitate asset sales with associated tax implications.  This could significantly impact the company\'s financial condition and operational flexibility.\n\n**2. Complex Accounting and Reporting:** Uber\'s 10-K notes the complexity of accounting for its business model, particularly revenue recognition.  Changes in accounting principles, business models, regulations, or SEC policies could materially alter reported financial results and necessitate changes to financial reporting processes and controls. This introduces uncertainty and potential for errors in financial reporting.\n\n**3. Costs and Demands of Public Company Status:** Lyft\'s 10-K emphasizes the substantial legal, accounting, and other expenses associated with being a public company.  Compliance with the Exchange Act, Sarbanes-Oxley Act, Dodd-Frank Act, SEC regulations, and Nasdaq listing standards increases costs and demands on management\'s time and resources.  The increased visibility also raises the risk of litigation and shareholder activism, further adding to operational and financial burdens.  Furthermore, the limited experience of some management team members in managing a public company adds to the challenges.\n\n**4.  Management Time Allocation:** Both documents indirectly highlight the challenge of balancing compliance demands with the day-to-day management of the business.  The significant time commitment required for regulatory compliance and investor relations could divert management\'s attention from core business operations, potentially impacting performance.\n\n\nIn summary, the primary challenges for an investment company stem from regulatory compliance (Investment Company Act), the complexities of financial reporting in a dynamic business environment, and the increased costs and management demands associated with being a publicly traded company.  These factors can significantly impact both operational efficiency and the accuracy and reliability of financial reporting.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-c2246620-5cd1-464b-8dc6-fffba640cfbe-0', usage_metadata={'input_tokens': 1772, 'output_tokens': 422, 'total_tokens': 2194, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'year': '2023', 'type': '10-K', 'company': 'Uber', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7106468677520752}, page_content='# Our reported financial results may be adversely affected by changes in accounting principles.\n\nThe accounting for our business is complicated, particularly in the area of revenue recognition, and is subject to change based on the evolution of our business model, interpretations of relevant accounting principles, enforcement of existing or new regulations, and changes in SEC or other agency policies, rules, regulations, and interpretations, of accounting regulations. Changes to our business model and accounting methods could result in changes to our financial statements, including changes in revenue and expenses in any period, or in certain categories of revenue and expenses moving to different periods, may result in materially different financial results, and may require that we change how we process, analyze, and report  ...
# What role do unobservable inputs play in fair value assessments vs. observable market inputs?
# {'response': AIMessage(content='Both Uber (2023 10-K) and Lyft (2023 10-K) reports describe a three-level fair value hierarchy in accordance with ASC 820.  The key difference lies in the role of unobservable inputs:\n\n* **Level 1 (Highest Priority):** Both companies prioritize quoted prices in active markets for identical assets or liabilities.\n\n* **Level 2 (Intermediate Priority):**  Both use observable inputs other than Level 1 prices, such as quoted prices for similar assets or liabilities in active markets, or other observable inputs.\n\n* **Level 3 (Lowest Priority):**  Both acknowledge the use of unobservable inputs when there is little or no market data.  However, the reports emphasize that these inputs must be consistent with market participant assumptions where reasonably available.  This suggests that while unobservable inputs are necessary in certain situations, they are used only when observable data is insufficient and must be justified based on market-consistent assumptions.  The use of Level 3 inputs is considered less reliable than Levels 1 and 2.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-cc8e41e5-9527-4e78-b463-5464f9feb3b5-0', usage_metadata={'input_tokens': 2046, 'output_tokens': 227, 'total_tokens': 2273, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'year': '2023', 'type': '10-K', 'company': 'Uber', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.5652345418930054}, page_content='# Fair Value Measurements and Financial Instruments\n\nFair value is defined as the price that would be received to sell an asset or paid to transfer a liability in an orderly transaction between market participants at the measurement date. In accordance with ASC 820, Fair Value Measurement ("ASC 820"), we use the fair value hierarchy, which prioritizes the inputs used to measure fair value. The hierarchy, as defined below, gives the highest priority to unadjusted quoted prices in active markets for identical assets or liabilities and the lowest priority to unobservable inputs. The three levels of the fair value hierarchy are set forth below: Level 1 Observable inputs such as quoted prices in active markets for identical assets or liabilities. Level 2 Observable inputs other than Level 1 prices such as quoted prices for similar assets or liabilities in active markets, quoted prices in markets that are not active or inputs other than the quoted prices that are observable either directly or indirectly for the full term of the assets or liabilities. Level 3 Unobservable inputs in which there is little or no market data and that are significant to the fair value of the assets or liabilities. 86 Our primary financial instruments include receivables, investments in debt and equity securities, accounts payable, accrued liabilities, long-term debt and warrants. The estimated fair value of marketable debt securities, accounts receivable, accounts payable and accrued liabilities approximates their carrying value due to the short-term maturities of these instruments. Refer to Note 3 - Investments and Fair Value Measurement and Note 8 – Long-Term Debt and Revolving Credit Arrangements for further information.\n\n# Variable Interest Entities\n\nWe evaluate our ownership, contractual, and other interests in entities to determine if we have a variable interest in an entity. These evaluations are complex, involve judgment and the use of estimates and assumptions based on available historical and prospective information, among other factors. If we determine that an entity for which we hold a contractual or ownership interest in is a VIE and that we are the primary beneficiary, we consolidate such entity in the consolidated financia ...
# How does ASC 842 affect revenue and cost reporting?
# {'response': AIMessage(content="Based on the provided 10K excerpts, ASC 842's impact on revenue and cost reporting is primarily demonstrated through the leasing of vehicles.\n\n**Lyft:**  ASC 842 dictates how Lyft accounts for its rental revenue from Flexdrive and Light Vehicles.  Revenue recognition depends on the type of arrangement. For single-use Light Vehicle rides, revenue is recognized upon ride completion. For Flexdrive rentals, revenue is recognized evenly over the rental period (typically seven days or less).  Costs, specifically fleet operating costs, include lease payments and other vehicle expenses.  For subleased vehicles, both sublease income and head lease expense are recognized on a gross basis.\n\n**Uber:** The excerpt focuses on Uber's application of ASC 842 to its leases, not directly on revenue.  It mentions that lease and non-lease components are accounted for as a single unit.  Variable lease payments (e.g., utilities, taxes) are recognized in operating expenses when the obligation is incurred.  For operating leases, lease expense is recognized straight-line over the lease term.  For finance leases, expense is recognized as depreciation (straight-line) and interest (effective interest method).  The provided text does not detail how ASC 842 affects Uber's revenue recognition.\n\n**In summary:**  The provided excerpts show that ASC 842 significantly impacts the *timing* of revenue recognition for Lyft's vehicle rentals, depending on the lease terms.  For costs, ASC 842 influences how lease expenses are recognized and categorized (operating vs. finance leases) for both Lyft and Uber, impacting the presentation of expenses on the income statement.  However, a complete picture of ASC 842's effect on revenue reporting requires more information, particularly regarding Uber's revenue streams.  The excerpts primarily illustrate the impact on lease accounting and expense recognition.\n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-d869dca4-bc3b-46b6-9457-653fd7095fd8-0', usage_metadata={'input_tokens': 1832, 'output_tokens': 392, 'total_tokens': 2224, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.6550003886222839}, page_content="# Lyft, Inc. Notes to Consolidated Financial Statements\n\n## Rental Revenue (ASC 842)\n\nThe Company generates rental revenues primarily from Flexdrive and its network of Light Vehicles. Rental revenues are recognized for rental and rental related activities where an identified asset is transferred to the customer and the customer has the ability to control that asset in accordance with ASC 842. The Company operates a fleet of rental vehicles through its independently managed subsidiary, Flexdrive, comprised of both owned vehicles and vehicles leased from third-party leasing companies. The Company either leases or subleases vehicles to drivers, and as a result, the Company considers itself to be the accounting lessor or sublessor, as applicable, in these arrangements in accordance with ASC 842. Fleet operating costs include monthly fixed lease payments and other vehicle operating or ownership costs, as applicable. For vehicles that are subleased, sublease income and head lease expense for these transactions are recognized on a gross basis on the consolidated financial statements. Drivers who rent vehicles are charged rental fees, which the Company collects from the driver by deducting such amounts from the driver's earnings on the Lyft Platform. 84 The Company owns and operates its Light Vehicles in some cities and operates city-owned Light Vehicles in other cities. Though the specif ...
# What IP risks come from joint dev. agreements and their effect on competition?
# {'response': AIMessage(content="Based on the provided 10-K excerpts from Lyft (2023) and Uber (2023), joint development agreements present several intellectual property (IP) risks that can affect competition:\n\n**1. Limited Ability to Protect and Commercialize IP:**  Both Lyft and Uber mention that joint development agreements may lead to joint ownership of IP or licensing arrangements with counterparties. This can restrict a company's ability to independently protect, enforce, or commercialize the resulting IP.  It may require agreement or payment to partners before taking action, potentially hindering their competitive advantage.  The Lyft excerpt specifically highlights that this could affect the value of jointly-owned IP and their ability to compete.\n\n**2. Increased Costs and Resource Allocation:**  Protecting IP rights, especially in the context of joint development agreements, can be costly and time-consuming.  Both companies acknowledge the potential for significant resource expenditure in monitoring and protecting their IP.  This diversion of resources could negatively impact other aspects of their business.\n\n**3. Litigation Risks:**  Both companies note the possibility of costly and time-consuming litigation to protect their IP.  This includes the risk of facing defenses, counterclaims, and countersuits challenging the validity of their IP rights.  The outcome of such litigation is uncertain and could result in the impairment or loss of IP, further impacting their competitive position.\n\n**4. Competitor Actions:**  The agreements may not prevent competitors from independently developing similar or superior technologies.  Furthermore, competitors might attempt to access and exploit data, compromising trade secrets and other IP rights.  This risk is explicitly mentioned by Lyft.\n\n**5. Difficulty in Detecting and Preventing Infringement:**  Both companies acknowledge the challenges in detecting IP theft, particularly given the potential for reverse engineering or unauthorized copying.  Even if infringement is detected, successful enforcement is not guaranteed, and the process can be expensive and distracting.  Uber highlights the risk of operating in countries with inadequate IP protection.\n\nIn summary, joint development agreements introduce complexities in IP ownership and control, potentially increasing costs, diverting resources, and exposing companies to legal challenges.  The resulting limitations on the ability to protect and commercialize IP can significantly impact a company's competitive landscape.  The risk of competitors independently developing similar technologies or exploiting compromised IP further exacerbates these challenges.\n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-a2cf2228-9b31-41bb-a575-fd84c73c1f9f-0', usage_metadata={'input_tokens': 1942, 'output_tokens': 474, 'total_tokens': 2416, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.6602307558059692}, page_content="# Failure to protect or enforce our intellectual property rights could harm our business, financial condition and results of operations.\n\nFurther, these agreements may not prevent our competitors from independently developing technologies that are substantially equivalent or superior to our offerings. Competitors and other third parties may also attempt to access, aggregate, and/or reverse engineer our data which would compromise our trade secrets and other rights. We also enter into strategic partnerships, joint development and other similar agreements with third parties where intellectual property arising from such par ...
# What links driver contracts, revenue recognition, and the Lyft Platform?
# {'response': AIMessage(content="Lyft's revenue is generated primarily from its ridesharing marketplace connecting drivers and riders.  The Lyft Platform facilitates this connection, and driver contracts (Terms of Service or ToS) govern the use of the platform.  Revenue recognition, in accordance with ASC 606 (as detailed in Note 2 of Lyft's 2023 10-K), is based on Lyft's role as an agent connecting drivers and riders.  Lyft does not control the transportation service itself, therefore revenue is recognized on a net basis, reflecting service fees and commissions from drivers, not the gross amount collected from riders.  The entire process—driver contracts, platform usage, and revenue recognition—is intrinsically linked through the Lyft Platform's role in facilitating the transaction between drivers and riders.\n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-d1b86bb4-7a35-43ee-8c82-c25e6a0c6e44-0', usage_metadata={'input_tokens': 1786, 'output_tokens': 165, 'total_tokens': 1951, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7447449564933777}, page_content='# Revenues from Contracts with Customers (ASC 606)\n\nWe generate substantially all our revenue from our ridesharing marketplace that connects drivers and riders. We recognize revenue from fees paid by drivers for use of our Lyft Platform offerings in accordance with ASC 606 as described in Note 2 of the notes to our consolidated financial statements. Drivers enter into terms of service ("ToS") with us in order to use our Lyft Driver App. We provide a service to drivers to complete a successful transportation service for riders. This service includes on-demand lead generation that assists drivers to find, receive and fulfill on-demand requests from riders seeking transportation services and related collection activities using our Lyft Platform. As a result, our single performance obligation in the transaction is to connect drivers with riders to facilitate the completion of a successful transportation service for riders. We evaluate the presentation of revenue on a gross versus net basis based on whether we act as a principal by controlling the transportation service provided to the rider or whether we act as an agent by arranging for third parties to provide the service to the rider. We facilitate the provision of a transportation service by a driver to a rider (the driver\'s customer) in order for the driver to fulfill their contractual promise to the rider. The driver fulfills their promise to provide a transportation service to their customer through use of the Lyft Platform. While we facilitate setting the price for transportation services, the drivers and riders have the discretion in accepting the transaction price through the platform. We do not control the transportation services being provided to the rider nor do we have inventory risk related to the transportation services. As a result, we act as an agent in facilitating the ability for a driver to provide a transportation service to a rider. We report revenue on a net basis, reflecting the service fees and commissions owed to us from the drivers as revenue, and not the gross amount collected from the rider. We made this determination of not being primarily responsible for the services since we do not promise the transportation services, do not contract with drivers to provide transportation services on our behalf, do not control whether the driver accepts or declines the transportation request via the Lyft Platform, and do not control the provision of transportation services by drivers to riders at any point i ...
# What regulatory challenges could come with global product launches?
# ...
# What reputational risks come from arbitration clauses under legal review?
# {'response': AIMessage(content='Both Uber (2023 10-K) and Lyft (2023 10-K)  report that the use of arbitration provisions in their terms of service, while intended to streamline litigation, presents reputational risks due to increasing public scrutiny.  The documents highlight that these provisions have become a subject of increasing public concern.  Further, the potential for conflicting legal interpretations across states and between state and federal law creates a risk that these arbitration agreements could be challenged, deemed unenforceable, or require revisions.  This could lead to increased litigation costs and exposure to potentially costly lawsuits, negatively impacting their reputation and brand.\n', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-75cf0dca-939a-4b20-a331-dcc0bc4c86c0-0', usage_metadata={'input_tokens': 1948, 'output_tokens': 132, 'total_tokens': 2080, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.7093332409858704}, page_content="# Adverse litigation judgments or settlements resulting from legal proceedings in which we may be involved could expose us to monetary damages or limit our ability to operate our business.\n\nWe have in the past been, are currently, and may in the future become, involved in private actions, collective actions, investigations, and various other legal proceedings by Drivers, consumers, merchants, Shippers, Carriers, employees, commercial partners, competitors or, government agencies, among others. We are subject to litigation relating to various matters including Driver classification, Drivers' tips and taxes, the Americans with Disabilities Act, antitrust, intellectual property infringement, privacy, unfair competition, workplace culture, safety practices, and employment and human resources practices. The results of any such litigation, investigations, and legal proceedings are inherently unpredictable and expensive. Any claims against us, whether meritorious or not, could be time consuming, costly, and harmful to our reputation, and could require significant amounts of management time and corporate resources. If any of these legal proceedings were to be determined adversely to us, or we were to enter into a settlement arrangement, we could be exposed to monetary damages or be forced to change the way in which we operate our business, which could have an adverse effect on our business, financial condition, and operating results. In addition, we regularly include arbitration provisions in our terms of service with end-users. These provisions are intended to streamline the litigation process for all parties involved, as arbitration can in some cases be faster and less costly than litigating disputes in state or federal court. However, arbitration may become more costly for us, or the volume of arbitrations may increase and become burdensome. Further, the use of arbitration provisions may subject us to certain risks to our reputation and brand, as these provisions have been the subject of increasing public scrutiny. To minimize these risks, we have in the past and may in the future 39 voluntarily limit our use of arbitration provisions, or we may be required to do so, in any legal or regulatory proceeding, either of which could increase our litigation costs and exposure in respect of such proceedings. For example, effective May 15, 2018, we ended mandatory arbitration of sexual misconduct claims by platform users and employees. Further, with the potential for conflicting rules regarding the scope and enforceability of arbitration on a state-by-state basis, as well as conflictin ...
# What perks do Uber One members get for rides and delivery?
# {'response': AIMessage(content="Based on the provided 10-K reports, only Uber's report mentions details about Uber One membership perks.  Lyft's report focuses on rider benefits but doesn't detail a specific membership program like Uber One.\n\nUber One members receive discounts, special pricing, priority service, and exclusive perks across rides, delivery, and grocery offerings.  The exact nature of these discounts and perks is not specified in the provided text.\n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-ff3975de-97be-4fe4-9345-a97efd2cd550-0', usage_metadata={'input_tokens': 1826, 'output_tokens': 90, 'total_tokens': 1916, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.6629749536514282}, page_content='# PART I\n\n## Our Platform\n\nWith our platform, we are making it even easier for our consumers to unlock convenience. In 2020, we rolled out our "Super App" view on iOS and Android, which combines our multiple offerings into a single app and is designed to remove friction for our consumers. During November 2021, we launched Uber One in the United States as our single cross-platform membership program that brings together the best of Uber. Uber One members have access to discounts, special pricing, priority service, and exclusive perks across our rides, delivery and grocery offerings. Since then, we have expanded Uber One to approximately 25 countries. Our Eats Pass membership program continues to remain available in select cities as a subscription offering. Our membership programs are designed to make utilizing our suite of products a seamless and rewarding experience for our consumers. We exited 2023 with 19 million members for our Uber One, Eats Pass and Rides Pass membership programs. We are also utilizing our data and scale to offer marketplace-centric advertising to connect merchants and brands with our platform network and unlocking cross-platform advertising formats. During October 2022, we officially launched Uber\'s advertising division and introduced Uber Journey Ads, an engaging way for brands to connect with consumers throughout the entire ride process. We now offer a model that enables brands to partner with Uber on a variety of advertising options on the Uber and Uber Eats apps, and beyond, while connecting with consumers in brand-safe and captivating ways. We also provide comprehensive reporting and analysis, which helps brands fine-tune their understanding of consumers and create more impactful campaigns as they connect with consumers at relevant points throughout their journeys and transactions. During the fourth quarter of 2023, active advertising merchants exceeded 550,000. We believe that our advertising further strengthens the power of our platform and will continue to do so as we onboard more advertisers.'), Document(metadata={'id': '1', 'source': 'gs://10k-docs/lyft.pdf', 'company': 'lyft', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001759509/d576a7f4-780c-4f39-86a6-aa54b03fa2ec.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.6476331949234009}, page_content='# Riders\n\nFlexibility. We offer drivers the flexibility to generate income on their own schedule, so they can best prioritize what is important in their lives. Technology. Our predictive technology around ride volume and demand enables us to share key information with drivers about when and where to drive to maximize their earnings on a real-time basis. Transparent and Consistent Pay: We\'ve released multiple products over the years such as upfront pay where drivers can see ...
# What exec mgmt & restructuring costs add to G&A?
# {'response': AIMessage(content="The provided text from Uber's 2023 10-K states that impairment of other long-lived assets are recorded within general and administrative (G&A) expenses.  However, it doesn't specify the amount of executive management and restructuring costs that are included within that G&A figure.  The document only explains *how* restructuring costs are allocated to different expense categories, not the specific dollar amounts.\n\nLyft's 2023 10-K mentions restructuring charges, but it also doesn't provide a breakdown of how much of those charges relate to executive management specifically.  It does state that $50.9 million in severance and other employee costs, and $25.3 million in right-of-use-asset impairments and other costs, were included in restructuring charges.  A portion of these costs *may* be attributable to executive management, but the report doesn't offer that level of detail.  To find the exact amount, you would need to consult Lyft's detailed financial statements or notes, which are not included in this excerpt.\n", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run-5e36bba3-6166-495a-a68b-0057d4e9a8d0-0', usage_metadata={'input_tokens': 2012, 'output_tokens': 229, 'total_tokens': 2241, 'input_token_details': {'cache_read': 0}}), 'context': [Document(metadata={'id': '2', 'source': 'gs://10k-docs/uber.pdf', 'company': 'Uber', 'type': '10-K', 'year': '2023', 'url': 'https://d18rn0p25nwr6d.cloudfront.net/CIK-0001543151/6fabd79a-baa9-4b08-84fe-deab4ef8415f.pdf', 'previous_segments': [], 'next_segments': [], 'relevance_score': 0.574410080909729}, page_content="# Restructuring and Related Charges\n\nCosts associated with management-approved restructuring activities, including reductions in headcount, exiting a market or consolidation of facilities are recognized when they are incurred and may include employee termination benefits, impairment of long-lived assets (including impairment of operating lease right- of-use assets), contract termination costs and accelerated lease cost for right-of-use assets that ceased to be used. We record a liability for employee termination benefits either when it is probable that an employee is entitled to them and the amount of the benefits can be reasonably estimated or when management has communicated the termination plan to employees and all of the following conditions have been met: management, having the authority to approve the action, commits to a plan of termination; the plan identifies the number of employees to be terminated, their job classifications and their locations, and the expected completion date; the plan establishes the terms of the benefit arrangement in sufficient detail to enable employees to determine the type and amount of benefits they will receive if they are involuntarily terminated; and actions required to complete the plan indicate that it is unlikely that significant changes to the plan will be made or that the plan will be withdrawn. We accrue for costs to terminate contracts other than a lease when we terminate the contract in accordance with the contract terms. Costs that will continue to be incurred for the remaining term of a contract that is not a lease, and provide no economic benefits to us are recognized at the cease-use date. Costs associated with lease contracts are accounted for under the leasing accounting guidance or under the long-lived assets accounting guidance. Restructuring and related charges are recognized as an operating expense within the consolidated statements of operations and are classified based on our classification policy for each category of operating expense. Personnel costs are classified based on each employee's classification, lease costs (including impairments of right-of-use assets) are classified in the same expense line item where each lease's rent expense was recognized and impairment of othe ...
# Evaluating:   0%|          | 0/215 [00:00<?, ?it/s]
# Exception raised in Job[143]: AttributeError('StringIO' object has no attribute 'classifications')
# Exception raised in Job[79]: TimeoutError()
# {'answer_correctness': 0.4555, 'answer_relevancy': 0.6077, 'context_precision': 0.8605, 'context_recall': 0.7918, 'faithfulness': 0.7869}
