# %% [markdown]
# # Setup

# %%
# %pip install -qU IProgress
# %pip install -qU ipywidgets
# %pip install -qU python-dotenv
# %pip install -qU tqdm

# %pip install -qU langchain-core==0.2.40
# %pip install -qU langchain-core
# %pip install -qU langchain-community
# %pip install -qU langchain-openai 
# %pip install -qU langchain-qdrant 

# %pip install -qU pymupdf
# %pip install -qU ragas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Environment Variables

# %%
# Get environment variables

from dotenv import load_dotenv


# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Utilities

# %%
# Load docs from a directory

from langchain_community.document_loaders import DirectoryLoader 
from langchain_community.document_loaders import PyMuPDFLoader

def process_directory(path: str, glob: str, loader_cls: str, use_multithreading=True):
	
	loader = DirectoryLoader(path=path, glob=glob, show_progress=True, loader_cls=loader_cls, use_multithreading=use_multithreading)
	
	docs = loader.load()
	
	return docs

#####

def test_process_directory():
	docs = process_directory('docs/', '**/*.pdf', PyMuPDFLoader, True)
	print(len(docs))

# test_process_directory()

# %%
# Create embeddings using OpenAI

from langchain_openai import OpenAIEmbeddings

def create_embeddings_openai(model="text-embedding-ada-002") -> OpenAIEmbeddings:

	# Initialize the OpenAIEmbeddings class
	embeddings = OpenAIEmbeddings(model=model)

	return embeddings

#####

def test_create_embeddings_openai():
	text = "What is the annual revenue of Uber?"
	
	embeddings = create_embeddings_openai()
	vector = embeddings.embed_query(text)
	
	print(vector)

# test_create_embeddings_openai()

# %%
# Create a text splitter using recursive character text splitter

# https://python.langchain.com/v0.1/docs/modules/data_connection/document_transformers/recursive_text_splitter/

from langchain.text_splitter import RecursiveCharacterTextSplitter

def chunk_docs_recursive(docs: list, chunk_size=500, chunk_overlap=50) -> list:

	text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

	chunks = text_splitter.split_documents(docs)

	return chunks

#####

def test_chunk_docs_recursive(): 
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)
	
	print(f"\nNumber of chunks = {len(chunks)}\n")
	print(f"First chunk = {chunks[0].page_content}")

# test_chunk_docs_recursive()

# %%
# Create a Qdrant vector store

from langchain_core.embeddings import Embeddings
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

def create_qdrant_vector_store(location: str, 
							   collection_name: str, 
							   vector_size: int, 
							   embeddings: Embeddings, 
							   docs: list) -> QdrantVectorStore:

	# Initialize the Qdrant client
	qdrant_client = QdrantClient(location=location)

	# Create a collection in Qdrant
	qdrant_client.create_collection(collection_name=collection_name, 
								 vectors_config=VectorParams(size=vector_size, distance=Distance.COSINE))

	# Initialize QdrantVectorStore with the Qdrant client
	qdrant_vector_store = QdrantVectorStore(client=qdrant_client, 
										 collection_name=collection_name, embedding=embeddings)
	
	# Add the docs to the vector store
	qdrant_vector_store.add_documents(docs)
	
	return qdrant_vector_store

#####

def test_create_qdrant_vector_store():
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)
	
	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)
	
	print(vector_store.collection_name)

# test_create_qdrant_vector_store()

# %%
# Create a Qdrant retriever

from langchain_core.retrievers import BaseRetriever
from langchain_qdrant import QdrantVectorStore

def create_retriever_qdrant(vector_store: QdrantVectorStore) -> BaseRetriever:

	retriever = vector_store.as_retriever()

	return retriever

#####

def test_create_retriever_qdrant(text):
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)
	
	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)
	
	retriever = create_retriever_qdrant(vector_store)
	
	docs = retriever.invoke(text)	
	print(docs[0])

# test_create_retriever_qdrant("What is the annual revenue for Uber?")

# %%
# Create a prompt template

# https://python.langchain.com/v0.1/docs/modules/model_io/prompts/quick_start/#chatprompttemplate
# https://python.langchain.com/v0.2/api_reference/core/prompts/langchain_core.prompts.chat.ChatPromptTemplate.html

from langchain.prompts import ChatPromptTemplate

def create_chat_prompt_template(template: str = None) -> ChatPromptTemplate:
	
	if template is None:
		template = '''
		You are an expert assistant designed to help users analyze and answer questions about 10K annual reports filed by publicly traded companies. Users may ask about specific sections, financial metrics, trends, or comparisons across multiple reports. Your role is to provide accurate, concise, and relevant answers, referencing appropriate sections or data points where applicable.

		When responding, adhere to the following principles:

		Understand the Question: Identify whether the query is focused on a specific company, year, or metric, or if it spans multiple reports for comparison.
		Clarify Uncertainty: If a user's question is unclear, ask for clarification or additional context.
		Locate and Reference Information: Use relevant sections of the 10K report(s), such as MD&A, Financial Statements, Risk Factors, or Notes to Financial Statements, to back up your answers.
		Synthesize Data: Provide summaries or insights when the question involves comparing data or trends across multiple reports.
		Stay Objective: Avoid providing subjective opinions or interpretations beyond the factual content in the reports.
		Example User Queries and Expected Responses:

		"What was the revenue for Company X in 2022 and 2023?"

		Locate and report the revenue figures from the Income Statements of the respective 10K reports for 2022 and 2023.
		"What are the main risk factors for Company Y in its latest report?"

		Summarize the key risk factors from the most recent 10K report's "Risk Factors" section.
		"How did the operating income of Company Z change over the last three years?"

		Extract operating income figures from the 10K reports for the past three years and provide a brief comparison.
		"Compare the debt levels of Company A and Company B in 2023."

		Retrieve debt-related figures from the Balance Sheets or Notes to Financial Statements of both companies and summarize the comparison.
		"What trends are evident in Company W's R&D expenses over the last five years?"

		Summarize trends using data from the Income Statements or footnotes for R&D expenses across five consecutive 10K reports.
		Assumptions and Constraints:

		Only use inforomation from 10K reports provided in the context below. 
		For complex queries spanning multiple reports, provide a structured summary highlighting key comparisons or trends.
		If certain information is unavailable, state so clearly and suggest alternative approaches to obtain it.

		Now it's your turn!
		
		{question}

		{context}
		'''
	
	prompt = ChatPromptTemplate.from_template(template)

	return prompt

#####

def test_create_chat_prompt_template():
	prompt = create_chat_prompt_template()
	
	print(prompt)

# test_create_chat_prompt_template()

# %%
# Create a Langchain chain

from operator import itemgetter

from langchain_core.retrievers import BaseRetriever
from langchain_core.runnables import RunnablePassthrough, RunnableSerializable
from langchain_openai import ChatOpenAI

def create_chain (model: str, 
				  prompt_template: ChatPromptTemplate, 
				  retriever: BaseRetriever
				  ) -> RunnableSerializable:

	llm = ChatOpenAI(model=model)
		
	chain = (
		{"context": itemgetter("question") | retriever, "question": itemgetter("question")} 
		| RunnablePassthrough.assign(context=itemgetter("context")) 
		| {"response": prompt_template | llm, "context": itemgetter("context")}
		)

	return chain

#####

def test_create_chain_qdrant():
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)

	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)

	retriever = create_retriever_qdrant(vector_store)
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain("gpt-4o-mini", chat_prompt_template, retriever)
	
	result = chain.invoke({"question" : "What is the annual revenue of Uber?"})
	print(result)

# test_create_chain_qdrant()

# %%
# Generate answers from a chain using a list of questions

from typing import List, Tuple

from langchain_core.output_parsers import JsonOutputParser, StrOutputParser
from langchain_core.runnables import RunnableSerializable


def generate_answers_contexts(chain: RunnableSerializable, 
							  questions: list
							  ) -> Tuple[List, List]:
	
	answers = []
	contexts = []

	# Loop over the list of questions and call the chain to get the answer and context
	for question in questions:
		print(question)

		# Call the chain to get answers and contexts
		response = chain.invoke({"question" : question})
		print(response)

		# Capture the answer and context 
		answers.append(response["response"].content)
		contexts.append([context.page_content for context in response["context"]])

	return answers, contexts

#####

def test_generate_answers_contexts():
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)

	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)
	
	retriever = create_retriever_qdrant(vector_store)
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain("gpt-4o-mini", chat_prompt_template, retriever)
	
	questions = ["What is the annual revenue of Lyft?",
			  "What is the annual revenue of Uber?",
			  "Which company has a larger annual revenue - Lyft or Uber?"]	
	
	answers, contexts = generate_answers_contexts(chain=chain, questions=questions)
	
	print(f"Total number of answers = {len(answers)}")
	print(f"Total number of contexts = {len(contexts)}")

# test_generate_answers_contexts()

# %%
# Run a Ragas evaluation 

import time
from typing import Tuple

import pandas as pd
from pandas import DataFrame

from datasets import Dataset
from langchain_core.runnables import RunnableSerializable
from ragas import evaluate
from ragas.metrics import (
    answer_correctness,
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness,
)

def run_ragas_evaluation(chain: RunnableSerializable, 
						questions: list, 
						groundtruths: list, 
						eval_metrics: list = [answer_correctness, answer_relevancy, context_recall, context_precision, faithfulness]
						):
	
	answers = []
	contexts = []
	answers, contexts = generate_answers_contexts(chain=chain, questions=questions)

	# Create the input dataset 
	input_dataset = Dataset.from_dict({"question" : questions,       	# From the dataframe
										"answer" : answers,             # From the chain
										"contexts" : contexts,          # From the chain
										"ground_truth" : groundtruths   # From the dataframe
										})

	# Run the Ragas evaluation using the input dataset and eval metrics
	ragas_results = evaluate(input_dataset, eval_metrics)
	ragas_results_df = ragas_results.to_pandas()
	
	return ragas_results, ragas_results_df
	
#####

def test_run_ragas_evaluation():
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)
	
	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)
	
	retriever = create_retriever_qdrant(vector_store)
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain("gpt-4o-mini", chat_prompt_template, retriever)
	
	testset_df = pd.read_csv("testsets/10k_test_testset.csv")	# This testset contains a small number of questions
	questions = testset_df["question"].values.tolist()
	questions = [str(question) for question in questions]
	groundtruths = testset_df["ground_truth"].values.tolist()
	groundtruths = [str(ground_truth) for ground_truth in groundtruths]  
	eval_metrics = [answer_correctness, answer_relevancy, context_precision, context_recall, faithfulness]
	ragas_results, ragas_results_df = run_ragas_evaluation(chain, questions, groundtruths, eval_metrics)
	
	timestr = time.strftime("%Y%m%d%H%M%S")
	ragas_results_df.to_csv(f"evaluations/10x_test_testset_evaluation_{timestr}.csv")
	
	print(ragas_results)

# test_run_ragas_evaluation()

# %% [markdown]
# # Test 1 - OpenAI and Qdrant

# %%
# Build chain using OpenAI and Qdrant

embeddings = create_embeddings_openai()
docs = process_directory('docs/', '**/*.pdf', PyMuPDFLoader, True)
chunks = chunk_docs_recursive(docs=docs)
print(f'\nNumber of chunks = {len(chunks)}\n')
vector_store = create_qdrant_vector_store(':memory:', 'holiday-test', 1536, embeddings, chunks)
retriever = create_retriever_qdrant(vector_store)
chat_prompt_template = create_chat_prompt_template()
chain = create_chain('gpt-4o', chat_prompt_template, retriever)
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.96it/s]
# Number of chunks = 3398

# %%
# Test the chain with a few questions 

questions = ["What is the annual revenue of Uber?",
"What is the annual revenue of Lyft?",
"How does Uber's revenue compare to Lyft's revenue?",]

for question in questions:
	print(question)
	result = chain.invoke({"question" : question})
	print(result)
	print(result["response"].content)
	print("\n*****")
# Out:
# What is the annual revenue of Uber?
# {'response': AIMessage(content="The annual revenue for Uber Technologies, Inc. for the years 2021, 2022, and 2023 are as follows:\n\n- **2021**: $17,455 million\n- **2022**: $31,877 million\n- **2023**: $37,281 million\n\nThese figures are extracted from the Consolidated Statements of Operations found in Uber's 10K annual report.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 2079, 'total_tokens': 2165, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-56109b77-3c66-4310-8072-5932643ca76a-0', usage_metadata={'input_tokens': 2079, 'output_tokens': 86, 'total_tokens': 2165, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 76, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '47ddb33e5dbd4e6fb15d78bea0f67a99', '_collection_name': 'holiday-test'}, page_content='UBER TECHNOLOGIES, INC.\nCONSOLIDATED STATEMENTS OF OPERATIONS\n(In millions, except share amounts which are reflected in thousands, and per share amounts)\nYear Ended December 31,\n2021\n2022\n2023\nRevenue\n$\n17,455\xa0\n$\n31,877\xa0\n$\n37,281\xa0\nCosts and expenses\nCost of revenue, exclusive of depreciation and amortization shown separately below\n9,351\xa0\n19,659\xa0\n22,457\xa0\nOperations and support\n1,877\xa0\n2,413\xa0\n2,689\xa0\nSales and marketing\n4,789\xa0\n4,756\xa0\n4,356\xa0\nResearch and development\n2,054\xa0\n2,798\xa0\n3,164'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 95, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '667047d5906a418389f84ac9922bcc42', '_collection_name': 'holiday-test'}, page_content='$\n6,953\xa0\n$\n14,029\xa0\n$\n19,832\xa0\nDelivery revenue \n8,362\xa0\n10,901\xa0\n12,204\xa0\nFreight revenue\n2,132\xa0\n6,947\xa0\n5,245\xa0\nAll Other revenue\n8\xa0\n—\xa0\n—\xa0\nTotal revenue\n$\n17,455\xa0\n$\n31,877\xa0\n$\n37,281\xa0\n We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass (“Subscription”). We recognize Subscription fees\nratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 51, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D ...
# The annual revenue for Uber Technologies, Inc. for the years 2021, 2022, and 2023 are as follows:
#
# - **2021**: $17,455 million
# - **2022**: $31,877 million
# - **2023**: $37,281 million
#
# These figures are extracted from the Consolidated Statements of Operations found in Uber's 10K annual report.
#
# *****
# What is the annual revenue of Lyft?
# {'response': AIMessage(content="The annual revenue of Lyft for the year ending December 31, 2023, was $4,403,589,000. This information is found in the Consolidated Statements of Operations section of Lyft's 10K report.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 1977, 'total_tokens': 2025, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-4256a207-de55-4901-bec0-12f5bc7b8722-0', usage_metadata={'input_tokens': 1977, 'output_tokens': 48, 'total_tokens': 2025, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 4, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'a3f18c48f4054417bbb25e045ff2c90b', '_collection_name': 'holiday-test'}, page_content='revenue. We also generate revenue from riders renting Light Vehicles, drivers renting vehicles through Express Drive and by making our ridesharing\nmarketplace available to organizations through our Lyft Business offerings, such as our Concierge and Lyft Pass programs. In 2021, we began generating\nrevenues from licensing and data access agreements. In 2022, we began generating revenues from the sale of bikes and bike station software and hardware'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 83, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '1552619ac0d5448e98e3dab06e19086a', '_collection_name': 'holiday-test'}, page_content='$\n4,403,589\xa0 $\n4,095,135\xa0\n$\n3,208,323\xa0\nRevenue from Contracts with Customers (ASC 606)\nThe Company recognizes revenue for its rideshare marketplace in accordance with ASC 606. The Company generates revenue from service fees and\ncommissions (collectively, “fees”) paid by drivers for use of the Lyft Platform and related activities to connect drivers with riders to facilitate and successfully'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 76, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '44501cd465ef458b85472ce54b4042ec', '_collection_name': 'holiday-test'}, page_content='Lyft, Inc.\nConsolidated Statements of Operations\n(in thousands, except for per share data)\nYear Ended December 31,\n2023\n2022\n2021\nRevenue\n$\n4,403,589\xa ...
# The annual revenue of Lyft for the year ending December 31, 2023, was $4,403,589,000. This information is found in the Consolidated Statements of Operations section of Lyft's 10K report.
#
# *****
# How does Uber's revenue compare to Lyft's revenue?
# {'response': AIMessage(content="To compare Uber's and Lyft's revenues for the year ending December 31, 2023, we can refer to the total revenue figures provided in their respective 10-K reports.\n\n**Uber's Revenue:**\n- Uber's total revenue for 2023 was $37,281 million. (Source: Uber 10-K report, page 95)\n\n**Lyft's Revenue:**\n- Lyft's total revenue for 2023 was $4,403,589 thousand, which is equivalent to $4,404 million. (Source: Lyft 10-K report, page 83)\n\n**Comparison:**\n- Uber's revenue in 2023 was significantly higher than Lyft's, with Uber reporting approximately $37.3 billion compared to Lyft's $4.4 billion.\n\nThis comparison highlights a substantial difference in the scale of operations between the two companies, with Uber generating over eight times more revenue than Lyft in 2023.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 190, 'prompt_tokens': 1938, 'total_tokens': 2128, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-155fb18e-b165-401b-b986-e98e5dc4283d-0', usage_metadata={'input_tokens': 1938, 'output_tokens': 190, 'total_tokens': 2128, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 4, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'a3f18c48f4054417bbb25e045ff2c90b', '_collection_name': 'holiday-test'}, page_content='revenue. We also generate revenue from riders renting Light Vehicles, drivers renting vehicles through Express Drive and by making our ridesharing\nmarketplace available to organizations through our Lyft Business offerings, such as our Concierge and Lyft Pass programs. In 2021, we began generating\nrevenues from licensing and data access agreements. In 2022, we began generating revenues from the sale of bikes and bike station software and hardware'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 83, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '1552619ac0d5448e98e3dab06e19086a', '_collection_name': 'holiday-test'}, page_content='$\n4,403,589\xa0 $\n4,095,135\xa0\n$\n3,208,323\xa0\nRevenue from Contracts with Customers (ASC 606)\nThe Company recognizes revenue for its rideshare marketplace in accordance with ASC 606. The Company generates revenue from service fees and\ncommissions (collectively, “fees”) paid by drivers for use of the Lyft Platform and related activities to connect drivers with riders to facilitate and successfully'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 95, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10- ...
# To compare Uber's and Lyft's revenues for the year ending December 31, 2023, we can refer to the total revenue figures provided in their respective 10-K reports.
#
# **Uber's Revenue:**
# - Uber's total revenue for 2023 was $37,281 million. (Source: Uber 10-K report, page 95)
#
# **Lyft's Revenue:**
# - Lyft's total revenue for 2023 was $4,403,589 thousand, which is equivalent to $4,404 million. (Source: Lyft 10-K report, page 83)
#
# **Comparison:**
# - Uber's revenue in 2023 was significantly higher than Lyft's, with Uber reporting approximately $37.3 billion compared to Lyft's $4.4 billion.
#
# This comparison highlights a substantial difference in the scale of operations between the two companies, with Uber generating over eight times more revenue than Lyft in 2023.
#
# *****

# %%
# Evaluate the chain using Ragas

import time

import pandas as pd

# Run the Ragas evaluation and show the results
# Get the questions and groundtruths from the dataframe
testset_df = pd.read_csv("testsets/10k_testset.csv")

questions = testset_df["question"].values.tolist()
questions = [str(question) for question in questions]

groundtruths = testset_df["ground_truth"].values.tolist()
groundtruths = [str(ground_truth) for ground_truth in groundtruths]  

# Specify the eval metrics
eval_metrics = [answer_correctness, answer_relevancy, context_precision, context_recall, faithfulness]

# Run the Ragas evaluation and show the results
ragas_results, ragas_results_df = run_ragas_evaluation(chain, questions, groundtruths, eval_metrics)

# Write the results to disk
timestr = time.strftime("%Y%m%d%H%M%S")
ragas_results_df.to_csv(f"evaluations/10x_test1_testset_evaluation_{timestr}.csv")

# Show the resutls
print(ragas_results)
# Out:
# What challenges do jurisdictions pose to business operations in the context of regulatory compliance?
# {'response': AIMessage(content='In the context of regulatory compliance, jurisdictions pose several challenges to business operations, particularly for companies like those in the ride-sharing industry. The key challenges identified from the provided 10K documents include:\n\n1. **Jurisdictional Restrictions and Modifications**: Businesses may be blocked or restricted from operating in certain jurisdictions. This could necessitate modifications to their business models to comply with local regulations, which can affect operations and market reach.\n\n2. **Extensive Regulation and Oversight**: Companies are subject to extensive government regulation and oversight, especially concerning payment and financial services. This requires constant monitoring and adaptation to ensure compliance with varying regulatory requirements across different regions.\n\n3. **Legal and Regulatory Risks**: Operating in multiple jurisdictions subjects companies to a broad spectrum of legal and regulatory risks. These risks can adversely impact the ability to conduct transactions, financial condition, and operating results.\n\n4. **Conflicting Laws and Regulations**: As companies expand their offerings and user bases, they may encounter additional laws and regulations. These can differ significantly from one jurisdiction to another, complicating compliance. Many existing laws were established before the emergence of new industry technologies, creating gaps and inconsistencies in regulatory frameworks.\n\nOverall, businesses must navigate a complex and evolving regulatory landscape, requiring significant resources and strategic adjustments to operate effectively across different jurisdictions.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 263, 'prompt_tokens': 1825, 'total_tokens': 2088, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-94656727-0e45-46f2-b07d-6dc5316a1b88-0', usage_metadata={'input_tokens': 1825, 'output_tokens': 263, 'total_tokens': 2088, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 12, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '36c815ad48a2440fad393b1df471cda7', '_collection_name': 'holiday-test'}, page_content='•\nWe may continue to be blocked from or limited in providing or operating our products and offerings in certain jurisdictions, and may be required to\nmodify our business model in those jurisdictions as a result.\n•\nOur business is subject to numerous legal and regulatory risks that could have an adverse impact on our business and future prospects.\n•\nOur business is subject to extensive government regulation and oversight relating to the provision of payment and financial services.\n•'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 35, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': ' ...
# What challenges does competition in technology pose for maintaining interoperability of platforms?
# {'response': AIMessage(content="Competition in the technology sector poses several challenges to maintaining the interoperability of platforms, as highlighted in the 10K reports:\n\n1. **Dependence on Third-Party Systems**: Companies depend heavily on third-party operating systems and applications, such as iOS and Android, for their platforms to function seamlessly across various devices. This dependency means any changes or updates in these third-party systems can potentially disrupt interoperability if the platform cannot be quickly adapted to maintain compatibility.\n\n2. **Rapid Evolution of Third-Party Services**: Third-party services and products are constantly evolving. This rapid change can make it challenging for companies to modify their platforms swiftly enough to ensure continued compatibility. Failing to keep up with these changes can lead to a loss of interoperability.\n\n3. **Competitive Actions**: Competitors or technology partners may take actions that intentionally disrupt the interoperability of a company's platform. This could include changes to their own products or services that create compatibility issues or exerting business influence that affects terms of access or integration.\n\nThese challenges require companies to be agile and proactive in maintaining their platforms' interoperability, despite the competitive and rapidly changing technology landscape.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 226, 'prompt_tokens': 1857, 'total_tokens': 2083, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-2a01e66e-aeff-4581-98b1-2877e02746a1-0', usage_metadata={'input_tokens': 1857, 'output_tokens': 226, 'total_tokens': 2083, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 30, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'b5a48651d25349daa53696307ed2519f', '_collection_name': 'holiday-test'}, page_content='be required to seek comparable software from other sources, which may be more expensive or inferior, or may not be available at all, any of which would adversely\naffect our business.\nOur business depends upon the interoperability of our platform across devices, operating systems, and third-party applications that we do not control.\nOne of the most important features of our platform is its broad interoperability with a range of devices, operating systems, and third-party applications. Our'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 30, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '0e45f98b575042deb78b9c372969450c', '_collection_name': 'holiday-test'}, page_content='platform is accessib ...
# What factors could adversely impact the financial results of the company?
# {'response': AIMessage(content='To determine the factors that could adversely impact the financial results of the company, we need to look at the relevant sections of the 10K report that discuss risks and challenges. Based on the provided excerpts from Lyft\'s 10K report, here are some factors that could negatively affect the company\'s financial results:\n\n1. **General Economic Factors:**\n   - A deterioration of macroeconomic conditions, such as slower growth or recession, inflation, increased interest rates, higher fuel and vehicle costs, and changes in the labor market, could materially and adversely affect the business and financial results.\n\n2. **Regulatory and Legal Factors:**\n   - The company is subject to a wide range of evolving laws and regulations. Non-compliance with such regulations could harm the business, financial condition, and results of operations.\n\n3. **Competitive Factors:**\n   - The company\'s ability to compete effectively depends on various factors both within and beyond its control. Failure to compete successfully could adversely affect the business, financial condition, and results of operations.\n\nThese factors are highlighted in the "Risk Factors" section of the 10K report, which typically discusses various elements that could pose risks to the company\'s financial performance.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 238, 'prompt_tokens': 1812, 'total_tokens': 2050, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-d76947e7-823e-4705-a975-963431df188c-0', usage_metadata={'input_tokens': 1812, 'output_tokens': 238, 'total_tokens': 2050, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 14, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '3283c710c04248db9bfdf03271ca37a4', '_collection_name': 'holiday-test'}, page_content='Risks Related to General Economic Factors\nA deterioration of general macroeconomic conditions could materially and adversely affect our business and financial results.\nOur business and results of operations are subject to global economic conditions. Deteriorating macroeconomic conditions, including slower growth or\nrecession, inflation and related increases in interest rates, increases to fuel and other energy costs or vehicle costs, changes in the labor market or decreases in'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 36, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'b4553bdfdcb243a5b5328811388707f4', '_collection_name': 'holiday-test'}, page_content='adverse effect on our reputation, brand, business, financial condition and results of operations.\ ...
# What role did the Deputy Chief Technology Officer play in the context of cybersecurity at a Fortune 500 company?
# {'response': AIMessage(content="The role of the Deputy Chief Technology Officer (DCTO) in the context of cybersecurity within a Fortune 500 company is not explicitly detailed in the provided documents. However, it is mentioned that the individual had engineering and/or cybersecurity experience, including serving as the CISO (Chief Information Security Officer) and Deputy Chief Technology Officer. This implies that the DCTO likely played a significant role in overseeing or guiding the company's cybersecurity initiatives.\n\nFor more detailed information on their specific responsibilities or contributions, additional context from the company's detailed organizational structure or specific descriptions of their cybersecurity framework might be necessary. If you have access to more specific sections of their 10K report or other internal documents, those could provide further insights into the exact role and responsibilities of the DCTO in cybersecurity.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 155, 'prompt_tokens': 1853, 'total_tokens': 2008, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1664}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-b02288be-7911-4e97-814b-a6d0fcf3676e-0', usage_metadata={'input_tokens': 1853, 'output_tokens': 155, 'total_tokens': 2008, 'input_token_details': {'audio': 0, 'cache_read': 1664}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 46, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '47a6461023474d47945f34b8a9de597a', '_collection_name': 'holiday-test'}, page_content='engineering and/or cybersecurity experience, including previously as CISO and Deputy Chief Technology Officer at a Fortune 500 company.\nThe Cybersecurity Program is also supported by Uber’s Chief Privacy Officer and Associate General Counsel, Privacy & Cybersecurity (“CPO”), who has\nserved in that role since August 2018. The CPO has three decades of experience as a legal advisor to\n45'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 47, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '8e9da58f46274e0893cc152afdfd8a6b', '_collection_name': 'holiday-test'}, page_content='multinational corporations, including serving as Chief Privacy & Security Counsel for a Fortune 100 technology company prior to her role at Uber.\nThe Cybersecurity Program is supported by other members of Uber’s senior management team as well, including the Chief Legal Officer, Head of Platform\nEngineering, and EU Data Protection Officer. Uber’s Board of Directors oversees the Cybersecurity Program through regular updates.'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 46, 'total_pages': 191, 'format': 'PDF 1 ...
# What benefits do members receive from the Uber One membership program?
# {'response': AIMessage(content="Uber One members receive several benefits, as outlined in the document. These benefits include:\n\n1. **Discounts**: Members have access to various discounts on Uber services.\n2. **Special Pricing**: They receive special pricing on rides, delivery, and grocery offerings.\n3. **Priority Service**: Members are given priority service across Uber's platforms.\n4. **Exclusive Perks**: They enjoy exclusive perks that are available only to Uber One members.\n\nThese benefits are designed to enhance the user experience across Uber's suite of services, including rides, delivery, and grocery.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 117, 'prompt_tokens': 1828, 'total_tokens': 1945, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-05a0bbea-8d75-4eda-a378-18005629d244-0', usage_metadata={'input_tokens': 1828, 'output_tokens': 117, 'total_tokens': 1945, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 6, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '93a49b6b494942918f8e21f07bfddcba', '_collection_name': 'holiday-test'}, page_content='which combines our multiple offerings into a single app and is designed to remove friction for our consumers. During November 2021, we launched Uber One in\nthe United States as our single cross-platform membership program that brings together the best of Uber. Uber One members have access to discounts, special\npricing, priority service, and exclusive perks across our rides, delivery and grocery offerings. Since then, we have expanded Uber One to approximately 25'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 6, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '93dbbea2f9ce4779add68d249c1f2424', '_collection_name': 'holiday-test'}, page_content='countries. Our Eats Pass membership program continues to remain available in select cities as a subscription offering. Our membership programs are designed to\nmake utilizing our suite of products a seamless and rewarding experience for our consumers. We exited 2023 with 19 million members for our Uber One, Eats Pass\nand Rides Pass membership programs.'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 9, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215 ...
# What challenges do ridesharing companies face in terms of government regulation?
# {'response': AIMessage(content='Ridesharing companies face several challenges regarding government regulation, as highlighted in the 10K reports for Lyft and Uber:\n\n1. **Local and National Legislation**: Many jurisdictions in the United States and Canada have enacted laws that impose limitations on ridesharing and bike/scooter sharing. These regulations can include minimum driver earnings and other operational restrictions. Companies must navigate these diverse regulatory environments, which can vary significantly from one location to another.\n\n2. **Earnings and Employment Classification**: There is ongoing consideration and implementation of laws regulating driver earnings, which can impact the financial model of ridesharing companies. Additionally, there is increased scrutiny on the classification of drivers as independent contractors, which can lead to regulatory challenges.\n\n3. **International Regulations**: Ridesharing companies may also face similar regulatory challenges from foreign regulators, as they expand their operations into new international markets.\n\n4. **Environmental Regulations**: Given that a considerable part of their business involves vehicles running on fossil fuels, ridesharing companies like Uber face potential regulations aimed at reducing environmental impact. This could include laws promoting electric vehicles or other sustainability measures.\n\n5. **Regulatory Scrutiny**: Recent events have heightened regulatory scrutiny on technology companies, especially those dealing with independent contractors. Ridesharing companies must contend with potential new laws or regulations that may be adverse to their business operations.\n\nOverall, ridesharing companies must actively engage with federal, state, and local governments to ensure compliance and adapt to new regulatory changes that may affect their business models.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 309, 'prompt_tokens': 1864, 'total_tokens': 2173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-0e96263e-b840-4448-b5c5-0cea157ff135-0', usage_metadata={'input_tokens': 1864, 'output_tokens': 309, 'total_tokens': 2173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 37, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '7b7527fd44a040f78103c2e65e29ef5d', '_collection_name': 'holiday-test'}, page_content='relationships with drivers or otherwise inhibited the growth of our ridesharing marketplace. We have been proactively working with federal, state and local\ngovernments and regulatory bodies to ensure that our ridesharing marketplace and other offerings are available broadly in the United States and Canada. In part\ndue to our efforts, a large majority of U.S. states have adopted laws related to TNCs to address the unique issues of the ridesharing industry. New laws and'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 37, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': ' ...
# What challenges could an 'investment company' face in operations and financial reporting?
# {'response': AIMessage(content='An \'investment company\' may face several challenges in operations and financial reporting. Based on the provided documents and typical considerations for investment companies, some challenges include:\n\n1. **Regulatory Compliance**: Investment companies are subject to the Investment Company Act, which imposes substantive legal requirements on their operations. Compliance with these regulations can be complex and resource-intensive, potentially affecting how the company conducts its business and reports its financials.\n\n2. **Financial Reporting Controls**: Maintaining effective internal controls over financial reporting is crucial. If these controls are inadequate, it may lead to inaccuracies in financial reports, eroding investor confidence and negatively impacting the company\'s stock price.\n\n3. **Operational Challenges**: As companies grow, particularly in high-growth areas, they may face challenges in designing and implementing appropriate controls for transaction processing and reporting systems. This is crucial for maintaining accurate and timely financial reporting.\n\n4. **Cost Management**: Operating as a public company involves significant costs related to compliance, reporting, and maintaining internal controls. Effective cost management is essential to ensure profitability and operational efficiency.\n\nIf any specific challenges are not covered by the documents provided, further details might be available in sections like "Risk Factors" or "Management\'s Discussion and Analysis" in a company\'s 10K report.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 253, 'prompt_tokens': 1814, 'total_tokens': 2067, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-38cfb515-cd6f-422b-a01c-dccb95e1fc40-0', usage_metadata={'input_tokens': 1814, 'output_tokens': 253, 'total_tokens': 2067, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 18, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '66895e91a49d4365907a0b8985f63515', '_collection_name': 'holiday-test'}, page_content='over financial reporting, we will be required to commit substantial financial, operational, and technical resources. In particular, we will need to improve our\ntransaction processing and reporting, operational, and financial systems, procedures, and controls. For example, due to our significant growth, especially with\nrespect to our high-growth emerging offerings like Delivery and Freight, we face challenges in timely and appropriately designing controls in response to evolving'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 43, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'tra ...
# What role do unobservable inputs play in fair value assessments vs. observable market inputs?
# {'response': AIMessage(content="In fair value assessments, inputs are categorized within a hierarchical framework, often referred to as levels, to determine the reliability and transparency of the valuation process. Here's how unobservable inputs compare to observable market inputs:\n\n1. **Observable Market Inputs (Level 1 and Level 2):**\n   - **Level 1 Inputs:** These are observable inputs that reflect quoted prices (unadjusted) for identical assets or liabilities in active markets. These inputs are the most reliable and transparent, as they are directly derived from active market data.\n   - **Level 2 Inputs:** These include inputs other than quoted prices included in Level 1 that are observable for the asset or liability, either directly or indirectly. These might include quoted prices for similar assets or liabilities in active markets, or other observable inputs like interest rates and yield curves.\n\n2. **Unobservable Inputs (Level 3):**\n   - Unobservable inputs are those for which there is little or no market data available, and they are significant to the fair value measurement. They often reflect the company’s own assumptions about what market participants would use in pricing the asset or liability. These inputs are typically used when observable inputs are not available, necessitating the use of internal data and assumptions.\n   - Unobservable inputs can include factors such as short-term revenue projections, time to liquidity, and volatility, among others. These inputs are inherently more subjective and can lead to greater variability in fair value estimates.\n\nThe choice between using observable and unobservable inputs depends largely on the availability of market data and the nature of the asset or liability being valued. Observable inputs are generally preferred due to their reliability, but when these are not available, unobservable inputs become essential, albeit with increased reliance on assumptions and internal projections.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 352, 'prompt_tokens': 1813, 'total_tokens': 2165, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-431b1a3e-4d61-4fd8-ba80-210d657bb354-0', usage_metadata={'input_tokens': 1813, 'output_tokens': 352, 'total_tokens': 2165, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 97, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '0a4d7315ecb74c989ab7810803c75730', '_collection_name': 'holiday-test'}, page_content='An increase or decrease in any of the unobservable inputs in isolation, such as the security price in a significant financing transaction of the investee, could\nresult in a material increase or decrease in our estimate of fair value. Other unobservable inputs, including short-term revenue projections, time to liquidity, and\nvolatility are less sensitive to the valuation in the respective reporting\n(2) \n(3) \n(1)\n(1) \n96'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 87, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® O ...
# How does ASC 842 affect revenue and cost reporting?
# {'response': AIMessage(content='ASC 842, "Leases," primarily affects the accounting treatment of leases rather than directly impacting revenue and cost reporting. However, it can influence financial reporting in the following ways:\n\n1. **Revenue Reporting**: \n   - Under ASC 842, companies must identify and account for rental revenue separately from revenue generated from contracts with customers. For example, in the provided Lyft document, rental revenue is reported separately from revenue from contracts with customers, as seen in the revenue breakdown for the years 2021 to 2023.\n\n2. **Cost Reporting**: \n   - ASC 842 affects the recognition and measurement of lease-related expenses. Companies might choose not to separate non-lease components from lease components, as noted in the Uber document. This decision can affect the classification and timing of expenses associated with leases.\n\nOverall, while ASC 842 does not directly change how revenue and costs are reported, it mandates specific treatment and disclosure of lease-related revenues and expenses, which can impact the presentation and understanding of a company\'s financial results.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 208, 'prompt_tokens': 1928, 'total_tokens': 2136, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-08012742-c728-41f5-973f-92641d1fb59d-0', usage_metadata={'input_tokens': 1928, 'output_tokens': 208, 'total_tokens': 2136, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 83, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'c30046cd3d7a470b8f6fb5bbd6517b99', '_collection_name': 'holiday-test'}, page_content="its network of Light Vehicles, which is recognized in accordance with Accounting Standards Codification Topic 842 (“ASC 842”).\nThe table below presents the Company's revenues as included on the consolidated statements of operations (in thousands):\nYear Ended December 31,\n2023\n2022\n2021\nRevenue from contracts with customers (ASC 606)\n$\n4,116,216\xa0 $\n3,811,993\xa0\n$\n2,957,979\xa0\nRental revenue (ASC 842)\n287,373\xa0\n283,142\xa0\n250,344\xa0\nTotal revenue\n$\n4,403,589\xa0 $\n4,095,135\xa0\n$\n3,208,323"), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 85, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'c9a5ef3745ac446b8d5ec3dd6819bab6', '_collection_name': 'holiday-test'}, page_content='Leases\nWe account for leases in accordance with Accounting Standards Codification (“ASC”) 842, “Leases” (“ASC 842”). We elected the “package of practical\nexpedients,” which permits us not to reassess under ASC 842 our prior conclus ...
# What IP risks come from joint dev. agreements and their effect on competition?
# {'response': AIMessage(content="Joint development agreements can present several intellectual property (IP) risks that may affect a company's ability to compete effectively. Here are the key points derived from the provided documents:\n\n1. **Joint Ownership and Control**: When intellectual property is developed through joint agreements, it may be jointly owned by the parties involved. This joint ownership can limit a company's ability to independently protect, maintain, enforce, or commercialize these IP rights. It may require agreement or payments to the joint development partners before any action can be taken regarding the IP (Source: Lyft).\n\n2. **Impact on IP Value and Competitive Position**: The manner in which joint development partners register, maintain, enforce, or license the jointly-owned intellectual property can affect its value and the original company's ability to compete in the market (Source: Lyft).\n\n3. **Adverse Business Effects**: A loss of control over intellectual property, or inadequate protection, can lead to adverse effects on a company's business, financial condition, or operating results. This includes harming a company's brand, reputation, and ultimately its ability to compete effectively (Source: Uber).\n\n4. **Challenges from Third Parties**: Companies in technology-driven industries may face challenges from other patent and trademark holders, including non-practicing entities seeking profits from royalties or injunctions. This can complicate the landscape for companies operating under joint development agreements (Source: Uber).\n\nThese risks underscore the importance of carefully structuring joint development agreements to ensure that a company retains sufficient control over its IP to protect its competitive position.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 305, 'prompt_tokens': 1785, 'total_tokens': 2090, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-8fd21d5e-2147-4da3-a6ab-a7611959539d-0', usage_metadata={'input_tokens': 1785, 'output_tokens': 305, 'total_tokens': 2090, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 39, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '9333b83205a54d96b06ee405cbfd3638', '_collection_name': 'holiday-test'}, page_content='initiating enforcement of such intellectual property rights, and may allow such joint development partners to register, maintain, enforce or license such\nintellectual property rights in a manner that may affect the value of the jointly-owned intellectual property or our ability to compete in the market.\n40'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 39, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D: ...
# What links driver contracts, revenue recognition, and the Lyft Platform?
# {'response': AIMessage(content='The links between driver contracts, revenue recognition, and the Lyft Platform can be understood through the following aspects based on the provided 10K document excerpts:\n\n1. **Driver Contracts**: Drivers using the Lyft Platform are required to enter into Terms of Service (ToS) agreements with Lyft. This contractual relationship allows drivers to access the Lyft Driver App and participate in the ridesharing marketplace.\n\n2. **Revenue Recognition**: Lyft recognizes revenue primarily from its ridesharing marketplace, which involves connecting drivers and riders. Revenue is recognized in accordance with ASC 606, which pertains to revenue from contracts with customers. Lyft generates revenue from service fees and commissions paid by drivers for using the Lyft Platform.\n\n3. **Lyft Platform**: The Lyft Platform facilitates the connection between drivers and riders, enabling a multimodal transportation network. The platform serves as the core through which the company derives its revenue from the ridesharing services.\n\nThe interplay of these elements is crucial: the driver contracts permit access to the Lyft Platform, which in turn generates revenue through fees paid by drivers. This revenue is recognized according to specific accounting standards (ASC 606), highlighting the structured approach Lyft takes in its financial operations.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 240, 'prompt_tokens': 1829, 'total_tokens': 2069, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-0355b784-0938-4e29-9cca-de363013a2be-0', usage_metadata={'input_tokens': 1829, 'output_tokens': 240, 'total_tokens': 2069, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 57, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'f4996978dce34d11ba2f7de734569202', '_collection_name': 'holiday-test'}, page_content='Revenues from Contracts with Customers (ASC 606)\nWe generate substantially all our revenue from our ridesharing marketplace that connects drivers and riders. We recognize revenue from fees paid by\ndrivers for use of our Lyft Platform offerings in accordance with ASC 606 as described in Note 2 of the notes to our consolidated financial statements. Drivers\nenter into terms of service (“ToS”) with us in order to use our Lyft Driver App.'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 83, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'c3758ed4a7f94036bc9a1a3d0d2176f4', '_collection_name': 'holiday-test'}, page_content='transactions are recognized on a gross basis on the consolidated financial statements. D ...
# What regulatory challenges could come with global product launches?
# ...
# What reputational risks come from arbitration clauses under legal review?
# {'response': AIMessage(content="The use of arbitration clauses in legal agreements can pose reputational risks for companies, as evidenced by the excerpts from the 10K reports of Uber and Lyft. These risks primarily arise from:\n\n1. **Public Scrutiny**: Arbitration provisions have been increasingly scrutinized by the public. This scrutiny can negatively impact a company's reputation and brand image, as stakeholders may perceive these clauses as limiting consumers' rights to seek redress through traditional legal avenues.\n\n2. **Increased Litigation Costs and Exposure**: If arbitration agreements are found unenforceable or if certain claims are exempted from arbitration, companies could face higher litigation costs and longer resolution times. This could lead to increased exposure to potentially costly lawsuits, thereby affecting the company's financial condition and operational results.\n\n3. **Regulatory Challenges**: Companies might be required to limit their use of arbitration provisions due to legal or regulatory proceedings. Compliance with such requirements can further increase litigation costs and expose the company to more lawsuits.\n\nBoth Uber and Lyft acknowledge these risks in their reports, indicating that they have taken steps to minimize them, such as potentially limiting the use of arbitration clauses. However, the ongoing legal reviews and changes in regulatory landscapes continue to pose challenges and risks to their reputations.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 247, 'prompt_tokens': 1822, 'total_tokens': 2069, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-0ffdc054-ffad-48fc-b7dc-16ca03742d0a-0', usage_metadata={'input_tokens': 1822, 'output_tokens': 247, 'total_tokens': 2069, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 40, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'bf845825360442b8ad11d7b2f093b152', '_collection_name': 'holiday-test'}, page_content='more costly for us, or the volume of arbitrations may increase and become burdensome. Further, the use of arbitration provisions may subject us to certain risks to\nour reputation and brand, as these provisions have been the subject of increasing public scrutiny. To minimize these risks, we have in the past and may in the future\n39'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 41, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'bcd90256d339473eba81aa3871bffb99', '_collection_name': 'holiday-test'}, page_content='the use of arbitration provisions may subject us to certain risks to our reputation and brand, as these provis ...
# What perks do Uber One members get for rides and delivery?
# {'response': AIMessage(content="Uber One members receive several perks for rides and delivery services. According to the provided information from Uber's 10-K report, Uber One members have access to:\n\n- Discounts\n- Special pricing\n- Priority service\n- Exclusive perks\n\nThese benefits are applicable across Uber's rides, delivery, and grocery offerings, making the membership a comprehensive package for frequent users of Uber's services.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1933, 'total_tokens': 2010, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-76826c51-a3a2-4434-b016-772dead35f23-0', usage_metadata={'input_tokens': 1933, 'output_tokens': 77, 'total_tokens': 2010, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 6, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '93a49b6b494942918f8e21f07bfddcba', '_collection_name': 'holiday-test'}, page_content='which combines our multiple offerings into a single app and is designed to remove friction for our consumers. During November 2021, we launched Uber One in\nthe United States as our single cross-platform membership program that brings together the best of Uber. Uber One members have access to discounts, special\npricing, priority service, and exclusive perks across our rides, delivery and grocery offerings. Since then, we have expanded Uber One to approximately 25'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 6, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '93dbbea2f9ce4779add68d249c1f2424', '_collection_name': 'holiday-test'}, page_content='countries. Our Eats Pass membership program continues to remain available in select cities as a subscription offering. Our membership programs are designed to\nmake utilizing our suite of products a seamless and rewarding experience for our consumers. We exited 2023 with 19 million members for our Uber One, Eats Pass\nand Rides Pass membership programs.'), Document(metadata={'source': 'docs\\lyft.pdf', 'file_path': 'docs\\lyft.pdf', 'page': 5, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '2331a513120d45199429561224d04de1', '_collection_name': 'hol ...
# What exec mgmt & restructuring costs add to G&A?
# {'response': AIMessage(content='The executive management and restructuring costs that contribute to General and Administrative (G&A) expenses are primarily related to compensation costs, including stock-based compensation, for executive management and administrative employees. This includes personnel in finance and accounting, human resources, policy and communications, and legal departments. Additionally, G&A expenses incorporate certain impairment charges, allocation of corporate costs, occupancy, general corporate insurance costs, and certain legal settlements.\n\nFurthermore, the restructuring and related charges are also part of the G&A expenses, as indicated by the document referencing a specific restructuring charge of $(51), which likely impacts the overall G&A figures.\n\nTo summarize, the key components adding to G&A expenses are:\n\n1. Compensation costs for executive management and administrative employees.\n2. Stock-based compensation.\n3. Impairment charges.\n4. Corporate costs, occupancy, and insurance.\n5. Legal settlements.\n6. Restructuring and related charges.\n\nThese elements collectively contribute to the G&A expenses as detailed in the 10K report.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 201, 'prompt_tokens': 1899, 'total_tokens': 2100, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-e8acb77c-ae42-4048-9dbe-5bfa514af1e9-0', usage_metadata={'input_tokens': 1899, 'output_tokens': 201, 'total_tokens': 2100, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), 'context': [Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 93, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '3561bf89548f4aaea65313437b1d80c2', '_collection_name': 'holiday-test'}, page_content='•\nGeneral and administrative expenses primarily consist of compensation costs, including stock-based compensation, for executive management and\nadministrative employees, including finance and accounting, human resources, policy and communications, legal, and certain impairment charges, as well\nas allocation of certain corporate costs, occupancy, and general corporate insurance costs. General and administrative expenses also include certain legal\nsettlements.\n•'), Document(metadata={'source': 'docs\\uber.pdf', 'file_path': 'docs\\uber.pdf', 'page': 53, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'd0caeaeeaa994c6d9d5526d8fecaff49', '_collection_name': 'holiday-test'}, page_content='administrative employees, including finance and accounting, human resources, policy and communications, legal, and certain impairment charges, as well as\nallocation of certain corporate costs, occupancy, and general corporate insurance costs. General and admi ...
# Evaluating:   0%|          | 0/215 [00:00<?, ?it/s]
# {'answer_correctness': 0.5195, 'answer_relevancy': 0.9159, 'context_precision': 0.7907, 'context_recall': 0.7240, 'faithfulness': 0.7783}
