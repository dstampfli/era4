# %% [markdown]
# # Setup

# %%
# %pip install -qU IProgress
# %pip install -qU ipywidgets
# %pip install -qU python-dotenv
# %pip install -qU tqdm

# %pip install -qU langchain-core==0.2.40
# %pip install -qU langchain-community
# %pip install -qU langchain-openai 
# %pip install -qU langchain-qdrant 

# %pip install -qU pymupdf
# %pip install -qU ragas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-qdrant 0.2.0 requires langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43, but you have langchain-core 0.2.40 which is incompatible.
# langchain-community 0.2.19 requires langchain-core<0.3.0,>=0.2.43, but you have langchain-core 0.2.40 which is incompatible.
# langchain 0.2.17 requires langchain-core<0.3.0,>=0.2.43, but you have langchain-core 0.2.40 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.1.25 requires langchain-core<0.3.0,>=0.2.40, but you have langchain-core 0.3.29 which is incompatible.
# ragas 0.1.20 requires langchain-core<0.3, but you have langchain-core 0.3.29 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ragas 0.1.20 requires langchain-core<0.3, but you have langchain-core 0.3.29 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Environment Variables

# %%
# Get environment variables

from dotenv import load_dotenv


# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %% [markdown]
# # Utilities

# %%
# Load docs from a directory

from langchain_community.document_loaders import DirectoryLoader 
from langchain_community.document_loaders import PyMuPDFLoader

def process_directory(path: str, glob: str, loader_cls: str, use_multithreading=True):
	
	loader = DirectoryLoader(path=path, glob=glob, show_progress=True, loader_cls=loader_cls, use_multithreading=use_multithreading)
	
	docs = loader.load()
	
	return docs

#####

def test_process_directory():
	docs = process_directory('docs/', '**/*.pdf', PyMuPDFLoader, True)
	print(len(docs))

# test_process_directory()

# %%
# Create embeddings using OpenAI

from langchain_openai import OpenAIEmbeddings

def create_embeddings_openai(model="text-embedding-ada-002") -> OpenAIEmbeddings:

	# Initialize the OpenAIEmbeddings class
	embeddings = OpenAIEmbeddings(model=model)

	return embeddings

#####

def test_create_embeddings_openai():
	text = "What is the annual revenue of Uber?"
	
	embeddings = create_embeddings_openai()
	vector = embeddings.embed_query(text)
	
	print(vector)

# test_create_embeddings_openai()

# %%
# Create a text splitter using recursive character text splitter

# https://python.langchain.com/v0.1/docs/modules/data_connection/document_transformers/recursive_text_splitter/

from langchain.text_splitter import RecursiveCharacterTextSplitter

def chunk_docs_recursive(docs: list, chunk_size=500, chunk_overlap=50) -> list:

	text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)

	chunks = text_splitter.split_documents(docs)

	return chunks

#####

def test_chunk_docs_recursive(): 
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)
	
	print(f"\nNumber of chunks = {len(chunks)}\n")
	print(f"First chunk = {chunks[0].page_content}")

# test_chunk_docs_recursive()

# %%
# Create a Qdrant vector store

from langchain_core.embeddings import Embeddings
from langchain_qdrant import QdrantVectorStore
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

def create_qdrant_vector_store(location: str, 
							   collection_name: str, 
							   vector_size: int, 
							   embeddings: Embeddings, 
							   docs: list) -> QdrantVectorStore:

	# Initialize the Qdrant client
	qdrant_client = QdrantClient(location=location)

	# Create a collection in Qdrant
	qdrant_client.create_collection(collection_name=collection_name, 
								 vectors_config=VectorParams(size=vector_size, distance=Distance.COSINE))

	# Initialize QdrantVectorStore with the Qdrant client
	qdrant_vector_store = QdrantVectorStore(client=qdrant_client, 
										 collection_name=collection_name, embedding=embeddings)
	
	# Add the docs to the vector store
	qdrant_vector_store.add_documents(docs)
	
	return qdrant_vector_store

#####

def test_create_qdrant_vector_store():
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)
	
	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)
	
	print(vector_store.collection_name)

# test_create_qdrant_vector_store()

# %%
# Create a Qdrant retriever

from langchain_core.retrievers import BaseRetriever
from langchain_qdrant import QdrantVectorStore

def create_retriever_qdrant(vector_store: QdrantVectorStore) -> BaseRetriever:

	retriever = vector_store.as_retriever()

	return retriever

#####

def test_create_retriever_qdrant(text):
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)
	
	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)
	
	retriever = create_retriever_qdrant(vector_store)
	
	docs = retriever.invoke(text)	
	print(docs[0])

# test_create_retriever_qdrant("What is the annual revenue for Uber?")

# %%
# Create a prompt template

# https://python.langchain.com/v0.1/docs/modules/model_io/prompts/quick_start/#chatprompttemplate
# https://python.langchain.com/v0.2/api_reference/core/prompts/langchain_core.prompts.chat.ChatPromptTemplate.html

from langchain.prompts import ChatPromptTemplate

def create_chat_prompt_template(template: str = None) -> ChatPromptTemplate:
	
	if template is None:
		template = '''
		You are an expert assistant designed to help users analyze and answer questions about 10K annual reports filed by publicly traded companies. Users may ask about specific sections, financial metrics, trends, or comparisons across multiple reports. Your role is to provide accurate, concise, and relevant answers, referencing appropriate sections or data points where applicable.

		When responding, adhere to the following principles:

		Understand the Question: Identify whether the query is focused on a specific company, year, or metric, or if it spans multiple reports for comparison.
		Clarify Uncertainty: If a user's question is unclear, ask for clarification or additional context.
		Locate and Reference Information: Use relevant sections of the 10K report(s), such as MD&A, Financial Statements, Risk Factors, or Notes to Financial Statements, to back up your answers.
		Synthesize Data: Provide summaries or insights when the question involves comparing data or trends across multiple reports.
		Stay Objective: Avoid providing subjective opinions or interpretations beyond the factual content in the reports.
		Example User Queries and Expected Responses:

		"What was the revenue for Company X in 2022 and 2023?"

		Locate and report the revenue figures from the Income Statements of the respective 10K reports for 2022 and 2023.
		"What are the main risk factors for Company Y in its latest report?"

		Summarize the key risk factors from the most recent 10K report's "Risk Factors" section.
		"How did the operating income of Company Z change over the last three years?"

		Extract operating income figures from the 10K reports for the past three years and provide a brief comparison.
		"Compare the debt levels of Company A and Company B in 2023."

		Retrieve debt-related figures from the Balance Sheets or Notes to Financial Statements of both companies and summarize the comparison.
		"What trends are evident in Company W's R&D expenses over the last five years?"

		Summarize trends using data from the Income Statements or footnotes for R&D expenses across five consecutive 10K reports.
		Assumptions and Constraints:

		Only use inforomation from 10K reports provided in the context below. 
		For complex queries spanning multiple reports, provide a structured summary highlighting key comparisons or trends.
		If certain information is unavailable, state so clearly and suggest alternative approaches to obtain it.

		Now it's your turn!
		
		{question}

		{context}
		'''
	
	prompt = ChatPromptTemplate.from_template(template)

	return prompt

#####

def test_create_chat_prompt_template():
	prompt = create_chat_prompt_template()
	
	print(prompt)

# test_create_chat_prompt_template()

# %%
# Create a Langchain chain

from operator import itemgetter

from langchain_core.retrievers import BaseRetriever
from langchain_core.runnables import RunnablePassthrough, RunnableSerializable
from langchain_openai import ChatOpenAI

def create_chain (model: str, 
				  prompt_template: ChatPromptTemplate, 
				  retriever: BaseRetriever
				  ) -> RunnableSerializable:

	llm = ChatOpenAI(model=model)
		
	chain = (
		{"context": itemgetter("question") | retriever, "question": itemgetter("question")} 
		| RunnablePassthrough.assign(context=itemgetter("context")) 
		| {"response": prompt_template | llm, "context": itemgetter("context")}
		)

	return chain

#####

def test_create_chain_qdrant():
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)

	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)

	retriever = create_retriever_qdrant(vector_store)
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain("gpt-4o-mini", chat_prompt_template, retriever)
	
	result = chain.invoke({"question" : "What is the annual revenue of Uber?"})
	print(result)

# test_create_chain_qdrant()

# %%
# Generate answers from a chain using a list of questions

from typing import List, Tuple

from langchain_core.output_parsers import JsonOutputParser, StrOutputParser
from langchain_core.runnables import RunnableSerializable


def generate_answers_contexts(chain: RunnableSerializable, 
							  questions: list
							  ) -> Tuple[List, List]:
	
	answers = []
	contexts = []

	# Loop over the list of questions and call the chain to get the answer and context
	for question in questions:
		print(question)

		# Call the chain to get answers and contexts
		response = chain.invoke({"question" : question})
		print(response)

		# Capture the answer and context 
		answers.append(response["response"].content)
		contexts.append([context.page_content for context in response["context"]])

	return answers, contexts

#####

def test_generate_answers_contexts():
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)

	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)
	
	retriever = create_retriever_qdrant(vector_store)
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain("gpt-4o-mini", chat_prompt_template, retriever)
	
	questions = ["What is the annual revenue of Lyft?",
			  "What is the annual revenue of Uber?",
			  "Which company has a larger annual revenue - Lyft or Uber?"]	
	
	answers, contexts = generate_answers_contexts(chain=chain, questions=questions)
	
	print(f"Total number of answers = {len(answers)}")
	print(f"Total number of contexts = {len(contexts)}")

# test_generate_answers_contexts()

# %%
# Run a Ragas evaluation 

import time
from typing import Tuple

import pandas as pd
from pandas import DataFrame

from datasets import Dataset
from langchain_core.runnables import RunnableSerializable
from ragas import evaluate
from ragas.metrics import (
    answer_correctness,
    answer_relevancy,
    context_precision,
    context_recall,
    faithfulness,
)

def run_ragas_evaluation(chain: RunnableSerializable, 
						questions: list, 
						groundtruths: list, 
						eval_metrics: list = [answer_correctness, answer_relevancy, context_recall, context_precision, faithfulness]
						):
	
	answers = []
	contexts = []
	answers, contexts = generate_answers_contexts(chain=chain, questions=questions)

	# Create the input dataset 
	input_dataset = Dataset.from_dict({"question" : questions,       	# From the dataframe
										"answer" : answers,             # From the chain
										"contexts" : contexts,          # From the chain
										"ground_truth" : groundtruths   # From the dataframe
										})

	# Run the Ragas evaluation using the input dataset and eval metrics
	ragas_results = evaluate(input_dataset, eval_metrics)
	ragas_results_df = ragas_results.to_pandas()
	
	return ragas_results, ragas_results_df
	
#####

def test_run_ragas_evaluation():
	docs = process_directory("docs/", "**/*.pdf", PyMuPDFLoader, True)
	chunks = chunk_docs_recursive(docs=docs)
	
	embeddings = create_embeddings_openai()
	vector_store = create_qdrant_vector_store(":memory:", "holiday-test", 1536, embeddings, chunks)
	
	retriever = create_retriever_qdrant(vector_store)
	chat_prompt_template = create_chat_prompt_template()
	chain = create_chain("gpt-4o-mini", chat_prompt_template, retriever)
	
	testset_df = pd.read_csv("testsets/10k_test_testset.csv")	# This testset contains a small number of questions
	questions = testset_df["question"].values.tolist()
	questions = [str(question) for question in questions]
	groundtruths = testset_df["ground_truth"].values.tolist()
	groundtruths = [str(ground_truth) for ground_truth in groundtruths]  
	eval_metrics = [answer_correctness, answer_relevancy, context_precision, context_recall, faithfulness]
	ragas_results, ragas_results_df = run_ragas_evaluation(chain, questions, groundtruths, eval_metrics)
	
	timestr = time.strftime("%Y%m%d%H%M%S")
	ragas_results_df.to_csv(f"evaluations/10x_test_testset_evaluation_{timestr}.csv")
	
	print(ragas_results)

# test_run_ragas_evaluation()
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.39it/s]
# What challenges do jurisdictions pose to business operations in the context of regulatory compliance?
# {'response': AIMessage(content="Jurisdictions can pose significant challenges to business operations, particularly in the context of regulatory compliance. Based on the 10-K reports of Uber and Lyft, the following challenges are evident:\n\n1. **Operational Limitations**: Companies may face restrictions in providing or operating their products and services in certain jurisdictions. For instance, Uber's report mentions that they may be blocked or limited in certain areas, necessitating modifications to their business model to comply with local regulations (Uber 10-K, page 12).\n\n2. **Extensive Regulation**: Both companies are subject to extensive government regulation and oversight, particularly concerning payment and financial services. This regulation can complicate operations and may restrict growth opportunities or lead to increased costs associated with compliance (Uber 10-K, page 37; Lyft 10-K, page 42).\n\n3. **Diverse and Conflicting Regulations**: As businesses expand their offerings, they may encounter a patchwork of laws and regulations that differ significantly from one jurisdiction to another. This situation can create compliance challenges and may require businesses to adapt their operations to align with varying legal requirements (Lyft 10-K, page 42).\n\n4. **Potential for Increased Scrutiny**: Regulatory authorities may impose additional laws that may not have been anticipated when the original regulations were created, particularly given the rapid evolution of technology in the industry. This can lead to uncertainty and the need for constant monitoring and adaptation to remain compliant (Lyft 10-K, page 42).\n\nThese challenges underscore the importance of regulatory compliance for businesses operating across multiple jurisdictions, as they can significantly impact operational capabilities and financial performance.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 326, 'prompt_tokens': 1828, 'total_tokens': 2154, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-af5cb7ca-5d56-4b6d-9a87-23323702c315-0', usage_metadata={'input_tokens': 1828, 'output_tokens': 326, 'total_tokens': 2154}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 12, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'ce2be2c1f0a34f95abb9d47a7e190a75', '_collection_name': 'holiday-test'}, page_content='•\nWe may continue to be blocked from or limited in providing or operating our products and offerings in certain jurisdictions, and may be required to\nmodify our business model in those jurisdictions as a result.\n•\nOur business is subject to numerous legal and regulatory risks that could have an adverse impact on our business and future prospects.\n•\nOur business is subject to extensive government regulation and oversight relating to the provision of payment and financial services.\n•'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 35, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ;  ...
# What challenges does competition in technology pose for maintaining interoperability of platforms?
# {'response': AIMessage(content="The challenges posed by competition in technology regarding the maintenance of interoperability of platforms, as highlighted in the 10-K reports from Uber and Lyft, include several key factors:\n\n1. **Dependence on Third-Party Systems**: Both companies emphasize that their platforms must remain interoperable across various devices and operating systems (e.g., iOS and Android) as well as with third-party applications that they do not control. Any changes in these third-party systems can affect their services. For instance, Uber mentions that its platform's accessibility is contingent on these external systems, which may evolve in ways that are not aligned with their own platform capabilities.\n\n2. **Evolving Third-Party Services**: There is a constant evolution of third-party applications and services, which can lead to difficulties in ensuring compatibility. Uber notes that it may not be able to modify its platform quickly enough to maintain compatibility with the rapid changes made by third-party developers.\n\n3. **Competitor Actions**: Lyft points out that competitors or technology partners might take actions that disrupt the interoperability of their platform with others, or they may exert influence over the terms of interoperability, which can restrict their business operations and integration capabilities.\n\n4. **Technological Changes**: Both companies face challenges related to changes in internet and mobile device technologies, which can impact how their platforms interact with external systems. This includes potential defects or vulnerabilities in their technology or that of third-party providers.\n\n5. **Intellectual Property Issues**: The management of intellectual property rights can also pose challenges in ensuring interoperability, as disputes or limitations regarding technology usage can hinder the ability to integrate effectively with other platforms.\n\nIn summary, maintaining interoperability in a competitive technology landscape involves navigating the complexities of third-party dependencies, rapid technological changes, competitive disruptions, and intellectual property considerations. These challenges can adversely affect the business operations of companies like Uber and Lyft if not managed effectively.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 377, 'prompt_tokens': 1855, 'total_tokens': 2232, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0aa8d3e20b', 'finish_reason': 'stop', 'logprobs': None}, id='run-db41144b-458e-4eb8-b2fa-557259f56e6d-0', usage_metadata={'input_tokens': 1855, 'output_tokens': 377, 'total_tokens': 2232}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 30, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'f2b0246963c741db8182592e90572118', '_collection_name': 'holiday-test'}, page_content='be required to seek comparable software from other sources, which may be more expensive or inferior, or may not be available at all, any of which would adversely\naffect our business.\nOur business depends upon the interoperability of our platform across devices, operating systems, and third-party applications that we do not control.\nOne of the most important features of our platform is its broad int ...
# Evaluating:   0%|          | 0/10 [00:00<?, ?it/s]
# {'answer_correctness': 0.5282, 'answer_relevancy': 0.9044, 'context_precision': 1.0000, 'context_recall': 1.0000, 'faithfulness': 0.8864}

# %% [markdown]
# # Test 1 - OpenAI and Qdrant

# %%
# Build chain using OpenAI and Qdrant

embeddings = create_embeddings_openai()
docs = process_directory('docs/', '**/*.pdf', PyMuPDFLoader, True)
chunks = chunk_docs_recursive(docs=docs)
print(f'\nNumber of chunks = {len(chunks)}\n')
vector_store = create_qdrant_vector_store(':memory:', 'holiday-test', 1536, embeddings, chunks)
retriever = create_retriever_qdrant(vector_store)
chat_prompt_template = create_chat_prompt_template()
chain = create_chain('gpt-4o', chat_prompt_template, retriever)
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.34it/s]
# Number of chunks = 3398

# %%
# Test the chain with a few questions 

questions = ["What is the annual revenue of Uber?",
"What is the annual revenue of Lyft?",
"How does Uber's revenue compare to Lyft's revenue?",]

for question in questions:
	print(question)
	result = chain.invoke({"question" : question})
	print(result)
	print(result["response"].content)
	print("\n*****")
# Out:
# What is the annual revenue of Uber?
# {'response': AIMessage(content='The annual revenue of Uber for the year 2023 is $37,281 million. This information is extracted from the Consolidated Statements of Operations in their 10-K report.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 37, 'prompt_tokens': 2076, 'total_tokens': 2113, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-cb0acc12-fbf5-4358-8b3f-0ac8a73c9bf0-0', usage_metadata={'input_tokens': 2076, 'output_tokens': 37, 'total_tokens': 2113}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 76, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'd2208c74edd14d43bc767408b4513016', '_collection_name': 'holiday-test'}, page_content='UBER TECHNOLOGIES, INC.\nCONSOLIDATED STATEMENTS OF OPERATIONS\n(In millions, except share amounts which are reflected in thousands, and per share amounts)\nYear Ended December 31,\n2021\n2022\n2023\nRevenue\n$\n17,455\xa0\n$\n31,877\xa0\n$\n37,281\xa0\nCosts and expenses\nCost of revenue, exclusive of depreciation and amortization shown separately below\n9,351\xa0\n19,659\xa0\n22,457\xa0\nOperations and support\n1,877\xa0\n2,413\xa0\n2,689\xa0\nSales and marketing\n4,789\xa0\n4,756\xa0\n4,356\xa0\nResearch and development\n2,054\xa0\n2,798\xa0\n3,164'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 95, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'f068d12d9e23479eb9358f0154d08937', '_collection_name': 'holiday-test'}, page_content='$\n6,953\xa0\n$\n14,029\xa0\n$\n19,832\xa0\nDelivery revenue \n8,362\xa0\n10,901\xa0\n12,204\xa0\nFreight revenue\n2,132\xa0\n6,947\xa0\n5,245\xa0\nAll Other revenue\n8\xa0\n—\xa0\n—\xa0\nTotal revenue\n$\n17,455\xa0\n$\n31,877\xa0\n$\n37,281\xa0\n We offer subscription memberships to end-users including Uber One, Uber Pass, Rides Pass, and Eats Pass (“Subscription”). We recognize Subscription fees\nratably over the life of the pass. We allocate Subscription fees earned to Mobility and Delivery revenue on a proportional basis, based on usage for each offering'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 51, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'ba7993ed473d43878b33dc85025b015c', '_collection_name': 'holiday-test'}, page_content='in Mobility and Delivery revenue w ...
# The annual revenue of Uber for the year 2023 is $37,281 million. This information is extracted from the Consolidated Statements of Operations in their 10-K report.
#
# *****
# What is the annual revenue of Lyft?
# {'response': AIMessage(content='The annual revenue for Lyft for the years 2023, 2022, and 2021 is as follows:\n\n- 2023: $4,403,589,000\n- 2022: $4,095,135,000\n- 2021: $3,208,323,000\n\nThese figures can be found in the Consolidated Statements of Operations within the 10K report.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 86, 'prompt_tokens': 1984, 'total_tokens': 2070, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-85445135-55f8-4a61-b56e-1654c17b8cc4-0', usage_metadata={'input_tokens': 1984, 'output_tokens': 86, 'total_tokens': 2070}), 'context': [Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 4, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'fc091f61d9ed4f138926d1103b4a0cff', '_collection_name': 'holiday-test'}, page_content='revenue. We also generate revenue from riders renting Light Vehicles, drivers renting vehicles through Express Drive and by making our ridesharing\nmarketplace available to organizations through our Lyft Business offerings, such as our Concierge and Lyft Pass programs. In 2021, we began generating\nrevenues from licensing and data access agreements. In 2022, we began generating revenues from the sale of bikes and bike station software and hardware'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 83, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'd09c41c833e241e0a9a6b5bea30078c7', '_collection_name': 'holiday-test'}, page_content='$\n4,403,589\xa0 $\n4,095,135\xa0\n$\n3,208,323\xa0\nRevenue from Contracts with Customers (ASC 606)\nThe Company recognizes revenue for its rideshare marketplace in accordance with ASC 606. The Company generates revenue from service fees and\ncommissions (collectively, “fees”) paid by drivers for use of the Lyft Platform and related activities to connect drivers with riders to facilitate and successfully'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 76, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '58a75322d74f409fa9f073cd4481afd7', '_collection_name': 'holiday-test'}, page_content='Lyft, Inc.\nConsolidated Statements of Operations\n(in thousands, except for per share data)\nYear Ended December 31,\n2023\n2022\n2021\nRevenue\n$\n4,403,589\xa0\n$\n4,095,135\xa0\n$\n3,208,323\xa0\nCosts and ex ...
# The annual revenue for Lyft for the years 2023, 2022, and 2021 is as follows:
#
# - 2023: $4,403,589,000
# - 2022: $4,095,135,000
# - 2021: $3,208,323,000
#
# These figures can be found in the Consolidated Statements of Operations within the 10K report.
#
# *****
# How does Uber's revenue compare to Lyft's revenue?
# {'response': AIMessage(content="To compare the revenue of Uber and Lyft for the year ending December 31, 2023, I will extract the relevant figures from their respective 10K reports.\n\n**Uber's Revenue:**\nBased on the document provided, Uber's total revenue for the year ending December 31, 2023, is $37,281 million.\n\n**Lyft's Revenue:**\nFrom the information given, Lyft's total revenue for the year ending December 31, 2023, is $4,403,589 thousand, which converts to $4,403.589 million.\n\n**Comparison:**\n- Uber's total revenue for 2023 was significantly higher than Lyft's, with Uber generating approximately $37,281 million compared to Lyft's $4,403.589 million.\n  \nThis showcases a substantial difference in revenue between the two companies, with Uber having a much larger revenue base in 2023.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 185, 'prompt_tokens': 1947, 'total_tokens': 2132, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-570dac3d-b6a1-44ab-8847-875e0c7fd676-0', usage_metadata={'input_tokens': 1947, 'output_tokens': 185, 'total_tokens': 2132}), 'context': [Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 4, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'fc091f61d9ed4f138926d1103b4a0cff', '_collection_name': 'holiday-test'}, page_content='revenue. We also generate revenue from riders renting Light Vehicles, drivers renting vehicles through Express Drive and by making our ridesharing\nmarketplace available to organizations through our Lyft Business offerings, such as our Concierge and Lyft Pass programs. In 2021, we began generating\nrevenues from licensing and data access agreements. In 2022, we began generating revenues from the sale of bikes and bike station software and hardware'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 83, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'd09c41c833e241e0a9a6b5bea30078c7', '_collection_name': 'holiday-test'}, page_content='$\n4,403,589\xa0 $\n4,095,135\xa0\n$\n3,208,323\xa0\nRevenue from Contracts with Customers (ASC 606)\nThe Company recognizes revenue for its rideshare marketplace in accordance with ASC 606. The Company generates revenue from service fees and\ncommissions (collectively, “fees”) paid by drivers for use of the Lyft Platform and related activities to connect drivers with riders to facilitate and successfully'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 95, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator':  ...
# To compare the revenue of Uber and Lyft for the year ending December 31, 2023, I will extract the relevant figures from their respective 10K reports.
#
# **Uber's Revenue:**
# Based on the document provided, Uber's total revenue for the year ending December 31, 2023, is $37,281 million.
#
# **Lyft's Revenue:**
# From the information given, Lyft's total revenue for the year ending December 31, 2023, is $4,403,589 thousand, which converts to $4,403.589 million.
#
# **Comparison:**
# - Uber's total revenue for 2023 was significantly higher than Lyft's, with Uber generating approximately $37,281 million compared to Lyft's $4,403.589 million.
#
# This showcases a substantial difference in revenue between the two companies, with Uber having a much larger revenue base in 2023.
#
# *****

# %%
# Evaluate the chain using Ragas

import time

import pandas as pd

# Run the Ragas evaluation and show the results
# Get the questions and groundtruths from the dataframe
testset_df = pd.read_csv("testsets/10k_testset.csv")

questions = testset_df["question"].values.tolist()
questions = [str(question) for question in questions]

groundtruths = testset_df["ground_truth"].values.tolist()
groundtruths = [str(ground_truth) for ground_truth in groundtruths]  

# Specify the eval metrics
eval_metrics = [answer_correctness, answer_relevancy, context_precision, context_recall, faithfulness]

# Run the Ragas evaluation and show the results
ragas_results, ragas_results_df = run_ragas_evaluation(chain, questions, groundtruths, eval_metrics)

# Write the results to disk
timestr = time.strftime("%Y%m%d%H%M%S")
ragas_results_df.to_csv(f"evaluations/10x_test1_testset_evaluation_{timestr}.csv")

# Show the resutls
print(ragas_results)
# Out:
# What challenges do jurisdictions pose to business operations in the context of regulatory compliance?
# {'response': AIMessage(content="In the context of regulatory compliance, jurisdictions pose several challenges to business operations, as highlighted in the provided excerpts from Uber and Lyft's 10K reports. Here are the key points:\n\n1. **Jurisdictional Restrictions**: Companies like Uber may face blocking or limitations on providing or operating their products in certain jurisdictions. This may require them to modify their business models to comply with local regulations (Uber, Page 12 and 35).\n\n2. **Legal and Regulatory Risks**: Businesses are subject to numerous legal and regulatory risks that could adversely impact their operations and future prospects. These risks can vary significantly across different jurisdictions and may involve compliance with extensive government regulation and oversight, particularly in sectors like payment and financial services (Uber, Page 12 and 37).\n\n3. **Varying Regulations**: As companies expand their offerings and user base, they may become subject to additional laws and regulations, which can differ or even conflict from one jurisdiction to another. This is particularly challenging as many existing laws were established before the advent of new industries and technologies, leaving them ill-equipped to address the unique issues faced by modern companies (Lyft, Page 42).\n\nThese excerpts highlight that navigating regulatory compliance across multiple jurisdictions requires businesses to be adaptable and often involves significant legal and operational adjustments to meet local legal requirements.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 263, 'prompt_tokens': 1830, 'total_tokens': 2093, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-486e2dc5-f731-42e7-9e3f-0b8efb058e1a-0', usage_metadata={'input_tokens': 1830, 'output_tokens': 263, 'total_tokens': 2093}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 12, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '77515dd7360a4c8b815544bcf18667f2', '_collection_name': 'holiday-test'}, page_content='•\nWe may continue to be blocked from or limited in providing or operating our products and offerings in certain jurisdictions, and may be required to\nmodify our business model in those jurisdictions as a result.\n•\nOur business is subject to numerous legal and regulatory risks that could have an adverse impact on our business and future prospects.\n•\nOur business is subject to extensive government regulation and oversight relating to the provision of payment and financial services.\n•'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 35, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '7f9e91f669384c5bbfc03623b6cf767e', '_collection_name': 'ho ...
# What challenges does competition in technology pose for maintaining interoperability of platforms?
# {'response': AIMessage(content="Competition in technology poses several challenges for maintaining the interoperability of platforms, as identified in the 10K reports:\n\n1. **Dependence on Third-Party Systems**: Companies like Uber and Lyft rely on the accessibility and interoperability of their platforms across various devices and third-party operating systems, such as iOS and Android. Since these systems are not under their control, any changes or incompatibilities introduced by third parties can disrupt their platform's functionality (Uber document, page 30; Lyft document, page 34).\n\n2. **Evolving Third-Party Applications**: Third-party applications and services are constantly evolving. This dynamic environment means that companies may struggle to modify their platforms quickly enough to ensure continued compatibility following these changes (Uber document, page 30; Lyft document, page 34).\n\n3. **Competitive Actions**: Competitors or technology partners may take actions that intentionally disrupt the interoperability of a company's platform with their own products or services. This can include exerting strong business influence over the terms of interoperability or compatibility (Lyft document, page 34).\n\n4. **Technological Changes**: Changes in the internet, mobile device accessibility, operating systems, and application marketplaces can affect platform interoperability. Companies must adapt to these changes to maintain seamless integration across different platforms and devices (Lyft document, page 13).\n\nThese factors highlight the challenges companies face in maintaining interoperability in a competitive and rapidly changing technological landscape.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 285, 'prompt_tokens': 1856, 'total_tokens': 2141, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-be4cf573-9c76-4718-8bf8-0d2d1df90371-0', usage_metadata={'input_tokens': 1856, 'output_tokens': 285, 'total_tokens': 2141}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 30, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'f7485f20d0c347ddb667f51e84ef7761', '_collection_name': 'holiday-test'}, page_content='be required to seek comparable software from other sources, which may be more expensive or inferior, or may not be available at all, any of which would adversely\naffect our business.\nOur business depends upon the interoperability of our platform across devices, operating systems, and third-party applications that we do not control.\nOne of the most important features of our platform is its broad interoperability with a range of devices, operating systems, and third-party applications. Our'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 30, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'0 ...
# What factors could adversely impact the financial results of the company?
# {'response': AIMessage(content="The financial results of the company could be adversely impacted by several factors, as highlighted in its 10K report. Here are the main factors:\n\n1. **General Economic Factors**: The company acknowledges that deteriorating macroeconomic conditions, such as slower growth, recession, inflation, increases in interest rates, increases in fuel and vehicle costs, and changes in the labor market, could materially and adversely affect its business and financial results (source: page 14).\n\n2. **Regulatory and Legal Factors**: The company operates under a wide range of laws and regulations, many of which are evolving. Failure to comply with these laws and regulations could harm the company's business, financial condition, and results of operations (source: page 36).\n\n3. **Competitive Factors**: The ability to effectively compete depends on many factors, both within and beyond the company's control. Inability to compete successfully could adversely affect the business, financial condition, and operational results (source: page 17).\n\nThese factors illustrate the complexity and potential volatility in the company's financial performance.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 212, 'prompt_tokens': 1817, 'total_tokens': 2029, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-7393f1b4-c8dd-48ab-b944-7786aceb8e06-0', usage_metadata={'input_tokens': 1817, 'output_tokens': 212, 'total_tokens': 2029}), 'context': [Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 14, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'ef67af1ef2ad4f159b05284435818e79', '_collection_name': 'holiday-test'}, page_content='Risks Related to General Economic Factors\nA deterioration of general macroeconomic conditions could materially and adversely affect our business and financial results.\nOur business and results of operations are subject to global economic conditions. Deteriorating macroeconomic conditions, including slower growth or\nrecession, inflation and related increases in interest rates, increases to fuel and other energy costs or vehicle costs, changes in the labor market or decreases in'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 36, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'da5e05a45b9b4f2692425ef9bcb0cfd0', '_collection_name': 'holiday-test'}, page_content='adverse effect on our reputation, brand, business, financial condition and results of operations.\nRisks Related to Regulatory and Legal Factors\nOur business is subject to a wide range of laws and regulations, many of which are evolving, and failure to comply with such laws and regulations could\nharm our business, financial condition and results of operation ...
# What role did the Deputy Chief Technology Officer play in the context of cybersecurity at a Fortune 500 company?
# {'response': AIMessage(content="The documents provided do not explicitly detail the specific role of the Deputy Chief Technology Officer (DCTO) in the context of cybersecurity at a Fortune 500 company. However, it is mentioned that the individual had engineering and/or cybersecurity experience, including previously serving as a CISO and Deputy Chief Technology Officer at such a company. This suggests that the DCTO likely had responsibilities related to cybersecurity strategy, risk management, and possibly oversight of cybersecurity operations, given their role as a former Chief Information Security Officer (CISO). \n\nFor more specific details about the DCTO's role in cybersecurity, additional context or documents would be necessary.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 128, 'prompt_tokens': 1862, 'total_tokens': 1990, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-df7d3538-8926-4794-a4c8-157b042ebd44-0', usage_metadata={'input_tokens': 1862, 'output_tokens': 128, 'total_tokens': 1990}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 46, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '5b4b83fb889a4f2687c94e06e74cd9c9', '_collection_name': 'holiday-test'}, page_content='engineering and/or cybersecurity experience, including previously as CISO and Deputy Chief Technology Officer at a Fortune 500 company.\nThe Cybersecurity Program is also supported by Uber’s Chief Privacy Officer and Associate General Counsel, Privacy & Cybersecurity (“CPO”), who has\nserved in that role since August 2018. The CPO has three decades of experience as a legal advisor to\n45'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 47, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'f02709163a6b4761977416e34c42a3c0', '_collection_name': 'holiday-test'}, page_content='multinational corporations, including serving as Chief Privacy & Security Counsel for a Fortune 100 technology company prior to her role at Uber.\nThe Cybersecurity Program is supported by other members of Uber’s senior management team as well, including the Chief Legal Officer, Head of Platform\nEngineering, and EU Data Protection Officer. Uber’s Board of Directors oversees the Cybersecurity Program through regular updates.'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 46, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:202 ...
# What benefits do members receive from the Uber One membership program?
# {'response': AIMessage(content="Uber One membership program provides its members with several benefits. According to the information available from the 10K report, Uber One members have access to:\n\n1. **Discounts**: Members receive price reductions on various services offered by Uber.\n2. **Special Pricing**: Members enjoy exclusive pricing options.\n3. **Priority Service**: Members receive prioritized service, ensuring quicker and more reliable access to Uber's offerings.\n4. **Exclusive Perks**: Members get unique benefits and perks across Uber's rides, delivery, and grocery services.\n\nThese benefits are designed to enhance the user experience by making it more seamless and rewarding across Uber's suite of products.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 132, 'prompt_tokens': 1836, 'total_tokens': 1968, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-5ae5aa20-e5b5-4f39-83c7-975eec9780be-0', usage_metadata={'input_tokens': 1836, 'output_tokens': 132, 'total_tokens': 1968}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 6, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '023a5f37fea8410d9c1bd04e5351cda0', '_collection_name': 'holiday-test'}, page_content='which combines our multiple offerings into a single app and is designed to remove friction for our consumers. During November 2021, we launched Uber One in\nthe United States as our single cross-platform membership program that brings together the best of Uber. Uber One members have access to discounts, special\npricing, priority service, and exclusive perks across our rides, delivery and grocery offerings. Since then, we have expanded Uber One to approximately 25'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 6, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '15378aa5cc0343b4a9470126bfb3974f', '_collection_name': 'holiday-test'}, page_content='countries. Our Eats Pass membership program continues to remain available in select cities as a subscription offering. Our membership programs are designed to\nmake utilizing our suite of products a seamless and rewarding experience for our consumers. We exited 2023 with 19 million members for our Uber One, Eats Pass\nand Rides Pass membership programs.'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 9, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:2024021516324 ...
# What challenges do ridesharing companies face in terms of government regulation?
# {'response': AIMessage(content='Ridesharing companies like Lyft and Uber face several challenges related to government regulation, as outlined in their 10K reports. Here are the key points:\n\n1. **Regulatory Environment**: Both Lyft and Uber operate in a complex regulatory environment where federal, state, and local governments create laws specific to Transportation Network Companies (TNCs). These laws can vary significantly by jurisdiction, affecting how ridesharing companies operate in different areas.\n\n2. **Driver Earnings Regulations**: Some jurisdictions have imposed limitations or adopted rules governing minimum driver earnings. This can affect the financial model of ridesharing companies, as they may need to adjust their pricing or compensation strategies to comply with these regulations.\n\n3. **Independent Contractor Status**: Ridesharing companies often classify drivers as independent contractors, which has been a focal point of regulatory scrutiny. Changes in laws regarding the classification of workers could impact the operational and cost structures of these companies.\n\n4. **Environmental Regulations**: Given that a significant portion of their business involves vehicles running on fossil fuels, ridesharing companies may face regulatory challenges or governmental actions aimed at reducing emissions or encouraging the use of electric vehicles.\n\n5. **International Regulations**: As these companies expand internationally, they may encounter similar regulatory issues from foreign regulators, which could include restrictions on operations or additional compliance requirements.\n\n6. **Proactive Engagement**: Both companies engage with regulatory bodies to influence legislation and protect their business interests. This involves lobbying and challenging adverse laws and regulations.\n\nOverall, the regulatory landscape presents both operational and strategic challenges for ridesharing companies, requiring them to navigate and adapt to a dynamic and varied regulatory environment across different jurisdictions.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 335, 'prompt_tokens': 1860, 'total_tokens': 2195, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-749329fa-73cf-45c3-9053-c6bad810dee3-0', usage_metadata={'input_tokens': 1860, 'output_tokens': 335, 'total_tokens': 2195}), 'context': [Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 37, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '74057eafac334652b11c909f81060460', '_collection_name': 'holiday-test'}, page_content='relationships with drivers or otherwise inhibited the growth of our ridesharing marketplace. We have been proactively working with federal, state and local\ngovernments and regulatory bodies to ensure that our ridesharing marketplace and other offerings are available broadly in the United States and Canada. In part\ndue to our efforts, a large majority of U.S. states have adopted laws related to TNCs to address the unique issues of the ridesharing industry. New laws and'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 37, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': ' ...
# What challenges could an 'investment company' face in operations and financial reporting?
# {'response': AIMessage(content='An \'investment company\' may face several challenges in operations and financial reporting, as inferred from the context provided in the 10K reports:\n\n1. **Regulatory Compliance**: If a company is deemed an "investment company" under the Investment Company Act, it would be subject to specific substantive legal requirements. These regulations can dictate how the company is permitted to conduct its business, potentially restricting its operations and strategic flexibility (page 43).\n\n2. **Financial Reporting Complexity**: Operating as a public company inherently involves complex financial reporting requirements. For an investment company, this complexity may be heightened due to the need to accurately measure and report on a diverse portfolio of investments, which can vary significantly in terms of valuation methods and financial characteristics (pages 18, 46).\n\n3. **Internal Controls**: Maintaining effective internal control over financial reporting is crucial. A failure in these controls could lead to a loss of investor confidence in the accuracy of financial reports, potentially harming the market price of the company\'s stock (page 46).\n\n4. **Operational Costs**: The costs associated with operating as a public company, including compliance and reporting costs, can be significant. For an investment company, these costs may include additional expenses related to managing and reporting on investment activities (page 13).\n\nOverall, these challenges highlight the importance of robust internal controls, compliance with regulatory requirements, and effective management of financial reporting processes to ensure operational efficiency and maintain investor confidence.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 290, 'prompt_tokens': 1814, 'total_tokens': 2104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-a1003cdc-c568-4774-97a5-47b449a74704-0', usage_metadata={'input_tokens': 1814, 'output_tokens': 290, 'total_tokens': 2104}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 18, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'a93b3e1cc1d541248caf9bd42ff1293a', '_collection_name': 'holiday-test'}, page_content='over financial reporting, we will be required to commit substantial financial, operational, and technical resources. In particular, we will need to improve our\ntransaction processing and reporting, operational, and financial systems, procedures, and controls. For example, due to our significant growth, especially with\nrespect to our high-growth emerging offerings like Delivery and Freight, we face challenges in timely and appropriately designing controls in response to evolving'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 43, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'mo ...
# What role do unobservable inputs play in fair value assessments vs. observable market inputs?
# {'response': AIMessage(content="In fair value assessments, observable market inputs and unobservable inputs play distinct roles. Observable market inputs, classified as Level 1 inputs, are those that reflect quoted prices (unadjusted) for identical assets or liabilities in active markets. These inputs are directly available and provide reliable data for fair value measurement, resulting in high confidence in the valuation.\n\nUnobservable inputs, on the other hand, are classified as Level 3 inputs. These inputs are used when there is little or no market data available for an asset or liability. As such, they rely on the company's own assumptions and are incorporated into valuation techniques to determine fair value. These assumptions must be consistent with those that market participants would use. Because of their subjective nature, unobservable inputs can lead to more variability in fair value estimates.\n\nFor instance, an increase or decrease in unobservable inputs, such as security prices in significant financing transactions, short-term revenue projections, time to liquidity, and volatility, can materially affect the estimated fair value of an asset or liability. Therefore, while unobservable inputs offer flexibility in valuation when market data is scarce, they also introduce additional uncertainty compared to the more consistent and reliable observable market inputs.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 237, 'prompt_tokens': 1813, 'total_tokens': 2050, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-86bf6320-e50b-435c-84bc-4c0cd8778e0d-0', usage_metadata={'input_tokens': 1813, 'output_tokens': 237, 'total_tokens': 2050}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 97, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'def5dca4b43241278150f434b1f0e7a5', '_collection_name': 'holiday-test'}, page_content='An increase or decrease in any of the unobservable inputs in isolation, such as the security price in a significant financing transaction of the investee, could\nresult in a material increase or decrease in our estimate of fair value. Other unobservable inputs, including short-term revenue projections, time to liquidity, and\nvolatility are less sensitive to the valuation in the respective reporting\n(2) \n(3) \n(1)\n(1) \n96'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 87, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '093d63e2210745d9aa4e590661604058', '_collection_name': 'holiday-test'}, page_content='Level\xa03\xa0\xa0\xa0\xa0Unobservable inputs in which there is little or no market data and that are significant to the fair value of the assets or liabilities.\n86'), Document(metadata={'source': 'docs ...
# How does ASC 842 affect revenue and cost reporting?
# {'response': AIMessage(content="ASC 842, which addresses lease accounting, affects the reporting of revenue and costs for companies that have leases as part of their operations. Here's how it impacts these areas based on the context provided:\n\n1. **Revenue Reporting:**\n   - ASC 842 impacts revenue recognition by requiring companies to report rental revenue separately from revenue from contracts with customers. For instance, in Lyft's 10K report, rental revenue is reported under ASC 842, while revenue from contracts with customers is reported under ASC 606. This distinction helps in clearly identifying the nature of revenues derived from leasing activities.\n   - Companies may also choose not to separate non-lease components from lease components, treating them as a single lease, which can simplify revenue reporting.\n\n2. **Cost Reporting:**\n   - The costs associated with leases under ASC 842 can affect cost of revenue. For instance, any lease-related costs would be accounted for according to the standards set out in ASC 842.\n   - Incentive programs related to leasing, if they do not result in distinct goods or services or if their fair value cannot be reasonably estimated, may be recorded as a reduction to revenue, which indirectly affects the cost reporting.\n\nOverall, ASC 842 requires a more detailed and clear presentation of lease-related revenue and costs, ensuring that users of financial statements can distinguish between different types of revenues and associated costs.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 275, 'prompt_tokens': 1931, 'total_tokens': 2206, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-67b16f56-9de0-4cd6-912d-ed351cae5341-0', usage_metadata={'input_tokens': 1931, 'output_tokens': 275, 'total_tokens': 2206}), 'context': [Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 83, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'ba9cb4468bf04108842671cf69b2fc07', '_collection_name': 'holiday-test'}, page_content="its network of Light Vehicles, which is recognized in accordance with Accounting Standards Codification Topic 842 (“ASC 842”).\nThe table below presents the Company's revenues as included on the consolidated statements of operations (in thousands):\nYear Ended December 31,\n2023\n2022\n2021\nRevenue from contracts with customers (ASC 606)\n$\n4,116,216\xa0 $\n3,811,993\xa0\n$\n2,957,979\xa0\nRental revenue (ASC 842)\n287,373\xa0\n283,142\xa0\n250,344\xa0\nTotal revenue\n$\n4,403,589\xa0 $\n4,095,135\xa0\n$\n3,208,323"), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 85, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'aebae3e3886f4b32b8eaaafbd02d8f64', '_collection_name': 'holiday-test'}, page_content=' ...
# What IP risks come from joint dev. agreements and their effect on competition?
# {'response': AIMessage(content="Joint development agreements can pose several intellectual property (IP) risks that may affect a company's competitive position. Based on the information provided from the 10K reports of companies like Lyft and Uber, here are the key risks and their potential impacts on competition:\n\n1. **Joint Ownership of IP**: When companies enter into strategic partnerships or joint development agreements, the resulting intellectual property may be jointly owned. This joint ownership can complicate the protection, maintenance, and enforcement of IP rights. For example, decisions regarding the commercialization or defense of the IP might require consensus between partners, potentially leading to delays or disagreements that can weaken the competitive edge.\n\n2. **Transfer or Licensing of IP**: Such agreements often involve the transfer or licensing of intellectual property to the counterparty. This can limit a company's control over its IP, reducing its ability to capitalize on the IP independently and potentially diminishing its competitive advantage if the partner also gains significant rights to use or exploit the IP.\n\n3. **Impact on Market Value**: Joint development partners may register, maintain, enforce, or license the IP in ways that may not align with the company's strategic interests. This misalignment can devalue the jointly-owned intellectual property, thereby affecting the company's market position.\n\n4. **Requirement for Agreement or Payment**: Companies might be required to obtain agreement from or make payments to their joint development partners to protect or commercialize the IP. This requirement can introduce additional costs and operational complexities, further impacting competitive positioning.\n\n5. **Adverse Effects on Business**: If a company is unable to adequately protect its IP due to the constraints of joint development agreements, this can harm its brand and reputation. It may lead to a devaluation of its products and offerings, impairing the company’s ability to compete effectively in the market.\n\nOverall, joint development agreements can introduce significant IP risks that may hinder a company's ability to compete, affecting its business, financial condition, and operating results.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 389, 'prompt_tokens': 1795, 'total_tokens': 2184, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-33a42ffc-df85-4e31-b0ca-0616faa2a537-0', usage_metadata={'input_tokens': 1795, 'output_tokens': 389, 'total_tokens': 2184}), 'context': [Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 39, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'd3e721258dc3431792be1a7f29918f76', '_collection_name': 'holiday-test'}, page_content='initiating enforcement of such intellectual property rights, and may allow such joint development partners to register, maintain, enforce or license such\nintellectual property rights in a manner that may affect the value of the jointly-owned intellectual property or our ability to compete in the market.\n40'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 39, 'total_pages': 143, 'format':  ...
# What links driver contracts, revenue recognition, and the Lyft Platform?
# {'response': AIMessage(content='The connection between driver contracts, revenue recognition, and the Lyft Platform is primarily based on the structure of Lyft\'s business model and how it generates revenue. Here\'s how these elements are linked:\n\n1. **Driver Contracts**: Drivers who wish to use the Lyft Platform must enter into terms of service ("ToS") with Lyft. This agreement allows them to access the Lyft Driver App and participate in the ridesharing marketplace. The ToS outlines the conditions under which drivers operate on the platform and the financial arrangements, including fees and commissions.\n\n2. **Revenue Recognition**: Lyft\'s revenue is primarily generated from its ridesharing marketplace, where it connects drivers and riders. The revenue is recognized in accordance with ASC 606, which is a standard that outlines how companies should recognize revenue from contracts with customers. Lyft earns revenue through service fees and commissions paid by drivers for using the Lyft Platform, as well as from vehicle rental fees charged to drivers who rent vehicles.\n\n3. **Lyft Platform**: The Lyft Platform is the core of Lyft\'s operations, providing a multimodal transportation network. It offers access to various transportation options through mobile-based applications. The platform facilitates the connection between drivers and riders, enabling Lyft to generate revenue through the described fees and commissions.\n\nIn summary, driver contracts establish the terms for using the Lyft Platform, which in turn facilitates ridesharing services. Revenue is recognized based on the transactions that occur on the platform, following the guidelines of ASC 606.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 297, 'prompt_tokens': 1835, 'total_tokens': 2132, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-c1468f50-9735-4824-98e2-fd1dfe8ca029-0', usage_metadata={'input_tokens': 1835, 'output_tokens': 297, 'total_tokens': 2132}), 'context': [Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 57, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '93c2786905a9417f82f512b0b6635b83', '_collection_name': 'holiday-test'}, page_content='Revenues from Contracts with Customers (ASC 606)\nWe generate substantially all our revenue from our ridesharing marketplace that connects drivers and riders. We recognize revenue from fees paid by\ndrivers for use of our Lyft Platform offerings in accordance with ASC 606 as described in Note 2 of the notes to our consolidated financial statements. Drivers\nenter into terms of service (“ToS”) with us in order to use our Lyft Driver App.'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 83, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC ...
# What regulatory challenges could come with global product launches?
# ...
# What reputational risks come from arbitration clauses under legal review?
# {'response': AIMessage(content="The reputational risks associated with arbitration clauses under legal review, as highlighted in the provided documents, primarily involve public scrutiny and potential negative perceptions. Both Uber and Lyft acknowledge that the use of arbitration provisions may subject them to certain reputational and brand risks due to increasing public scrutiny. To mitigate these risks, both companies have considered limiting their use of arbitration clauses, or they may be required to do so by legal or regulatory proceedings. This limitation could lead to increased litigation costs and exposure to costly lawsuits, impacting their business and financial condition. \n\nIn summary, the reputational risks stem from public scrutiny of arbitration clauses, which can influence public perception of a company's fairness and transparency, potentially affecting the company's brand and customer trust.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 144, 'prompt_tokens': 1830, 'total_tokens': 1974, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-b38f7d65-d30c-4b03-b9a7-4483f520dbaf-0', usage_metadata={'input_tokens': 1830, 'output_tokens': 144, 'total_tokens': 1974}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 40, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'c4fd947d5c20476c8fdb20bb1534ea74', '_collection_name': 'holiday-test'}, page_content='more costly for us, or the volume of arbitrations may increase and become burdensome. Further, the use of arbitration provisions may subject us to certain risks to\nour reputation and brand, as these provisions have been the subject of increasing public scrutiny. To minimize these risks, we have in the past and may in the future\n39'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 41, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '7f99c04ab5a74958bf7cb22e7e7d66e2', '_collection_name': 'holiday-test'}, page_content='the use of arbitration provisions may subject us to certain risks to our reputation and brand, as these provisions have been the subject of increasing public\nscrutiny. In order to minimize these risks to our reputation and brand, we have in the past and may continue to limit our use of arbitration provisions or be\nrequired to do so in a legal or regulatory proceeding, either of which could increase our litigation costs and exposure. For example, effective May 2018, we'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 41, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 20 ...
# What perks do Uber One members get for rides and delivery?
# {'response': AIMessage(content="Uber One members receive several perks related to rides and delivery services as detailed in Uber's 10K report. Members have access to:\n\n- **Discounts**: Special pricing and discounts on various services.\n- **Priority Service**: Enhanced service priority across Uber's platforms.\n- **Exclusive Perks**: Unique benefits exclusive to Uber One members.\n  \nThese perks apply to Uber's rides, delivery, and grocery offerings, creating a more seamless and rewarding experience for consumers.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 1941, 'total_tokens': 2037, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-3f438e43-40cf-4cea-9cff-a9b0c1acb99e-0', usage_metadata={'input_tokens': 1941, 'output_tokens': 96, 'total_tokens': 2037}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 6, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '023a5f37fea8410d9c1bd04e5351cda0', '_collection_name': 'holiday-test'}, page_content='which combines our multiple offerings into a single app and is designed to remove friction for our consumers. During November 2021, we launched Uber One in\nthe United States as our single cross-platform membership program that brings together the best of Uber. Uber One members have access to discounts, special\npricing, priority service, and exclusive perks across our rides, delivery and grocery offerings. Since then, we have expanded Uber One to approximately 25'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 6, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '15378aa5cc0343b4a9470126bfb3974f', '_collection_name': 'holiday-test'}, page_content='countries. Our Eats Pass membership program continues to remain available in select cities as a subscription offering. Our membership programs are designed to\nmake utilizing our suite of products a seamless and rewarding experience for our consumers. We exited 2023 with 19 million members for our Uber One, Eats Pass\nand Rides Pass membership programs.'), Document(metadata={'source': 'docs/lyft.pdf', 'file_path': 'docs/lyft.pdf', 'page': 5, 'total_pages': 143, 'format': 'PDF 1.4', 'title': '0001759509-24-000019', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-20 for the period ending 2023-12-31', 'keywords': '0001759509-24-000019; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240220060533-05'00'", 'modDate': "D:20240220060544-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'a5311654132a4559b6af134d9bfc0e03', '_collection_name': 'holiday-test'}, page_content="they’ll  ...
# What exec mgmt & restructuring costs add to G&A?
# {'response': AIMessage(content='The question is about how executive management and restructuring costs contribute to General and Administrative (G&A) expenses for Uber. Based on the provided excerpts from the 10K report:\n\n1. **Executive Management Costs**: G&A expenses primarily include compensation costs for executive management. This encompasses salaries, stock-based compensation, and potentially other benefits related to executive roles. This information is found in the sections detailing G&A expenses, highlighting the inclusion of executive management compensation.\n\n2. **Restructuring Costs**: The provided document excerpts mention restructuring-related charges as a separate line item. However, these charges may also be considered part of broader corporate costs that could be allocated to G&A if they are not directly associated with specific business segments. In this context, restructuring costs contribute to G&A through the allocation of certain corporate costs, which may include restructuring activities.\n\nIn summary, executive management costs add to G&A expenses through compensation and stock-based compensation for executives. Restructuring costs, while sometimes itemized separately, can contribute to G&A through the allocation of corporate costs related to restructuring activities.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 217, 'prompt_tokens': 1898, 'total_tokens': 2115, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f20662549', 'finish_reason': 'stop', 'logprobs': None}, id='run-ee98a24f-fbf3-444c-b68b-7a058cb260e3-0', usage_metadata={'input_tokens': 1898, 'output_tokens': 217, 'total_tokens': 2115}), 'context': [Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 93, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': 'c682adde857741dca3fd9c23577965fb', '_collection_name': 'holiday-test'}, page_content='•\nGeneral and administrative expenses primarily consist of compensation costs, including stock-based compensation, for executive management and\nadministrative employees, including finance and accounting, human resources, policy and communications, legal, and certain impairment charges, as well\nas allocation of certain corporate costs, occupancy, and general corporate insurance costs. General and administrative expenses also include certain legal\nsettlements.\n•'), Document(metadata={'source': 'docs/uber.pdf', 'file_path': 'docs/uber.pdf', 'page': 53, 'total_pages': 191, 'format': 'PDF 1.4', 'title': '0001543151-24-000012', 'author': 'EDGAR® Online LLC, a subsidiary of OTC Markets Group', 'subject': 'Form 10-K filed on 2024-02-15 for the period ending 2023-12-31', 'keywords': '0001543151-24-000012; ; 10-K', 'creator': 'EDGAR Filing HTML Converter', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creationDate': "D:20240215163245-05'00'", 'modDate': "D:20240215163307-05'00'", 'trapped': '', 'encryption': 'Standard V2 R3 128-bit RC4', '_id': '6b9e4c49fb6e4c27bcd23ec01238ab62', '_collection_name': 'holiday-test'}, page_content='administrative employees, including finance and accounting, human resources, policy and communications, legal, and certain impairment charges, as well as\nallocation of certain corporate costs, occupancy, and general corporate insurance costs. ...
# Evaluating:   0%|          | 0/215 [00:00<?, ?it/s]
# No statements were generated from the answer.
# {'answer_correctness': 0.5956, 'answer_relevancy': 0.8700, 'context_precision': 0.7797, 'context_recall': 0.8560, 'faithfulness': 0.8057}
